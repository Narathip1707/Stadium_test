# %% [markdown]
# # UCD MAIN

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # UCD001

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 📋 Use Case Description: UCD-001 (Login System)
#
# ### **Diagram Information**
# - **Diagram ID:** UCD-001
# - **Use Case Name:** Login System
# - **Scope:** Sports Booking System
# - **Level:** User Goal
# - **Primary Actor:** Customer, Booking Staff, System Administrator, Accounting Staff, Marketing Staff, Managing Director
#
# ---
#
# ### **STAKEHOLDERS (and their interests)**
# - **Customer:** ต้องการเข้าสู่ระบบเพื่อจองสนามและใช้บริการต่างๆ
# - **Booking Staff:** ต้องการเข้าสู่ระบบเพื่อจัดการการจองสนาม
# - **System Administrator:** ต้องการเข้าสู่ระบบเพื่อจัดการผู้ใช้และระบบ
# - **Accounting Staff:** ต้องการเข้าสู่ระบบเพื่อจัดการด้านการเงิน
# - **Marketing Staff:** ต้องการเข้าสู่ระบบเพื่อจัดการโปรโมชันและการตลาด
# - **Managing Director:** ต้องการเข้าสู่ระบบเพื่อดูรายงานและตัดสินใจ
#
# ---
#
# ### **PRE-CONDITION**
# - ระบบพร้อมให้บริการ
# - ผู้ใช้มีบัญชีในระบบแล้ว (สำหรับ Login)
#
# ---
#
# ### **SUCCESS GUARANTEE (Post-Condition)**
# - ผู้ใช้เข้าสู่ระบบสำเร็จ
# - Session ถูกสร้างและเก็บข้อมูลผู้ใช้
# - ผู้ใช้สามารถใช้งานฟังก์ชันตาม Role ได้
#
# ---
#
# ### **MAIN SUCCESS SCENARIO**
#
# | | ACTOR | SYSTEM |
# |---|-------|--------|
# | **1. Register** | | |
# | | **Customer** | |
# | | **กดลงทะเบียน** | - ระบบตรวจสอบข้อมูล |
# | | | - ระบบแสดงหน้าแบบฟอร์มลงทะเบียน |
# | | - กรอกข้อมูล + กดปุ่มลงทะเบียน | - ระบบตรวจสอบความถูกต้อง |
# | | | - ระบบแสดงหน้ายืนยันที่ข้อมูล<br>ลงทะเบียนสำเร็จ |
# | | **กดลงทะเบียนผ่านโซเชียลมีเดีย** | - ระบบตรวจสอบข้อมูล |
# | | | - ระบบแสดงหน้าของบุคคลที่สามจาก<br>โซเชียลมีเดีย (Google/Facebook) |
# | | - กดปุ่มยอมรับการเชื่อมโยงกับโซเชียลมีเดีย | - ระบบตรวจสอบความถูกต้อง |
# | | | - ระบบแสดงหน้ายืนยันที่ข้อมูล<br>ลงทะเบียนสำเร็จ |
# | | | **กรณีลงทะเบียนไม่สำเร็จ** |
# | | | - ระบบแสดงหน้าลงทะเบียนไม่สำเร็จ<br>(ระบุเหตุผล) |
# | **2. Login** | | |
# | | **Customer, Booking Staff, System Administrator, Accounting Staff, Marketing Staff, Managing Director** | |
# | | **กดเข้าสู่ระบบ** | - ระบบตรวจสอบข้อมูล |
# | | | - ระบบแสดงหน้าเข้าสู่ระบบ |
# | | - กรอกอีเมล และ รหัสผ่าน | - ระบบตรวจสอบความถูกต้อง |
# | | | - ระบบแสดงหน้าเข้าสู่ระบบสำเร็จ |
# | | | **กรณีเข้าสู่ระบบไม่สำเร็จ** |
# | | | - ระบบแสดงหน้าเข้าสู่ระบบไม่สำเร็จ<br>(ระบุเหตุผล และกรุณาใช้อีเมล, รหัสผ่านอีกครั้ง) |
# | **3. Forget Password** | | |
# | | **Customer** | |
# | | **กดลืมรหัสผ่าน** | - ระบบตรวจสอบข้อมูล |
# | | | - ระบบแสดงหน้ายืนยันข้อมูลผู้ใช้ |
# | | - กรอกอีเมล + กดปุ่มยืนยัน | - ระบบตรวจสอบความถูกต้อง |
# | | | - ระบบส่งรหัสผ่านชั่วคราวไปยังอีเมล |
# | | | **กรณีไม่พบผู้ใช้** |
# | | | - ระบบแสดงหน้าข้อมูลผู้ใช้ไม่ถูกต้อง<br>(กรุณาใช้อีเมลอีกครั้ง) |
# | | **Booking Staff, Accounting Staff, Marketing Staff** | |
# | | **กดลืมรหัสผ่าน** | - ระบบตรวจสอบความถูกต้อง |
# | | - กรอกอีเมลพนักงาน + กดปุ่มยืนยัน | - ระบบส่งคำขอไปยัง System Administrator<br>หรือ Managing Director |
# | | | - ระบบรอการอนุมัติ |
# | | **System Administrator หรือ Managing Director** | |
# | | - ตรวจสอบและอนุมัติคำขอ | - ระบบส่งรหัสผ่านชั่วคราวไปยังอีเมล<br>พนักงาน |
#
# ---
#
# ### **EXTENSIONS:**
# 1. **กรณีระบบมีข้อง**
#    - 1.1 ให้ผู้ใช้ Refresh หน้าใหม่/ใช้ดี
#    - 1.2 ให้ผู้ใช้เลือก Register and Log in ใหม่
#
# ---
#
# ### **SPECIAL REQUIREMENT:**
# 1. ขั้นต่ำให้ใช้ได้สามารถเข้าได้ในฐานข้อมูล
# 2. กรณีระบบมีข้อง ระบบต้องสำรองข้อมูลหลักไว้เพื่อป้องกันการสูญหาย
# 3. **สำหรับ Staff:** บัญชีต้องถูกสร้างโดย System Administrator เท่านั้น (ไม่สามารถ Register เอง)
#
# ---
#
# ### **TECHNOLOGY AND DATA VARIATION LIST:**
# 1. OAuth (Open Authorization) เพื่อสร้างบัญชีทาง Google หรือ Facebook (สำหรับ Customer เท่านั้น)
# 2. ใช้ระบบ Generate รหัสผ่านชั่วคราว
# 3. ใช้ระบบ Verify อีเมล
#
# ---
#
# ### **FREQUENCY OF OCCURRENCE:**
# - Login: 500-800 ครั้ง/วัน
# - Register: 20-50 ครั้ง/วัน
# - Forget Password: 5-10 ครั้ง/วัน
#
# ---
#
# ### **OPEN ISSUES:**
# 1. ควรเพิ่ม Two-Factor Authentication (2FA) สำหรับ Staff และ Admin
# 2. ควรเปลี่ยนจาก plain text password เป็น hashing (BCrypt/Argon2)

# %% [markdown]
# # UCD002

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 📋 Use Case Description: UCD-002 (System Administrator)
#
# ### **Diagram Information**
# - **Diagram ID:** UCD-002
# - **Use Case Name:** System Administrator Operations
# - **Scope:** Sports Booking System
# - **Level:** User Goal
# - **Primary Actor:** System Administrator
#
# ---
#
# ### **STAKEHOLDERS (and their interests)**
# - **System Administrator:** ต้องการจัดการผู้ใช้, ควบคุมระบบ, รักษาความปลอดภัย และสำรองข้อมูล
# - **All Users:** ต้องการให้ระบบทำงานได้อย่างมีประสิทธิภาพและปลอดภัย
#
# ---
#
# ### **PRE-CONDITION**
# - System Administrator ต้อง login สำเร็จ
# - มี role = "admin" หรือ "system_administrator"
# - ระบบพร้อมให้บริการ
#
# ---
#
# ### **SUCCESS GUARANTEE (Post-Condition)**
# - ข้อมูลผู้ใช้/สนาม/การจองถูกจัดการตามที่ต้องการ
# - ระบบทำงานได้อย่างเสถียร
# - ข้อมูลถูกสำรองและรักษาความปลอดภัย
# - Audit log ถูกบันทึกครบถ้วน
#
# ---
#
# ### **MAIN SUCCESS SCENARIO**
#
# | | ACTOR | SYSTEM |
# |---|-------|--------|
# | **1. User Management** | | |
# | | **System Administrator** | |
# | | **Create User** | - ระบบแสดงฟอร์มสร้างผู้ใช้ใหม่ |
# | | - กรอกข้อมูล (Username, Email, Password, Role, ชื่อ-นามสกุล, เบอร์โทร) | - ระบบตรวจสอบความถูกต้อง |
# | | - กำหนด Role (Booking Staff, Accounting, Marketing, etc.) | - ระบบบันทึกข้อมูลผู้ใช้ใหม่ |
# | | | - ระบบส่งอีเมลยืนยันไปยังผู้ใช้ |
# | | **Edit User** | - ระบบแสดงรายการผู้ใช้ทั้งหมด |
# | | - เลือกผู้ใช้ที่ต้องการแก้ไข | - ระบบแสดงข้อมูลปัจจุบัน |
# | | - แก้ไขข้อมูล (ชื่อ, นามสกุล, อีเมล, เบอร์โทร, Role) | - ระบบอัพเดตข้อมูล |
# | | | - ระบบบันทึก audit log |
# | | **Delete User** | - ระบบแสดงรายการผู้ใช้ |
# | | - เลือกผู้ใช้ที่ต้องการลบ | - ระบบแสดงยืนยันการลบ |
# | | - ยืนยันการลบ | - ระบบลบข้อมูลผู้ใช้ |
# | | | - ระบบบันทึก audit log |
# | | **Assign Roles** | - ระบบแสดงรายการผู้ใช้ |
# | | - เลือกผู้ใช้และกำหนด Role ใหม่ | - ระบบอัพเดต permissions |
# | | | - ระบบบันทึกการเปลี่ยนแปลง |
# | **2. Field Management** | | |
# | | **System Administrator** | |
# | | **View Fields** | - ระบบแสดงรายการสนามทั้งหมด |
# | | **Create Field** | - ระบบแสดงฟอร์มสร้างสนามใหม่ |
# | | - กรอกข้อมูล (ชื่อสนาม, ประเภท, ราคา, เวลาให้บริการ, สถานที่, capacity) | - ระบบตรวจสอบความถูกต้อง |
# | | | - ระบบบันทึกข้อมูลสนาม |
# | | **Edit Field** | - ระบบแสดงรายการสนาม |
# | | - เลือกสนามที่ต้องการแก้ไข | - ระบบแสดงข้อมูลปัจจุบัน |
# | | - แก้ไขข้อมูล (ชื่อสนาม, ราคา, เวลาให้บริการ) | - ระบบอัพเดตข้อมูล |
# | | **Delete Field** | - ระบบแสดงรายการสนาม |
# | | - เลือกสนามที่ต้องการลบ | - ระบบตรวจสอบว่ามีการจองหรือไม่ |
# | | - ยืนยันการลบ | - ระบบลบข้อมูลสนาม (ถ้าไม่มีการจอง) |
# | **3. View Bookings** | | |
# | | **System Administrator** | |
# | | **View All Bookings** | - ระบบแสดงรายการการจองทั้งหมด |
# | | - Filter ตามวันที่/สถานะ | - ระบบแสดงผลตาม filter |
# | | **View Booking History** | - ระบบแสดงประวัติการจองย้อนหลัง |
# | **4. Data Control** | | |
# | | **System Administrator** | |
# | | **Backup Data** | - ระบบแสดงตัวเลือก backup |
# | | - เลือกประเภทข้อมูลที่ต้องการ backup | - ระบบเริ่มกระบวนการ backup |
# | | | - ระบบสร้างไฟล์ backup (.sql) |
# | | | - ระบบแสดงผลสำเร็จ พร้อม timestamp |
# | **5. System Control** | | |
# | | **System Administrator** | |
# | | **View Access Logs** | - ระบบแสดง access logs |
# | | - Filter ตามวันที่/ผู้ใช้ | - ระบบแสดงรายละเอียด logs |
# | **6. System Security** | | |
# | | **System Administrator** | |
# | | **Reset User Password** | - ระบบแสดงรายการผู้ใช้ |
# | | - เลือกผู้ใช้ที่ต้องการ reset | - ระบบ generate รหัสผ่านชั่วคราว |
# | | | - ระบบส่งอีเมลแจ้งผู้ใช้ |
# | | | - ระบบบังคับเปลี่ยน password ครั้งแรก |
#
# ---
#
# ### **EXTENSIONS:**
# 1. **กรณีลบข้อมูลที่มี dependencies**
#    - 1.1 ระบบตรวจพบการจองที่เกี่ยวข้อง
#    - 1.2 ระบบแจ้งเตือนว่าไม่สามารถลบได้
#    - 1.3 แนะนำให้ deactivate แทนการลบ
#
# 2. **กรณี backup ล้มเหลว**
#    - 2.1 ระบบแจ้งข้อผิดพลาด
#    - 2.2 ระบบแนะนำให้ลองใหม่
#    - 2.3 ระบบบันทึก error log
#
# ---
#
# ### **SPECIAL REQUIREMENT:**
# 1. **Security:** ทุกการกระทำต้องบันทึก audit log พร้อม timestamp และ user
# 2. **Data Integrity:** การลบข้อมูลต้องตรวจสอบ foreign key constraints
# 3. **Backup:** ควร backup อัตโนมัติทุกวันเวลา 02:00 น.
# 4. **Access Control:** เฉพาะ System Administrator เท่านั้นที่เข้าถึงได้
#
# ---
#
# ### **TECHNOLOGY AND DATA VARIATION LIST:**
# 1. Database: MySQL 8.0+ with transaction support
# 2. Backup Format: SQL dump files
# 3. Audit Logging: Centralized logging system
# 4. Password Generation: Secure random string generator
#
# ---
#
# ### **FREQUENCY OF OCCURRENCE:**
# - Create User: 5-10 ครั้ง/สัปดาห์
# - Edit User/Field: 20-30 ครั้ง/สัปดาห์
# - View Logs: 50-100 ครั้ง/สัปดาห์
# - Backup Data: 1 ครั้ง/วัน (อัตโนมัติ)
#
# ---
#
# ### **OPEN ISSUES:**
# 1. ควรเพิ่ม role-based access control ที่ละเอียดขึ้น (permissions)
# 2. ควรมี restore data function คู่กับ backup
# 3. ควรเพิ่ม system health monitoring และ alerts

# %% [markdown]
# # UCD 003

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 📋 Use Case Description: UCD-003 (Booking Staff Operations)
#
# ### **Diagram Information**
# - **Diagram ID:** UCD-003
# - **Use Case Name:** Booking Staff Operations
# - **Scope:** Sports Booking System
# - **Level:** User Goal
# - **Primary Actor:** Booking Staff
# - **Secondary Actor:** System Administrator, Managing Director
# - **Support Actor:** Payment Gateway, Logistic System
#
# ---
#
# ### **STAKEHOLDERS (and their interests)**
# - **Booking Staff:** ต้องการจัดการการจองสนามอย่างมีประสิทธิภาพ
# - **Customer:** ต้องการการบริการที่รวดเร็วและถูกต้อง
# - **Managing Director:** ต้องการรายงานและสถิติการจอง
#
# ---
#
# ### **PRE-CONDITION**
# - Booking Staff ต้อง login สำเร็จ
# - มี role = "booking_staff" หรือ "admin"
# - ระบบพร้อมให้บริการ
#
# ---
#
# ### **SUCCESS GUARANTEE (Post-Condition)**
# - การจองถูกสร้าง/แก้ไข/ลบตามที่ต้องการ
# - Order-ID ถูกส่งไปยัง Logistic System
# - Tracking number ถูกบันทึก
# - Customer ได้รับ notification
# - ข้อมูลถูกบันทึกใน audit log
#
# ---
#
# ### **MAIN SUCCESS SCENARIO**
#
# | | ACTOR | SYSTEM |
# |---|-------|--------|
# | **1. Create Booking** | | |
# | | **Booking Staff** | |
# | | - เลือก "Create Booking" | - ระบบแสดงฟอร์มสร้างการจองใหม่ |
# | | - กรอกข้อมูล (Customer, สนาม, วันที่, เวลาเริ่ม-สิ้นสุด) | - ระบบตรวจสอบความว่างของสนาม |
# | | | - ระบบคำนวณราคา |
# | | - ยืนยันการจอง | - ระบบบันทึกการจอง |
# | | | - ระบบสร้าง order-id |
# | | | - ระบบส่ง order-id ไปยัง Logistic System |
# | | | - ระบบรับ tracking number กลับมา |
# | | | - ระบบแจ้งเตือน Customer |
# | **2. Search Bookings** | | |
# | | **Booking Staff, System Administrator** | |
# | | - เลือก "Search Bookings" | - ระบบแสดงหน้าค้นหา พร้อมฟิลเตอร์ |
# | | - ใส่เงื่อนไข (วันที่, สนาม, Customer, สถานะ) | - ระบบค้นหาและแสดงผลลัพธ์ |
# | **3. Edit Booking** | | |
# | | **Booking Staff** | |
# | | - เลือกการจองที่ต้องการแก้ไข | - ระบบแสดงข้อมูลปัจจุบัน |
# | | - แก้ไขข้อมูล (วันที่, เวลา, สนาม) | - ระบบตรวจสอบความว่าง |
# | | | - ระบบคำนวณราคาใหม่ |
# | | - ยืนยันการแก้ไข | - ระบบอัพเดตข้อมูล |
# | | | - ระบบแจ้งเตือน Customer |
# | **4. Delete Booking** | | |
# | | **Booking Staff** | |
# | | - เลือกการจองที่ต้องการลบ | - ระบบแสดงข้อมูลการจอง |
# | | - ยืนยันการลบ | - ระบบตรวจสอบสถานะการชำระเงิน |
# | | | - ระบบลบการจอง (ถ้ายังไม่ชำระ) |
# | | | - ระบบ process refund (ถ้าชำระแล้ว) |
# | **5. Approve Booking** | | |
# | | **Booking Staff, System Administrator** | |
# | | - เลือกการจองและคลิก "Approve" | - ระบบแสดงข้อมูลการจองสำหรับตรวจสอบ |
# | | - ยืนยันการอนุมัติ | - ระบบอัพเดตสถานะเป็น "Approved" |
# | | | - ระบบแจ้งเตือน Customer |
# | **6. Reject Booking** | | |
# | | **Booking Staff, System Administrator** | |
# | | - เลือกการจองและคลิก "Reject" | - ระบบแสดงฟอร์มใส่เหตุผล |
# | | - ใส่เหตุผลการปฏิเสธ | - ระบบอัพเดตสถานะเป็น "Rejected" |
# | | | - ระบบบันทึก log พร้อมเหตุผล |
# | | | - ระบบแจ้งเตือน Customer พร้อมเหตุผล |
# | **7. Manage Schedule** | | |
# | | **Booking Staff** | |
# | | - เลือก "Manage Schedule" | - ระบบแสดงปฏิทินการจองรายสนาม |
# | | - แก้ไขตารางการจอง | - ระบบตรวจสอบความขัดแย้ง |
# | | | - ระบบอัพเดตตาราง |
# | **8. Process Payment** | | |
# | | **Booking Staff** | |
# | | - เลือกการจองที่ต้องการชำระเงิน | - ระบบแสดงข้อมูลการจองและราคา |
# | | - เลือกช่องทางชำระเงิน | - ระบบเชื่อมต่อ Payment Gateway |
# | | **Payment Gateway** | |
# | | - ส่งสถานะการชำระเงิน | - ระบบอัพเดตสถานะการชำระ |
# | | | - ระบบส่งการยืนยันกลับไปยัง Gateway |
# | **9. Track Delivery** | | |
# | | **Booking Staff** | |
# | | - เลือก "Track Delivery" | - ระบบแสดงข้อมูล tracking |
# | | - ป้อน tracking number หรือ order-id | - ระบบ query Logistic System |
# | | | - ระบบแสดงสถานะการส่งมอบ |
# | **10. View Customer Information** | | |
# | | **Booking Staff** | |
# | | - เลือก Customer จากรายการจอง | - ระบบแสดงข้อมูล Customer |
# | | | - ชื่อ-นามสกุล, เบอร์โทร, อีเมล |
# | | | - ประวัติการจอง |
# | **11. Answer Customer Inquiry** | | |
# | | **Booking Staff** | |
# | | - รับคำถามจาก Customer | - ระบบแสดงข้อมูลที่เกี่ยวข้อง |
# | | - ตอบคำถามและให้ข้อมูล | - ระบบบันทึกการสนทนา |
# | **12. View Reports** | | |
# | | **Managing Director** | |
# | | - เลือก "View Reports" | - ระบบแสดงรายงานการจองและสถิติ |
# | | - เลือกประเภทรายงาน (รายวัน/เดือน/ปี) | - ระบบ generate รายงาน |
#
# ---
#
# ### **EXTENSIONS:**
# 1. **สนามไม่ว่าง**
#    - 1.1 ระบบตรวจพบการจองซ้อนทับ
#    - 1.2 แสดง "สนามไม่ว่าง กรุณาเลือกช่วงเวลาอื่น"
#    - 1.3 แนะนำช่วงเวลาว่าง
#
# 2. **ระบบภายนอกขัดข้อง**
#    - 2.1 Payment Gateway/Logistic ไม่ตอบสนอง
#    - 2.2 แสดงข้อความแจ้งเตือน
#    - 2.3 Retry อัตโนมัติ 3 ครั้ง
#    - 2.4 ถ้ายังล้มเหลว → บันทึก log และแจ้ง Admin
#
# ---
#
# ### **SPECIAL REQUIREMENT:**
# 1. **Concurrency:** ตรวจสอบ concurrent booking ป้องกัน double-booking
# 2. **Performance:** เวลาในการตอบสนองต้องไม่เกิน 3 วินาที
# 3. **Audit Trail:** Log ทุกการดำเนินการพร้อม timestamp
# 4. **Real-time:** สถานะต้องอัพเดตแบบ real-time
#
# ---
#
# ### **TECHNOLOGY AND DATA VARIATION LIST:**
# 1. Web Browser: Chrome, Edge, Firefox
# 2. Database: MySQL 8.0+ with locking mechanism
# 3. API Integration: REST API สำหรับ Payment Gateway และ Logistic
# 4. Session Management: Jakarta EE Session API
#
# ---
#
# ### **FREQUENCY OF OCCURRENCE:**
# - Create Booking: 200-300 ครั้ง/วัน (Peak ช่วงเย็น)
# - Search: 500-800 ครั้ง/วัน
# - Approve/Reject: 100-150 ครั้ง/วัน
# - View Reports: 20-50 ครั้ง/วัน
#
# ---
#
# ### **OPEN ISSUES:**
# 1. ควรมี bulk operations สำหรับจัดการหลายการจองพร้อมกัน
# 2. ควรเพิ่ม real-time notification system
# 3. ควรเพิ่ม performance optimization ด้วย caching

# %% [markdown]
# # UCD 004

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 📋 Use Case Description: UCD-004 (Accounting Staff)
#
# ### **Diagram Information**
# - **Diagram ID:** UCD-004
# - **Use Case Name:** Accounting Operations
# - **Scope:** Sports Booking System
# - **Level:** User Goal
# - **Primary Actor:** Accounting Staff
# - **Secondary Actor:** System Administrator, Managing Director
# - **Support Actor:** Payment Gateway
#
# ---
#
# ### **STAKEHOLDERS (and their interests)**
# - **Accounting Staff:** ต้องการจัดการด้านการเงินและบัญชีอย่างถูกต้องครบถ้วน
# - **Managing Director:** ต้องการรายงานการเงินที่แม่นยำสำหรับตัดสินใจ
# - **Customer:** ต้องการใบเสร็จและการคืนเงินที่ถูกต้อง
#
# ---
#
# ### **PRE-CONDITION**
# - Accounting Staff ต้อง login สำเร็จ
# - มี role = "accounting_staff" หรือ "admin"
# - Payment Gateway พร้อมใช้งาน
#
# ---
#
# ### **SUCCESS GUARANTEE (Post-Condition)**
# - รายการชำระเงินถูกอัพเดต
# - Invoice ถูกสร้าง (ถ้ามี)
# - รายงานการเงินถูก generate
# - ข้อมูลถูก export (ถ้าต้องการ)
# - Audit log ถูกบันทึก
#
# ---
#
# ### **MAIN SUCCESS SCENARIO**
#
# | | ACTOR | SYSTEM |
# |---|-------|--------|
# | **1. Manage Payment Records** | | |
# | | **Accounting Staff** | |
# | | - เลือก "Manage Payment Records" | - ระบบแสดงรายการชำระเงินทั้งหมด |
# | | - Filter ตาม (วันที่, สถานะ, Customer, ยอดเงิน) | - ระบบแสดงผลตาม filter |
# | | - ดูรายละเอียดการชำระเงิน | - ระบบแสดง: ชื่อ, นามสกุล, ยอดเงิน, วิธีชำระ, สถานะ |
# | **2. Verify Payment Status** | | |
# | | **Accounting Staff** | |
# | | - เลือกรายการที่ต้องการตรวจสอบ | - ระบบแสดงข้อมูลการชำระเงิน |
# | | | - สถานะการโอนเงิน |
# | | | - ช่องทางการชำระเงิน (QR/Transfer/Card) |
# | | - ตรวจสอบและยืนยันสถานะ | - ระบบอัพเดตสถานะ |
# | **3. Process Refund** | | |
# | | **Accounting Staff** | |
# | | - เลือกการจองที่ต้องการคืนเงิน | - ระบบแสดงข้อมูลการชำระเงิน |
# | | - คำนวณจำนวนเงินคืน | - ระบบแสดงยอดคืนตาม policy |
# | | - ยืนยันการคืนเงิน | - ระบบ process refund via Payment Gateway |
# | | **Payment Gateway** | |
# | | - ประมวลผลคืนเงิน | - ระบบอัพเดตสถานะเป็น "Refunded" |
# | | | - ระบบแจ้งเตือน Customer |
# | **4. Generate Invoice** | | |
# | | **Accounting Staff** | |
# | | - เลือกการชำระเงินที่ต้องการออก Invoice | - ระบบดึงข้อมูลการชำระเงิน |
# | | - กำหนดรายละเอียดเพิ่มเติม (ถ้ามี) | - ระบบสร้าง Invoice พร้อมหมายเลข |
# | | | - ระบบรวมข้อมูล Customer และรายการ |
# | | - Approve Invoice | - ระบบส่ง Invoice ให้ Customer |
# | **5. Reconcile Transactions** | | |
# | | **Accounting Staff** | |
# | | - เลือก "Reconcile Transactions" | - ระบบแสดงรายการที่ต้อง reconcile |
# | | - จับคู่การชำระเงินกับการจอง | - ระบบตรวจสอบความถูกต้อง |
# | | - ระบุรายการที่ไม่ตรงกัน | - ระบบแสดงรายการที่มีปัญหา |
# | | - แก้ไขและ resolve conflicts | - ระบบอัพเดตสถานะ |
# | **6. View Revenue Analytics** | | |
# | | **Accounting Staff, Managing Director** | |
# | | - เลือก "View Revenue Analytics" | - ระบบแสดง dashboard รายรับ |
# | | - เลือกช่วงเวลา (วัน/เดือน/ปี) | - ระบบแสดง: |
# | | | - ยอดทั้งหมดจากสนามที่มี |
# | | | - รายรับรายวัน |
# | | | - รายรับรายเดือน |
# | | | - รายรับรายปี |
# | | | - Trend analysis และ charts |
# | **7. Generate Financial Report** | | |
# | | **Accounting Staff, Managing Director** | |
# | | - เลือก "Generate Financial Report" | - ระบบแสดงตัวเลือกประเภทรายงาน |
# | | - เลือกประเภท (รายวัน/เดือน/ปี) | - ระบบ generate รายงาน |
# | | - เลือกช่วงวันที่ | - ระบบแสดงสรุปรายรับ-รายจ่าย |
# | | | - ระบบแสดง breakdown ตามสนาม |
# | **8. Export Financial Data** | | |
# | | **Accounting Staff** | |
# | | - เลือก "Export Financial Data" | - ระบบแสดงตัวเลือก export |
# | | - เลือกช่วงข้อมูลและรูปแบบ (CSV/Excel/PDF) | - ระบบสร้างไฟล์ export |
# | | - ดาวน์โหลดไฟล์ | - ระบบส่งไฟล์ให้ download |
# | **9. Audit Financial Records** | | |
# | | **Accounting Staff** | |
# | | - เลือก "Audit Financial Records" | - ระบบแสดงรายการทุก transaction |
# | | - ตรวจสอบความถูกต้อง | - ระบบแสดง audit trail |
# | | - สร้างรายงาน audit | - ระบบ generate รายงาน compliance |
# | **10. View Customer Information** | | |
# | | **Accounting Staff** | |
# | | - เลือก Customer จากรายการชำระเงิน | - ระบบแสดงข้อมูล Customer: |
# | | | - ชื่อ-นามสกุล |
# | | | - เบอร์โทรศัพท์, อีเมล |
# | | | - ประวัติการชำระเงิน |
#
# ---
#
# ### **EXTENSIONS:**
# 1. **Payment Gateway timeout**
#    - 1.1 ระบบไม่ได้รับ response ภายใน timeout period
#    - 1.2 Retry 3 ครั้ง
#    - 1.3 ถ้าล้มเหลว → บันทึก log และแจ้ง Admin
#
# 2. **Refund failed**
#    - 2.1 Refund process ล้มเหลว
#    - 2.2 Escalate to manual processing
#    - 2.3 แจ้ง Accounting Staff และ Customer
#
# ---
#
# ### **SPECIAL REQUIREMENT:**
# 1. **Accuracy:** รายงานการเงินต้องแม่นยำ 100%
# 2. **Compliance:** ทุก transaction ต้องมี audit trail
# 3. **Security:** ข้อมูลการเงินต้องเข้ารหัส
# 4. **Performance:** Response time < 5 วินาที
#
# ---
#
# ### **TECHNOLOGY AND DATA VARIATION LIST:**
# 1. Payment Gateway API integration
# 2. Export formats: CSV, Excel, PDF
# 3. Chart libraries สำหรับ analytics
# 4. Encryption สำหรับข้อมูลละเอียดอ่อน
#
# ---
#
# ### **FREQUENCY OF OCCURRENCE:**
# - Verify Payment: 100-200 ครั้ง/วัน
# - Generate Report: 50-100 ครั้ง/วัน
# - Reconcile: 1-2 ครั้ง/วัน
# - Export Data: 10-20 ครั้ง/วัน
#
# ---
#
# ### **OPEN ISSUES:**
# 1. ควรเพิ่ม automated reconciliation
# 2. ควรมี real-time revenue dashboard
# 3. ควรเพิ่ม advanced analytics และ forecasting

# %% [markdown]
# # UCD 005

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 📋 Use Case Description: UCD-005 (Managing Director)
#
# ### **Diagram Information**
# - **Diagram ID:** UCD-005
# - **Use Case Name:** Managing Director Operations
# - **Scope:** Sports Booking System
# - **Level:** Executive Goal
# - **Primary Actor:** Managing Director
# - **Secondary Actor:** System Administrator
#
# ---
#
# ### **STAKEHOLDERS (and their interests)**
# - **Managing Director:** ต้องการภาพรวมธุรกิจ รายงานการเงิน และข้อมูลสำหรับตัดสินใจ
# - **ผู้ถือหุ้น:** ต้องการผลประกอบการที่ดีและการเติบโตของธุรกิจ
#
# ---
#
# ### **PRE-CONDITION**
# - Managing Director ต้อง login สำเร็จ
# - มี role = "managing_director"
# - มีสิทธิ์เข้าถึงข้อมูลทุกระดับ
#
# ---
#
# ### **SUCCESS GUARANTEE (Post-Condition)**
# - ได้รับข้อมูลและรายงานที่ต้องการ
# - สามารถตัดสินใจได้อย่างมีข้อมูลรองรับ
# - การตัดสินใจสำคัญถูกบันทึก
#
# ---
#
# ### **MAIN SUCCESS SCENARIO**
#
# | | ACTOR | SYSTEM |
# |---|-------|--------|
# | **1. View Executive Dashboard** | | |
# | | **Managing Director** | |
# | | - เลือก "Executive Dashboard" | - ระบบแสดง overview ภาพรวมธุรกิจ: |
# | | | - Key Performance Indicators (KPIs) |
# | | | - สถิติ real-time |
# | | | - สรุปรายรับรายวัน |
# | | | - อัตราการใช้สนาม |
# | **2. View Revenue Reports** | | |
# | | **Managing Director** | |
# | | - เลือก "View Revenue Reports" | - ระบบแสดงรายงานรายรับ: |
# | | | - ยอดทั้งหมดจากสนามที่มี |
# | | | - รายรับรายวัน |
# | | | - รายรับรายเดือน |
# | | | - รายรับรายปี |
# | | - Export เป็น PDF/Excel | - ระบบสร้างไฟล์ export |
# | **3. Analyze Business Performance** | | |
# | | **Managing Director** | |
# | | - เลือก "Analyze Business Performance" | - ระบบแสดงการวิเคราะห์: |
# | | | - สถานะการจอง (confirmed/pending/cancelled) |
# | | | - สถานะการชำระเงิน (paid/unpaid) |
# | | | - จำนวนสนามที่ถูกใช้งาน |
# | | | - Trend analysis |
# | | | - Comparison ย้อนหลัง |
# | **4. Monitor System Usage** | | |
# | | **Managing Director** | |
# | | - เลือก "Monitor System Usage" | - ระบบแสดงสถิติการใช้งาน: |
# | | | - สนามที่มีผู้ใช้บริการสูงสุด |
# | | | - Peak hours analysis |
# | | | - Occupancy rate ตามสนาม |
# | | | - Customer demographics |
# | **5. Field Management** | | |
# | | **Managing Director** | |
# | | **View Fields** | - ระบบแสดงรายการสนามทั้งหมด |
# | | | - พร้อมสถิติการใช้งาน |
# | | **Create Field** | - ระบบแสดงฟอร์มสร้างสนามใหม่ |
# | | - กรอกข้อมูล (ชื่อสนาม, ราคา, เวลาให้บริการ) | - ระบบบันทึกข้อมูล |
# | | **Edit Field** | - ระบบแสดงข้อมูลปัจจุบัน |
# | | - แก้ไข (ชื่อสนาม, ราคา, เวลาให้บริการ) | - ระบบอัพเดตข้อมูล |
# | | **Delete Field** | - ระบบตรวจสอบการจองที่เกี่ยวข้อง |
# | | - ยืนยันการลบ | - ระบบลบข้อมูล (ถ้าไม่มีการจอง) |
# | **6. Customer Management** | | |
# | | **Managing Director** | |
# | | **View Customer List** | - ระบบแสดงรายการลูกค้าทั้งหมด |
# | | **View Customer Details** | - ระบบแสดงข้อมูล: |
# | | - เลือก Customer | - ชื่อ-นามสกุล |
# | | | - เบอร์โทรศัพท์ |
# | | | - อีเมล |
# | | | - สถิติการใช้บริการ |
# | | **View Customer Booking History** | - ระบบแสดงประวัติการจอง: |
# | | | - สนาม, วันที่ |
# | | | - เวลาเริ่ม-สิ้นสุด |
# | | | - ราคา, สถานะ |
# | **7. Review Strategic Plans** | | |
# | | **Managing Director** | |
# | | - เลือก "Review Strategic Plans" | - ระบบแสดงแผนธุรกิจ |
# | | - ทบทวนผลการดำเนินงาน vs เป้าหมาย | - ระบบแสดงการเปรียบเทียบ |
# | | - ปรับแผนกลยุทธ์ | - ระบบบันทึกการเปลี่ยนแปลง |
# | **8. Approve Major Decisions** | | |
# | | **Managing Director** | |
# | | - ทบทวนการตัดสินใจสำคัญที่รออนุมัติ | - ระบบแสดงรายการรอ approval |
# | | - Approve/Reject การเปลี่ยนแปลงสำคัญ | - ระบบอัพเดตสถานะ |
# | | - ระบุเหตุผล (ถ้า reject) | - ระบบบันทึก audit log |
# | **9. Set Business Policies** | | |
# | | **Managing Director** | |
# | | - กำหนดนโยบายธุรกิจ | - ระบบแสดงฟอร์มกำหนดนโยบาย |
# | | - Set pricing policies | - ระบบอัพเดต pricing rules |
# | | - Configure operational policies | - ระบบนำไปใช้ทั่วทั้งระบบ |
# | **10. Access Control Management** | | |
# | | **Managing Director** | |
# | | - จัดการสิทธิ์การเข้าถึงระดับสูง | - ระบบแสดงการตั้งค่า permissions |
# | | - Set access levels | - ระบบอัพเดต access control |
# | **11. Review Audit Reports** | | |
# | | **Managing Director** | |
# | | - เลือก "Review Audit Reports" | - ระบบแสดงรายงาน audit: |
# | | | - Financial audits |
# | | | - System audits |
# | | | - Compliance reports |
# | **12. Monitor System Health** | | |
# | | **Managing Director** | |
# | | - เลือก "Monitor System Health" | - ระบบแสดงสถานะระบบ: |
# | | | - Server status |
# | | | - Database health |
# | | | - System performance metrics |
#
# ---
#
# ### **EXTENSIONS:**
# 1. **ข้อมูลไม่เพียงพอ**
#    - 1.1 ระบบแจ้งว่าต้องการข้อมูลเพิ่ม
#    - 1.2 แนะนำให้รอจนข้อมูลครบ
#
# 2. **การอนุมัติถูกปฏิเสธ**
#    - 2.1 บันทึกเหตุผลการปฏิเสธ
#    - 2.2 แจ้งผู้เสนอพร้อมเหตุผล
#
# ---
#
# ### **SPECIAL REQUIREMENT:**
# 1. **Confidentiality:** ข้อมูลต้องมีความปลอดภัยสูง
# 2. **Real-time:** Dashboard ต้องแสดงข้อมูล near real-time
# 3. **Accuracy:** รายงานต้องถูกต้องแม่นยำ
# 4. **Audit:** ทุกการตัดสินใจต้องมี audit trail
#
# ---
#
# ### **TECHNOLOGY AND DATA VARIATION LIST:**
# 1. Business Intelligence (BI) tools
# 2. Dashboard visualization libraries
# 3. Export formats: PDF, Excel, PowerPoint
# 4. Mobile responsive สำหรับดูบน tablet/phone
#
# ---
#
# ### **FREQUENCY OF OCCURRENCE:**
# - View Dashboard: 10-20 ครั้ง/วัน
# - View Reports: 5-10 ครั้ง/วัน
# - Field Management: 2-5 ครั้ง/สัปดาห์
# - Customer Management: 5-10 ครั้ง/สัปดาห์
# - Strategic Review: 1-2 ครั้ง/เดือน
#
# ---
#
# ### **OPEN ISSUES:**
# 1. ควรเพิ่ม predictive analytics
# 2. ควรมี mobile app สำหรับ Executive
# 3. ควรเพิ่ม automated alerts สำหรับ KPIs ผิดปกติ

# %% [markdown]
# # UCD 006

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 📋 Use Case Description: UCD-006 (Marketing Staff)
#
# ### **Diagram Information**
# - **Diagram ID:** UCD-006
# - **Use Case Name:** Marketing Operations
# - **Scope:** Sports Booking System
# - **Level:** User Goal
# - **Primary Actor:** Marketing Staff
# - **Secondary Actor:** Managing Director, System Administrator
#
# ---
#
# ### **STAKEHOLDERS (and their interests)**
# - **Marketing Staff:** ต้องการจัดการโปรโมชันและวิเคราะห์พฤติกรรมลูกค้า
# - **Customer:** ต้องการโปรโมชันและข้อเสนอพิเศษ
# - **Managing Director:** ต้องการ ROI จากการทำ marketing
#
# ---
#
# ### **PRE-CONDITION**
# - Marketing Staff ต้อง login สำเร็จ
# - มี role = "marketing_staff" หรือ "admin"
# - มีข้อมูลการจองและลูกค้าเพียงพอสำหรับวิเคราะห์
#
# ---
#
# ### **SUCCESS GUARANTEE (Post-Condition)**
# - โปรโมชันถูกสร้าง/แก้ไข/ลบ
# - Campaign ถูก launch
# - รายงาน marketing ถูก generate
# - ข้อมูล analytics ถูกวิเคราะห์
#
# ---
#
# ### **MAIN SUCCESS SCENARIO**
#
# | | ACTOR | SYSTEM |
# |---|-------|--------|
# | **1. Promotion Management** | | |
# | | **Marketing Staff** | |
# | | **Create Promotion** | - ระบบแสดงฟอร์มสร้างโปรโมชัน |
# | | - กรอกข้อมูล: | - ระบบตรวจสอบความถูกต้อง |
# | | • ชื่อโปรโมชัน | |
# | | • ประเภท (รายวัน/รายเดือน) | |
# | | • ส่วนลด (%, บาท) | |
# | | • วันที่เริ่มต้น-สิ้นสุด | |
# | | • สนามที่ใช้ได้ | |
# | | - ยืนยันสร้างโปรโมชัน | - ระบบบันทึกโปรโมชัน |
# | | | - ระบบ activate โปรโมชัน |
# | | **Edit Promotion** | - ระบบแสดงรายการโปรโมชัน |
# | | - เลือกโปรโมชันที่ต้องการแก้ไข | - ระบบแสดงข้อมูลปัจจุบัน |
# | | - แก้ไขรายละเอียด | - ระบบอัพเดตข้อมูล |
# | | **Delete Promotion** | - ระบบแสดงรายการโปรโมชัน |
# | | - เลือกโปรโมชันที่ต้องการลบ | - ระบบตรวจสอบการใช้งาน |
# | | - ยืนยันการลบ | - ระบบลบโปรโมชัน |
# | | **Activate/Deactivate Promotion** | - ระบบเปลี่ยนสถานะโปรโมชัน |
# | | - Toggle สถานะ | - ระบบอัพเดต visibility |
# | **2. Campaign Management** | | |
# | | **Marketing Staff** | |
# | | **Plan Seasonal Campaign** | - ระบบแสดงฟอร์ม campaign |
# | | - สร้างแคมเปญตามฤดูกาล | - ระบบบันทึก campaign details |
# | | - กำหนด target audience | - ระบบ segment customers |
# | | - Set campaign budget และ goals | - ระบบติดตาม metrics |
# | | **Create Special Event** | - ระบบแสดงฟอร์ม event |
# | | - วางแผนกิจกรรมพิเศษ | - ระบบบันทึกรายละเอียด |
# | | - กำหนดวันเวลาและสถานที่ | - ระบบจองสนามสำหรับ event |
# | | **Coordinate with Booking Staff** | - ระบบส่งข้อมูล event |
# | | - แจ้งรายละเอียดกิจกรรมพิเศษ | - Booking Staff รับทราบ |
# | | - ประสานงานการจัดงาน | - ระบบ track coordination |
# | | **Track Campaign Performance** | - ระบบแสดง campaign metrics: |
# | | | - Conversion rate |
# | | | - Customer acquisition |
# | | | - ROI |
# | **3. Field Popularity Analysis** | | |
# | | **Marketing Staff** | |
# | | **View Field Popularity** | - ระบบแสดงสถิติความนิยม: |
# | | - เลือกช่วงเวลาที่ต้องการวิเคราะห์ | - สนามที่ได้รับความนิยมสูงสุด |
# | | | - Peak hours แต่ละสนาม |
# | | | - Seasonal trends |
# | | **Analyze by Time Period** | - ระบบแสดงการวิเคราะห์: |
# | | | - Usage by hour/day/month |
# | | | - Occupancy rates |
# | | | - Popular time slots |
# | **4. Customer Analytics** | | |
# | | **Marketing Staff** | |
# | | **View Customer Information** | - ระบบแสดงข้อมูลลูกค้า: |
# | | - เลือก segment ที่ต้องการ | - ชื่อ (aggregated) |
# | | | - พฤติกรรมการจอง |
# | | | - ความถี่การใช้บริการ |
# | | **Customer Segmentation** | - ระบบแบ่งกลุ่มลูกค้า: |
# | | | - VIP customers |
# | | | - Regular customers |
# | | | - New customers |
# | | | - Inactive customers |
# | | **Analyze Booking Patterns** | - ระบบวิเคราะห์รูปแบบ: |
# | | | - Preferred fields |
# | | | - Preferred times |
# | | | - Average spending |
# | | **Analyze Purchase Behavior** | - ระบบวิเคราะห์: |
# | | | - Response to promotions |
# | | | - Price sensitivity |
# | | | - Booking frequency |
# | **5. View Analytics Dashboard** | | |
# | | **Marketing Staff, Managing Director** | |
# | | - เลือก "Marketing Analytics" | - ระบบแสดง dashboard: |
# | | | - Marketing KPIs |
# | | | - Campaign performance |
# | | | - Promotion effectiveness |
# | | | - Customer trends |
# | **6. Generate Sales Report** | | |
# | | **Marketing Staff** | |
# | | - เลือก "Generate Sales Report" | - ระบบ generate รายงาน: |
# | | - เลือกช่วงเวลา | - Sales by period |
# | | | - Sales by field |
# | | | - Conversion rates |
# | | | - Attribution analysis |
# | **7. Generate Marketing Report** | | |
# | | **Marketing Staff** | |
# | | - เลือก "Generate Marketing Report" | - ระบบ generate รายงาน: |
# | | | - Campaign performance |
# | | | - Promotion ROI |
# | | | - Customer acquisition cost |
# | | | - Marketing effectiveness |
# | **8. Export Data** | | |
# | | **Marketing Staff** | |
# | | - เลือก "Export Data" | - ระบบแสดงตัวเลือก |
# | | - เลือกข้อมูลและรูปแบบ (Excel/CSV) | - ระบบสร้างไฟล์ export |
# | | - ดาวน์โหลด | - ระบบส่งไฟล์ |
# | **9. Send Email Report** | | |
# | | **Marketing Staff** | |
# | | - เลือก "Send Email Report" | - ระบบแสดงฟอร์ม |
# | | - เลือกรายงานและผู้รับ | - ระบบส่งอีเมลพร้อม attachment |
#
# ---
#
# ### **EXTENSIONS:**
# 1. **โปรโมชันซ้ำกัน**
#    - 1.1 ระบบตรวจพบโปรโมชันซ้อนทับ
#    - 1.2 แจ้งเตือนและขอยืนยัน
#    - 1.3 ปรับเงื่อนไขหรือยกเลิก
#
# 2. **ไม่มีข้อมูลเพียงพอ**
#    - 2.1 ระบบแจ้งว่าต้องการข้อมูลอย่างน้อย 7 วัน
#    - 2.2 แนะนำให้รอหรือใช้ข้อมูลที่มี
#
# ---
#
# ### **SPECIAL REQUIREMENT:**
# 1. **Privacy:** ข้อมูลลูกค้าต้อง anonymized สำหรับ analytics
# 2. **Real-time:** Analytics ต้อง near real-time
# 3. **Flexibility:** สามารถสร้างโปรโมชันได้หลากหลาย
# 4. **Tracking:** ต้อง track ROI ของทุก campaign
#
# ---
#
# ### **TECHNOLOGY AND DATA VARIATION LIST:**
# 1. Analytics tools และ visualization
# 2. Email marketing integration
# 3. Customer segmentation algorithms
# 4. Export formats: Excel, CSV, PDF
#
# ---
#
# ### **FREQUENCY OF OCCURRENCE:**
# - Create/Edit Promotion: 10-20 ครั้ง/สัปดาห์
# - View Analytics: 50-100 ครั้ง/วัน
# - Generate Reports: 20-30 ครั้ง/สัปดาห์
# - Campaign Management: 5-10 ครั้ง/เดือน
#
# ---
#
# ### **OPEN ISSUES:**
# 1. ควรเพิ่ม A/B testing สำหรับโปรโมชัน
# 2. ควรมี automated campaign triggers
# 3. ควรเพิ่ม customer lifetime value analysis

# %% [markdown]
# # UCD 007

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 📋 Use Case Description: UCD-007 (Payment Gateway Integration)
#
# ### **Diagram Information**
# - **Diagram ID:** UCD-007
# - **Use Case Name:** Payment Gateway Integration
# - **Scope:** Sports Booking System - External Integration
# - **Level:** System Goal
# - **Primary Actor:** Payment Gateway (Supporting System)
# - **Secondary Actor:** Customer, System Administrator, Accounting Staff
#
# ---
#
# ### **STAKEHOLDERS (and their interests)**
# - **Payment Gateway:** ต้องการประมวลผลการชำระเงินที่ถูกต้องและปลอดภัย
# - **Customer:** ต้องการชำระเงินได้สะดวกและปลอดภัย
# - **Accounting Staff:** ต้องการข้อมูลการชำระเงินที่แม่นยำ
#
# ---
#
# ### **PRE-CONDITION**
# - ระบบเชื่อมต่อกับ Payment Gateway สำเร็จ
# - Customer เลือกช่องทางการชำระเงิน
# - Booking มีข้อมูลครบถ้วน
#
# ---
#
# ### **SUCCESS GUARANTEE (Post-Condition)**
# - Payment processed (Success/Failed)
# - Transaction File ถูกส่งและบันทึก
# - Payment Status อัพเดต real-time
# - Receipt ถูกสร้าง (ถ้าสำเร็จ)
# - Accounting Staff ได้รับข้อมูล
# - Customer ได้รับ notification
#
# ---
#
# ### **MAIN SUCCESS SCENARIO**
#
# | | ACTOR | SYSTEM |
# |---|-------|--------|
# | **1. Process Payment** | | |
# | | **Customer** | |
# | | - เลือก payment method (QR/Transfer/Card) | - ระบบแสดงตัวเลือกการชำระเงิน |
# | | - กรอกข้อมูลการชำระ | - ระบบส่งข้อมูลไป Payment Gateway |
# | | **Payment Gateway** | |
# | | - รับข้อมูลการชำระเงิน | - Validate transaction |
# | | - ประมวลผลการชำระเงิน | - Process payment |
# | | **Send Payment Confirmation** | |
# | | - ส่ง confirmation กลับ | - ระบบรับและตรวจสอบ |
# | | | - Update booking status |
# | **2. Handle Payment Response** | | |
# | | **Payment Gateway** | |
# | | - ส่ง response พร้อม transaction data | - ระบบรับ response |
# | | | - Parse transaction data |
# | | | - Extract payment details |
# | | | - ประมวลผลตามสถานะ |
# | | **Generate Payment Receipt** | |
# | | | - สร้างใบเสร็จอัตโนมัติ |
# | | | - รวม transaction details |
# | | | - ส่งให้ Customer (email/download) |
# | **3. Send Payment Status** | | |
# | | **Payment Gateway** | |
# | | - ส่ง Transaction File พร้อมสถานะ | - ระบบรับข้อมูล (real-time) |
# | | | - อัพเดตฐานข้อมูล |
# | | | - แจ้ง Accounting Staff |
# | | | - Notify System Admin (if needed) |
# | **4. Verify Payment** | | |
# | | **Accounting Staff** | |
# | | - ตรวจสอบการชำระเงิน | - ระบบส่งคำขอไป Payment Gateway |
# | | **Payment Gateway** | |
# | | - ยืนยันการรับเงิน | - ระบบอัพเดตสถานะ |
# | | - ส่งข้อมูลการยืนยัน | - Reconcile transaction |
# | | | - Match with bank statement |
# | **5. Process Refund** | | |
# | | **Accounting Staff** | |
# | | - Request refund | - ระบบส่งคำขอไป Payment Gateway |
# | | **Payment Gateway** | |
# | | - Validate refund eligibility | - ระบบตรวจสอบข้อมูล |
# | | - Process refund | - อัพเดตสถานะเป็น "Refunded" |
# | | - ส่งการยืนยันคืนเงิน | - แจ้ง Customer |
# | | | - บันทึก refund transaction |
#
# ---
#
# ### **EXTENSIONS:**
# 1. **Payment Timeout**
#    - 1.1 Gateway ไม่ตอบกลับภายใน timeout period (5 นาที)
#    - 1.2 Retry 3 ครั้ง
#    - 1.3 ถ้าล้มเหลว → mark as failed และแจ้งลูกค้า
#
# 2. **Payment Failed**
#    - 2.1 Gateway ส่ง failed status
#    - 2.2 บันทึก error log
#    - 2.3 แจ้งลูกค้าให้ลองใหม่
#    - 2.4 Suggest alternative payment method
#
# 3. **Duplicate Payment**
#    - 3.1 ตรวจพบการชำระซ้ำ
#    - 3.2 Block duplicate transaction
#    - 3.3 Process refund automatically
#    - 3.4 Notify customer
#
# 4. **Partial Payment**
#    - 4.1 จำนวนเงินไม่ครบ
#    - 4.2 Mark as partial paid
#    - 4.3 Calculate remaining amount
#    - 4.4 Send payment reminder
#
# ---
#
# ### **SPECIAL REQUIREMENT:**
# 1. **Security:**
#    - การเชื่อมต่อต้องใช้ HTTPS/TLS
#    - API Key authentication
#    - Transaction data encryption
#    - PCI DSS compliance (สำหรับบัตรเครดิต)
#
# 2. **Performance:**
#    - Response time < 5 วินาที
#    - 99.9% uptime
#    - Handle concurrent transactions
#
# 3. **Reliability:**
#    - Transaction atomicity (ไม่สำเร็จ = rollback)
#    - Idempotent operations
#    - Auto-retry mechanism
#
# ---
#
# ### **TECHNOLOGY AND DATA VARIATION LIST:**
# 1. **Payment Methods:**
#    - QR Code พร้อมเพย์
#    - โอนเงินธนาคาร
#    - บัตรเครดิต/เดบิต
#
# 2. **Transaction File Format:**
# ```json
# {
#   "transaction_id": "TXN_20251016_001",
#   "booking_id": "BK_12345",
#   "customer_id": "CUST_678",
#   "amount": 1500.00,
#   "payment_method": "qr_code",
#   "status": "success",
#   "timestamp": "2025-10-16T10:30:00Z",
#   "gateway_ref": "GW_REF_001"
# }
# ```
#
# 3. **Status Values:**
#    - Pending, Processing, Success, Failed, Refunded
#
# ---
#
# ### **FREQUENCY OF OCCURRENCE:**
# - Process Payment: 200-300 ครั้ง/วัน
# - Verify Payment: 100-200 ครั้ง/วัน
# - Process Refund: 10-20 ครั้ง/วัน
# - Handle Response: 200-300 ครั้ง/วัน (auto)
#
# ---
#
# ### **OPEN ISSUES:**
# 1. ควรเพิ่ม fraud detection mechanism
# 2. ควรมี multi-gateway support สำหรับ failover
# 3. ควรเพิ่ม installment payment option

# %% [markdown]
# # UCD 008

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 📋 Use Case Description: UCD-008 (Logistic System Integration)
#
# ### **Diagram Information**
# - **Diagram ID:** UCD-008
# - **Use Case Name:** Logistic System Integration
# - **Scope:** Sports Booking System - External Integration
# - **Level:** System Goal
# - **Primary Actor:** Logistic System (Supporting System)
# - **Secondary Actor:** Customer, Booking Staff, System Administrator
#
# ---
#
# ### **STAKEHOLDERS (and their interests)**
# - **Logistic System:** ต้องการข้อมูลการจัดส่งที่ถูกต้อง
# - **Customer:** ต้องการติดตามสถานะการจัดส่งอุปกรณ์
# - **Booking Staff:** ต้องการข้อมูลการจัดส่งเพื่อให้บริการลูกค้า
#
# ---
#
# ### **PRE-CONDITION**
# - ระบบเชื่อมต่อกับ Logistic System สำเร็จ
# - Booking ที่มีการเช่าอุปกรณ์ถูกยืนยันแล้ว
# - Payment ผ่านการยืนยันแล้ว
#
# ---
#
# ### **SUCCESS GUARANTEE (Post-Condition)**
# - Order-ID ถูกส่งไป Logistic System
# - Tracking Number ถูกสร้างและบันทึก
# - Delivery Status อัพเดต real-time
# - Customer และ Staff ได้รับข้อมูลการจัดส่ง
# - Delivery completed successfully
#
# ---
#
# ### **MAIN SUCCESS SCENARIO**
#
# | | ACTOR | SYSTEM |
# |---|-------|--------|
# | **1. Receive Order-ID** | | |
# | | **Booking Staff** | |
# | | - ยืนยัน booking ที่มีการเช่าอุปกรณ์ | - ระบบสร้าง Order-ID |
# | | | - Generate unique identifier |
# | | | - แนบข้อมูลอุปกรณ์และที่อยู่ |
# | | | - ส่ง Order-ID ไป Logistic System |
# | | **Logistic System** | |
# | | - รับ Order-ID พร้อมรายละเอียด | - ระบบบันทึกการส่ง |
# | | - Validate order information | - Create delivery record |
# | **2. Generate Tracking Number** | | |
# | | **Logistic System** | |
# | | - สร้าง Tracking Number | - ระบบรับ Tracking Number |
# | | - ส่ง Tracking Number กลับ | - บันทึกเข้าฐานข้อมูล |
# | | | - Link กับ Booking และ Order-ID |
# | | | - ส่งให้ Customer (SMS/Email) |
# | | | - แสดงบน booking detail page |
# | **3. Update Delivery Status** | | |
# | | **Logistic System** | |
# | | - อัพเดตสถานะการจัดส่ง | - ระบบรับสถานะ (real-time) |
# | | - ส่ง status update | - Parse status information |
# | | (Confirmed → Processing → In-Transit → Delivered) | - อัพเดตฐานข้อมูล |
# | | | - Notify customer (each status change) |
# | | | - Log status history |
# | **4. Send Status Updates** | | |
# | | **Logistic System** | |
# | | - ส่งการแจ้งเตือนอัตโนมัติ | - ระบบรับ notification |
# | | - รวม estimated delivery time | - Forward to Customer |
# | | - รวม current location | - Display on tracking page |
# | | | - Send push notification/email |
# | **5. Track Delivery** | | |
# | | **Customer** | |
# | | - เปิด tracking page | - ระบบแสดงข้อมูล real-time |
# | | - ดู Tracking Number | - Show status timeline |
# | | | - Show current location (if available) |
# | | | - Show estimated delivery time |
# | | **Booking Staff** | |
# | | - ตรวจสอบสถานะเพื่อให้ข้อมูลลูกค้า | - ระบบ query Logistic System |
# | | | - Display detailed tracking info |
# | **6. Schedule Delivery** | | |
# | | **Logistic System** | |
# | | - กำหนด delivery time slot | - ระบบรับข้อมูล schedule |
# | | - ส่งตารางการจัดส่ง | - แสดงให้ Customer เลือก |
# | | **Customer** | |
# | | - เลือก delivery time slot | - ระบบส่งการยืนยันไป Logistic |
# | | **Logistic System** | |
# | | - ยืนยัน time slot | - อัพเดต delivery schedule |
# | | | - ส่ง confirmation ให้ Customer |
# | **7. Notify Delivery Progress** | | |
# | | **Logistic System** | |
# | | - แจ้งเมื่อออกจากคลัง | - ระบบส่ง notification ให้ Customer |
# | | - แจ้งเมื่อใกล้ถึง | - "Your equipment is on the way!" |
# | | - แจ้งเมื่อส่งสำเร็จ | - Request confirmation signature |
# | | | - Complete delivery record |
# | | | - Update booking status to "Delivered" |
#
# ---
#
# ### **EXTENSIONS:**
# 1. **Delivery Delay**
#    - 1.1 Logistic System แจ้งความล่าช้า
#    - 1.2 ระบบแจ้ง Customer พร้อมเหตุผล
#    - 1.3 เสนอ reschedule option
#    - 1.4 Booking Staff follow-up กับลูกค้า
#
# 2. **Failed Delivery**
#    - 2.1 ไม่พบผู้รับ หรือที่อยู่ผิด
#    - 2.2 Logistic System แจ้งสถานะ "Failed"
#    - 2.3 Booking Staff ติดต่อลูกค้า
#    - 2.4 จัดส่งใหม่ หรือให้มารับเอง
#
# 3. **Lost Tracking Number**
#    - 3.1 Logistic System ไม่ส่ง Tracking Number
#    - 3.2 Retry 3 ครั้ง
#    - 3.3 Manual request โดย Booking Staff
#    - 3.4 Log error และแจ้ง System Admin
#
# 4. **Equipment Damaged**
#    - 4.1 Customer รายงานอุปกรณ์เสียหาย
#    - 4.2 ระบบบันทึก complaint
#    - 4.3 แจ้ง Logistic System และ Booking Staff
#    - 4.4 Process refund/compensation
#
# ---
#
# ### **SPECIAL REQUIREMENT:**
# 1. **Real-time Tracking:**
#    - GPS tracking integration (ถ้ามี)
#    - Status update ทุก 30 นาที
#    - Webhook สำหรับ status change
#
# 2. **Integration:**
#    - RESTful API
#    - JSON data format
#    - API authentication (API Key)
#
# 3. **Reliability:**
#    - Auto-retry mechanism
#    - Fallback to manual tracking
#    - Status sync every hour
#
# ---
#
# ### **TECHNOLOGY AND DATA VARIATION LIST:**
# 1. **Order Data Format:**
# ```json
# {
#   "order_id": "ORD_20251016_001",
#   "booking_id": "BK_12345",
#   "customer_name": "John Doe",
#   "delivery_address": "123 Main St, Bangkok",
#   "phone": "081-234-5678",
#   "equipment_list": [
#     {"item": "Football", "quantity": 2},
#     {"item": "Cone", "quantity": 10}
#   ],
#   "delivery_date": "2025-10-20",
#   "special_instructions": "Call before delivery"
# }
# ```
#
# 2. **Tracking Response Format:**
# ```json
# {
#   "tracking_number": "TRK_ABC123456",
#   "order_id": "ORD_20251016_001",
#   "status": "in_transit",
#   "current_location": "Distribution Center, Bangkok",
#   "estimated_delivery": "2025-10-20T14:00:00Z",
#   "status_history": [
#     {"status": "confirmed", "timestamp": "2025-10-18T10:00:00Z"},
#     {"status": "processing", "timestamp": "2025-10-18T14:00:00Z"},
#     {"status": "in_transit", "timestamp": "2025-10-19T08:00:00Z"}
#   ]
# }
# ```
#
# 3. **Delivery Status Values:**
#    - Confirmed → Processing → In-Transit → Out for Delivery → Delivered
#    - Failed, Cancelled, Returned
#
# ---
#
# ### **FREQUENCY OF OCCURRENCE:**
# - Generate Order-ID: 50-100 ครั้ง/วัน
# - Receive Tracking Number: 50-100 ครั้ง/วัน
# - Update Status: 200-400 ครั้ง/วัน (auto)
# - Customer Track Delivery: 100-200 ครั้ง/วัน
# - Schedule Delivery: 30-60 ครั้ง/วัน
#
# ---
#
# ### **OPEN ISSUES:**
# 1. ควรเพิ่ม same-day delivery option
# 2. ควรมี return/pickup integration
# 3. ควรเพิ่ม SMS notification สำหรับทุก status change
# 4. ควรมี multi-logistic provider support

# %% [markdown]
# # UCD 009

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 📋 Use Case Description: UCD-009 (Customer Experience)
#
# ### **Diagram Information**
# - **Diagram ID:** UCD-009
# - **Use Case Name:** Customer Experience
# - **Scope:** Sports Booking System - Customer Operations
# - **Level:** User Goal
# - **Primary Actor:** Customer
# - **Secondary Actor:** Booking Staff, Payment Gateway, Logistic System
#
# ---
#
# ### **STAKEHOLDERS (and their interests)**
# - **Customer:** ต้องการจองสนามและติดตามการใช้บริการได้ง่าย
# - **Booking Staff:** ต้องการให้ลูกค้าใช้งานระบบได้ด้วยตัวเอง
# - **System Owner:** ต้องการเพิ่ม customer satisfaction และ retention
#
# ---
#
# ### **PRE-CONDITION**
# - ระบบพร้อมใช้งาน
# - Customer มี account (สำหรับฟังก์ชันบางอย่าง)
# - มีสนามและอุปกรณ์พร้อมให้บริการ
#
# ---
#
# ### **SUCCESS GUARANTEE (Post-Condition)**
# - Customer สามารถใช้บริการได้สำเร็จ
# - Booking ถูกสร้างและยืนยัน
# - Payment ผ่านการชำระ
# - Customer ได้รับข้อมูลและเอกสารครบถ้วน
# - ประสบการณ์ใช้งานที่ดี
#
# ---
#
# ### **MAIN SUCCESS SCENARIO**
#
# | | ACTOR | SYSTEM |
# |---|-------|--------|
# | **1. Browse Available Fields** | | |
# | | **Customer** | |
# | | - เข้าสู่หน้าแรก | - ระบบแสดงรายการสนาม |
# | | - ดูรายการสนามกีฬา | - แสดงรูปภาพ, รายละเอียด, ราคา |
# | | - เลือกหมวดหมู่ (ฟุตบอล, บาส, etc.) | - Filter ตามหมวดหมู่ |
# | | - ดูรายละเอียดสนาม | - แสดง field details, facilities |
# | | - ตรวจสอบความพร้อม | - แสดง available time slots |
# | **2. Search and Filter** | | |
# | | - ค้นหาสนาม (ชื่อ, สถานที่) | - ระบบค้นหาและแสดงผล |
# | | - กรองตามราคา | - Filter results |
# | | - กรองตามสิ่งอำนวยความสะดวก | - Apply filters |
# | | - เรียงลำดับ (ราคา, ความนิยม) | - Sort results |
# | **3. Make Booking** | | |
# | | - เลือกสนาม | - ระบบแสดง booking form |
# | | - เลือกวันที่และเวลา | - ตรวจสอบความพร้อม |
# | | - เลือกอุปกรณ์เพิ่มเติม (ถ้าต้องการ) | - คำนวณราคารวม |
# | | - กรอกข้อมูลการจอง | - Validate ข้อมูล |
# | | - ยืนยันการจอง | - สร้าง booking record |
# | | | - Generate booking ID |
# | | | - แสดงสรุปการจอง |
# | **4. Make Payment** | | |
# | | - เลือกช่องทางชำระเงิน | - ระบบแสดงตัวเลือก payment |
# | | - ชำระเงิน (QR/Transfer/Card) | - ส่งข้อมูลไป Payment Gateway |
# | | **Payment Gateway** | |
# | | - Process payment | - รับ confirmation |
# | | | - อัพเดตสถานะเป็น "Paid" |
# | | | - ส่ง confirmation email |
# | **5. Receive Confirmation** | | |
# | | - รับ email confirmation | - ระบบส่งอีเมลยืนยัน |
# | | - ดาวน์โหลดใบเสร็จ | - สร้างใบเสร็จ PDF |
# | | - บันทึก booking reference | - แสดง booking details |
# | **6. Track Order (Equipment Delivery)** | | |
# | | - เปิด tracking page | - ระบบแสดง Tracking Number |
# | | - ดู delivery status | - Query Logistic System |
# | | | - แสดง real-time status |
# | | | - แสดง estimated delivery time |
# | | - รับ notification การจัดส่ง | - ส่ง push notification/SMS |
# | **7. View Booking History** | | |
# | | - เปิด booking history page | - ระบบแสดงรายการ booking |
# | | - ดู booking ทั้งหมด | - แสดงทั้ง active และ past |
# | | - เลือก booking เพื่อดูรายละเอียด | - แสดง full details |
# | | - ดาวน์โหลดใบเสร็จย้อนหลัง | - สร้าง receipt PDF |
# | **8. Cancel Booking** | | |
# | | - เลือก booking ที่ต้องการยกเลิก | - ระบบตรวจสอบ cancellation policy |
# | | - ยืนยันการยกเลิก | - Calculate refund amount |
# | | | - Process cancellation |
# | | | - Request refund (ถ้ามี) |
# | | - รับการยืนยันการยกเลิก | - ส่ง cancellation confirmation |
# | **9. View Promotions** | | |
# | | - เปิดหน้า promotions | - ระบบแสดง active promotions |
# | | - ดูโปรโมชั่นประจำวัน/เดือน | - แสดงรายละเอียดและเงื่อนไข |
# | | - Apply promotion code | - Validate code |
# | | | - Apply discount |
# | | | - อัพเดตราคา |
# | **10. Rate and Review** | | |
# | | - เปิดหน้า booking ที่เสร็จสิ้น | - ระบบแสดงฟอร์ม rating |
# | | - ให้คะแนนสนาม (1-5 stars) | - บันทึก rating |
# | | - เขียน review | - บันทึก comment |
# | | - แนบรูปภาพ (optional) | - Upload images |
# | | - Submit review | - Publish review |
# | | | - อัพเดต field average rating |
# | **11. Contact Support** | | |
# | | - เปิดหน้า contact/help | - ระบบแสดงตัวเลือก contact |
# | | - เลือก inquiry type | - แสดงฟอร์มที่เหมาะสม |
# | | - กรอกรายละเอียดคำถาม | - Validate ข้อมูล |
# | | - ส่งคำถาม | - สร้าง support ticket |
# | | | - แจ้ง Booking Staff |
# | | - รับ ticket number | - ส่ง confirmation email |
# | **12. Download Receipt** | | |
# | | - เลือก booking | - ระบบแสดง receipt option |
# | | - คลิก download receipt | - Generate receipt PDF |
# | | | - Include booking details |
# | | | - Include payment information |
# | | - บันทึก receipt | - Download file |
#
# ---
#
# ### **EXTENSIONS:**
# 1. **No Available Time Slot**
#    - 1.1 ช่วงเวลาที่เลือกเต็ม
#    - 1.2 ระบบแนะนำช่วงเวลาอื่น
#    - 1.3 ระบบแสดงสนามอื่นที่มีช่วงเวลาตรงกัน
#    - 1.4 Customer เลือกใหม่
#
# 2. **Payment Failed**
#    - 2.1 การชำระเงินไม่สำเร็จ
#    - 2.2 ระบบแจ้ง error message
#    - 2.3 Suggest ลองชำระใหม่ หรือเปลี่ยน payment method
#    - 2.4 Hold booking for 15 minutes
#
# 3. **Booking Conflict**
#    - 3.1 มีคนจองช่วงเวลาเดียวกันขณะกำลัง checkout
#    - 3.2 ระบบแจ้งว่าช่วงเวลาไม่ available แล้ว
#    - 3.3 Suggest ช่วงเวลาใกล้เคียง
#    - 3.4 Customer เลือกใหม่
#
# 4. **Late Cancellation**
#    - 4.1 Customer ยกเลิกใกล้วันจอง
#    - 4.2 ระบบตรวจสอบ cancellation policy
#    - 4.3 คิดค่าปรับ (ถ้ามี)
#    - 4.4 Process partial refund
#
# 5. **Equipment Not Available**
#    - 5.1 อุปกรณ์ที่เลือกหมด
#    - 5.2 ระบบแจ้งและแนะนำอุปกรณ์อื่น
#    - 5.3 Customer เลือกใหม่ หรือข้ามการเช่าอุปกรณ์
#
# ---
#
# ### **SPECIAL REQUIREMENT:**
# 1. **User Experience:**
#    - Responsive design (mobile, tablet, desktop)
#    - ใช้งานง่าย, intuitive interface
#    - Fast loading time (< 3 seconds)
#
# 2. **Accessibility:**
#    - Support screen reader
#    - Keyboard navigation
#    - Multi-language support (Thai/English)
#
# 3. **Performance:**
#    - Real-time availability check
#    - Instant search results
#    - Concurrent booking handling
#
# 4. **Security:**
#    - Secure payment processing
#    - Personal data protection
#    - HTTPS encryption
#
# ---
#
# ### **TECHNOLOGY AND DATA VARIATION LIST:**
# 1. **Search Filters:**
#    - Field type (ฟุตบอล, บาสเกตบอล, วอลเลย์บอล)
#    - Price range
#    - Location
#    - Facilities (parking, shower, etc.)
#    - Available time
#    - Rating
#
# 2. **Booking Data:**
# ```json
# {
#   "booking_id": "BK_12345",
#   "customer_id": "CUST_678",
#   "field_id": "FIELD_001",
#   "booking_date": "2025-10-20",
#   "time_slot": "14:00-16:00",
#   "duration": 2,
#   "equipment": [
#     {"item": "Football", "quantity": 2, "price": 100}
#   ],
#   "total_price": 1600,
#   "status": "confirmed",
#   "payment_status": "paid"
# }
# ```
#
# 3. **Rating System:**
#    - Stars: 1-5
#    - Categories: Cleanliness, Facilities, Staff, Value for Money
#    - Photo upload: Max 5 images
#
# ---
#
# ### **FREQUENCY OF OCCURRENCE:**
# - Browse Fields: 500-1000 ครั้ง/วัน
# - Make Booking: 200-300 ครั้ง/วัน
# - Make Payment: 200-300 ครั้ง/วัน
# - Track Order: 50-100 ครั้ง/วัน
# - View History: 100-200 ครั้ง/วัน
# - Cancel Booking: 20-40 ครั้ง/วัน
# - View Promotions: 300-500 ครั้ง/วัน
# - Download Receipt: 50-100 ครั้ง/วัน
# - Rate Service: 30-50 ครั้ง/วัน
# - Contact Support: 20-30 ครั้ง/วัน
#
# ---
#
# ### **OPEN ISSUES:**
# 1. ควรเพิ่ม wishlist/favorite fields feature
# 2. ควรมี loyalty program/points system
# 3. ควรเพิ่ม social sharing (แชร์การจองบน social media)
# 4. ควรมี mobile app สำหรับ iOS และ Android
# 5. ควรเพิ่ม live chat support

# %% [markdown]
# # SEQUENCE DIAGRAMS
#
# ---
#
# ## 📊 Sequence Diagram Specifications for All Use Cases

# %% [markdown]
# ## 🔄 Sequence Diagram: UCD-001 (Login System)
#
# ### **Participants**
# ```
# User (Customer/Staff) | System (LoginController, UserDAO, EmailService) | Database (MySQL)
# ```
#
# ---
#
# ### **Scenario 1: Register (Customer Only)**
#
# ```
# User                    System                          Database
#   |                        |                                |
#   |--ผู้ใช้กด Register---->|                                |
#   |                        |                                |
#   |                   แสดงหน้าเว็บ Register                 |
#   |<-----------------------|                                |
#   |                        |                                |
#   |--กรอกข้อมูล + Submit-->|                                |
#   |                        |                                |
#   |                        |--ตรวจสอบอีเมลซ้ำ-------------->|
#   |                        |   SELECT * FROM users          |
#   |                        |   WHERE email = ?              |
#   |                        |                                |
#   |                        |<-------[ไม่พบข้อมูล]-----------|
#   |                        |                                |
#   |                   [ทำการเข้ารหัสรหัสผ่าน]              |
#   |                        |                                |
#   |                        |--บันทึกผู้ใช้ใหม่------------->|
#   |                        |   INSERT INTO users(...)       |
#   |                        |                                |
#   |                        |<-------[userId]----------------|
#   |                        |                                |
#   |                   [ส่งอีเมลยืนยันตัวตน]               |
#   |                        |                                |
#   |<--แสดงข้อความสำเร็จ----|                                |
#   |  "กรุณาตรวจสอบอีเมล"   |                                |
#   |                        |                                |
# ```
#
# **[กรณีอีเมลซ้ำ - alt]**
# ```
#   |                        |<-------[พบข้อมูล]--------------|
#   |                        |                                |
#   |<--แสดง Error-----------|                                |
#   |  "อีเมลนี้ถูกใช้แล้ว"  |                                |
# ```
#
# ---
#
# ### **Scenario 2: Login (All Users)**
#
# ```
# User                    System                          Database
#   |                        |                                |
#   |--ผู้ใช้กด Login------->|                                |
#   |                        |                                |
#   |                   แสดงหน้าเข้าสู่ระบบ                  |
#   |<-----------------------|                                |
#   |                        |                                |
#   |--กรอก Email + Password>|                                |
#   |                        |                                |
#   |                        |--ค้นหาผู้ใช้------------------>|
#   |                        |   SELECT * FROM users          |
#   |                        |   WHERE email = ?              |
#   |                        |                                |
#   |                        |<-------[ข้อมูลผู้ใช้]----------|
#   |                        |  (userId, passwordHash, role)  |
#   |                        |                                |
#   |                   [ตรวจสอบรหัสผ่าน]                    |
#   |                   [BCrypt.compare()]                   |
#   |                        |                                |
#   |                   [ตรวจสอบสถานะบัญชี]                  |
#   |                        |  - is_verified = true?         |
#   |                        |  - is_active = true?           |
#   |                        |                                |
#   |                        |--สร้าง Session---------------->|
#   |                        |   INSERT INTO sessions(...)    |
#   |                        |                                |
#   |                        |<-------[sessionToken]----------|
#   |                        |                                |
#   |                        |--บันทึกเวลา Login------------->|
#   |                        |   UPDATE users                 |
#   |                        |   SET last_login = NOW()       |
#   |                        |                                |
#   |<--Redirect ตาม Role----|                                |
#   |  Customer → dashboard  |                                |
#   |  Admin → admin panel   |                                |
#   |  Staff → manage page   |                                |
#   |                        |                                |
# ```
#
# **[กรณีรหัสผ่านผิด - alt]**
# ```
#   |                   [รหัสผ่านไม่ตรง]                     |
#   |                        |                                |
#   |<--แสดง Error-----------|                                |
#   |  "Email/Password ผิด"  |                                |
#   |                        |                                |
#   |                        |--บันทึก Failed Attempt-------->|
#   |                        |   UPDATE users                 |
#   |                        |   SET failed_login_count++     |
#   |                        |                                |
# ```
#
# **[กรณีบัญชีถูก Lock - opt]**
# ```
#   |                   [failed_attempts > 5]                |
#   |                        |                                |
#   |<--แสดง Error-----------|                                |
#   |  "บัญชีถูกล็อก 15 นาที" |                                |
# ```
#
# ---
#
# ### **Scenario 3: Forgot Password**
#
# ```
# User                    System                          Database
#   |                        |                                |
#   |--กด Forgot Password--->|                                |
#   |                        |                                |
#   |                   แสดงฟอร์มกรอกอีเมล                   |
#   |<-----------------------|                                |
#   |                        |                                |
#   |--กรอก Email + Submit-->|                                |
#   |                        |                                |
#   |                        |--ค้นหาผู้ใช้------------------>|
#   |                        |   SELECT user_id, role         |
#   |                        |   FROM users WHERE email = ?   |
#   |                        |                                |
#   |                        |<-------[ข้อมูลผู้ใช้]----------|
#   |                        |  (userId, role)                |
#   |                        |                                |
#   |                   [ตรวจสอบ Role]                        |
#   |                        |                                |
#   +------------------------+--------------------------------+
#   |                        |                                |
#   | [alt: role = customer] |                                |
#   |                        |                                |
#   |                   [สร้าง Reset Token]                  |
#   |                   [expires in 1 hour]                  |
#   |                        |                                |
#   |                        |--บันทึก Token----------------->|
#   |                        |   INSERT INTO                  |
#   |                        |   password_reset_tokens(...)   |
#   |                        |                                |
#   |                   [ส่งอีเมลพร้อมลิงก์รีเซ็ต]           |
#   |                        |                                |
#   |<--แสดงข้อความ----------|                                |
#   |  "ตรวจสอบอีเมล"        |                                |
#   |                        |                                |
#   | [else: role = staff]   |                                |
#   |                        |                                |
#   |                   [ส่งการแจ้งเตือนไป Admin]            |
#   |                   [ไม่ส่งลิงก์โดยตรง]                  |
#   |                        |                                |
#   |                        |--บันทึกคำขอรีเซ็ต------------->|
#   |                        |   INSERT INTO                  |
#   |                        |   password_reset_requests(...) |
#   |                        |                                |
#   |<--แสดงข้อความ----------|                                |
#   |  "ส่งคำขอไป Admin แล้ว"|                                |
#   +------------------------+--------------------------------+
#   |                        |                                |
# ```
#
# **[Customer: คลิกลิงก์จากอีเมล]**
# ```
# User                    System                          Database
#   |                        |                                |
#   |--คลิกลิงก์รีเซ็ต------->|                                |
#   |                        |                                |
#   |                        |--ตรวจสอบ Token---------------->|
#   |                        |   SELECT * FROM                |
#   |                        |   password_reset_tokens        |
#   |                        |   WHERE token = ?              |
#   |                        |                                |
#   |                        |<-------[token valid]-----------|
#   |                        |  (not expired, not used)       |
#   |                        |                                |
#   |                   แสดงฟอร์มรหัสผ่านใหม่                |
#   |<-----------------------|                                |
#   |                        |                                |
#   |--กรอกรหัสผ่านใหม่----->|                                |
#   |                        |                                |
#   |                   [เข้ารหัสรหัสผ่านใหม่]               |
#   |                        |                                |
#   |                        |--อัพเดทรหัสผ่าน--------------->|
#   |                        |   UPDATE users                 |
#   |                        |   SET password_hash = ?        |
#   |                        |                                |
#   |                        |--ทำ Token ใช้ไม่ได้----------->|
#   |                        |   UPDATE password_reset_tokens |
#   |                        |   SET used = true              |
#   |                        |                                |
#   |<--แสดงข้อความสำเร็จ----|                                |
#   |  "รีเซ็ตรหัสผ่านสำเร็จ" |                                |
#   |                        |                                |
#   |<--Redirect to Login----|                                |
# ```
#
# **[กรณี Token หมดอายุ - alt]**
# ```
#   |                        |<-------[token expired]---------|
#   |                        |                                |
#   |<--แสดง Error-----------|                                |
#   |  "ลิงก์หมดอายุแล้ว"    |                                |
#   |  "กรุณาขอลิงก์ใหม่"    |                                |
# ```
#
# ---
#
# ### **Bug Fixing / Error Handling**
#
# ```
# [กรณี 1: อีเมลซ้ำตอน Register]
# System ----ตรวจสอบอีเมล----> Database
#        <----[พบข้อมูล]------
#        ----แสดง Error-----> User
#            "อีเมลถูกใช้แล้ว"
#
# [กรณี 2: Login ผิดเกิน 5 ครั้ง]
# System ----บันทึก Failed Attempt----> Database
#        ----นับจำนวนครั้ง-------------> Database
#        <----[count > 5]---------------
#        ----Lock Account 15 นาที-----> Database
#        ----แสดง Error----------------> User
#            "บัญชีถูกล็อกชั่วคราว"
#
# [กรณี 3: Token หมดอายุ]
# User ------คลิกลิงก์------------> System
#      <-----แสดง Error------------
#            "ลิงก์หมดอายุ กรุณาขอใหม่"
# ```
#
# ---
#
# ### **PlantUML Code (ถ้าต้องการใช้ PlantUML วาดอัตโนมัติ)**
#
# ```plantuml
# @startuml UCD001_Login_System
#
# actor User
# participant "System\n(LoginController)" as System
# database "Database\n(MySQL)" as DB
#
# == Register (Customer Only) ==
#
# User -> System: ผู้ใช้กด Register
# System --> User: แสดงหน้าเว็บ Register
#
# User -> System: กรอกข้อมูล + Submit
#
# System -> DB: ตรวจสอบอีเมลซ้ำ\nSELECT * FROM users WHERE email = ?
#
# alt อีเมลซ้ำ
#     DB --> System: [พบข้อมูล]
#     System --> User: แสดง Error\n"อีเมลนี้ถูกใช้แล้ว"
# else อีเมลไม่ซ้ำ
#     DB --> System: [ไม่พบข้อมูล]
#
#     System -> System: ทำการเข้ารหัสรหัสผ่าน
#
#     System -> DB: บันทึกผู้ใช้ใหม่\nINSERT INTO users(...)
#     DB --> System: [userId]
#
#     System -> System: ส่งอีเมลยืนยันตัวตน
#
#     System --> User: แสดงข้อความสำเร็จ\n"กรุณาตรวจสอบอีเมล"
# end
#
# == Login (All Users) ==
#
# User -> System: ผู้ใช้กด Login
# System --> User: แสดงหน้าเข้าสู่ระบบ
#
# User -> System: กรอก Email + Password
#
# System -> DB: ค้นหาผู้ใช้\nSELECT * FROM users WHERE email = ?
#
# alt ไม่พบผู้ใช้
#     DB --> System: [ไม่พบข้อมูล]
#     System --> User: แสดง Error\n"Email/Password ผิด"
# else พบผู้ใช้
#     DB --> System: [ข้อมูลผู้ใช้]\n(userId, passwordHash, role)
#
#     System -> System: ตรวจสอบรหัสผ่าน\nBCrypt.compare()
#
#     alt รหัสผ่านผิด
#         System -> DB: บันทึก Failed Attempt\nUPDATE users SET failed_login_count++
#         System --> User: แสดง Error\n"Email/Password ผิด"
#
#         opt ล็อกบัญชี
#             note right: failed_attempts > 5
#             System --> User: "บัญชีถูกล็อก 15 นาที"
#         end
#
#     else รหัสผ่านถูก
#         System -> System: ตรวจสอบสถานะบัญชี\n(is_verified, is_active)
#
#         System -> DB: สร้าง Session\nINSERT INTO sessions(...)
#         DB --> System: [sessionToken]
#
#         System -> DB: บันทึกเวลา Login\nUPDATE users SET last_login = NOW()
#
#         alt Customer
#             System --> User: Redirect → dashboard
#         else Admin
#             System --> User: Redirect → admin panel
#         else Staff
#             System --> User: Redirect → manage page
#         end
#     end
# end
#
# == Forgot Password ==
#
# User -> System: กด Forgot Password
# System --> User: แสดงฟอร์มกรอกอีเมล
#
# User -> System: กรอก Email + Submit
#
# System -> DB: ค้นหาผู้ใช้\nSELECT user_id, role FROM users WHERE email = ?
# DB --> System: [ข้อมูลผู้ใช้]\n(userId, role)
#
# alt role = customer
#     System -> System: สร้าง Reset Token\n(expires in 1 hour)
#     System -> DB: บันทึก Token\nINSERT INTO password_reset_tokens(...)
#     System -> System: ส่งอีเมลพร้อมลิงก์รีเซ็ต
#     System --> User: "ตรวจสอบอีเมล"
#
#     ... ผู้ใช้เปิดอีเมล ...
#
#     User -> System: คลิกลิงก์รีเซ็ต
#     System -> DB: ตรวจสอบ Token\nSELECT * FROM password_reset_tokens WHERE token = ?
#
#     alt Token หมดอายุ
#         DB --> System: [token expired]
#         System --> User: แสดง Error\n"ลิงก์หมดอายุแล้ว\nกรุณาขอลิงก์ใหม่"
#     else Token ใช้งานได้
#         DB --> System: [token valid]
#         System --> User: แสดงฟอร์มรหัสผ่านใหม่
#
#         User -> System: กรอกรหัสผ่านใหม่
#         System -> System: เข้ารหัสรหัสผ่านใหม่
#         System -> DB: อัพเดทรหัสผ่าน\nUPDATE users SET password_hash = ?
#         System -> DB: ทำ Token ใช้ไม่ได้\nUPDATE password_reset_tokens SET used = true
#         System --> User: "รีเซ็ตรหัสผ่านสำเร็จ"
#         System --> User: Redirect to Login
#     end
#
# else role = staff
#     System -> System: ส่งการแจ้งเตือนไป Admin\n(ไม่ส่งลิงก์โดยตรง)
#     System -> DB: บันทึกคำขอรีเซ็ต\nINSERT INTO password_reset_requests(...)
#     System --> User: "ส่งคำขอไป Admin แล้ว"
#
#     note right: Admin ต้อง approve ก่อน\nจึงจะส่งลิงก์ให้ Staff
# end
#
# @enduml
# ```
#
# ---
#
# ### **สรุป Key Points**
# - ✅ แสดง flow แบบเห็นภาพชัดเจน (ลูกศรบอกทิศทาง)
# - ✅ มี alt/opt fragments สำหรับ conditions
# - ✅ แยก path Customer/Staff ชัดเจน
# - ✅ แสดง Error handling ครบถ้วน
# - ✅ มี PlantUML code พร้อมใช้งาน

# %% [markdown]
# ---
#
# ## 🔄 Sequence Diagram: UCD-002 (System Administrator)
#
# ### **Participants**
# ```
# Admin (System Administrator) | System (AdminController, UserDAO, FieldDAO, BackupService) | Database (MySQL)
# ```
#
# ---
#
# ### **Scenario 1: User Management (CRUD)**
#
# ```
# Admin                   System                          Database
#   |                        |                                |
#   |--เข้าหน้า User Mgmt--->|                                |
#   |                        |                                |
#   |                        |--ดึงรายการผู้ใช้-------------->|
#   |                        |   SELECT * FROM users          |
#   |                        |                                |
#   |                        |<-------[รายการผู้ใช้]-----------|
#   |                        |  (id, username, email, role,   |
#   |                        |   status, last_login)          |
#   |                        |                                |
#   |<--แสดงตาราง User-------|                                |
#   |                        |                                |
# ```
#
# **[Create New User]**
# ```
# Admin                   System                          Database
#   |                        |                                |
#   |--กดปุ่ม "Add User"---->|                                |
#   |                        |                                |
#   |<--แสดงฟอร์ม------------|                                |
#   |                        |                                |
#   |--กรอกข้อมูล + Submit-->|                                |
#   |  (username, email,     |                                |
#   |   role, password)      |                                |
#   |                        |                                |
#   |                        |--ตรวจสอบอีเมลซ้ำ-------------->|
#   |                        |   SELECT * FROM users          |
#   |                        |   WHERE email = ?              |
#   |                        |                                |
#   |                        |<-------[ไม่พบข้อมูล]-----------|
#   |                        |                                |
#   |                   [Hash Password]                       |
#   |                        |                                |
#   |                        |--สร้างผู้ใช้ใหม่-------------->|
#   |                        |   INSERT INTO users(...)       |
#   |                        |                                |
#   |                        |<-------[userId]----------------|
#   |                        |                                |
#   |                   [ส่งอีเมลแจ้งข้อมูล Login]           |
#   |                        |                                |
#   |<--แสดงความสำเร็จ-------|                                |
#   |  "เพิ่มผู้ใช้เรียบร้อย"|                                |
#   |                        |                                |
# ```
#
# **[Edit User]**
# ```
# Admin                   System                          Database
#   |                        |                                |
#   |--เลือก User + กด Edit->|                                |
#   |                        |                                |
#   |                        |--ดึงข้อมูล User--------------->|
#   |                        |   SELECT * FROM users          |
#   |                        |   WHERE user_id = ?            |
#   |                        |                                |
#   |                        |<-------[ข้อมูลผู้ใช้]-----------|
#   |                        |                                |
#   |<--แสดงฟอร์มพร้อมข้อมูล-|                                |
#   |                        |                                |
#   |--แก้ไขข้อมูล + Submit->|                                |
#   |                        |                                |
#   |                        |--อัพเดทข้อมูล----------------->|
#   |                        |   UPDATE users SET ...         |
#   |                        |   WHERE user_id = ?            |
#   |                        |                                |
#   |<--แสดงความสำเร็จ-------|                                |
#   |                        |                                |
# ```
#
# **[Delete User]**
# ```
# Admin                   System                          Database
#   |                        |                                |
#   |--เลือก User + กด Delete|                                |
#   |                        |                                |
#   |<--แสดง Confirmation----|                                |
#   |  "ต้องการลบผู้ใช้?"    |                                |
#   |                        |                                |
#   |--ยืนยันการลบ---------->|                                |
#   |                        |                                |
#   |                        |--ตรวจสอบ Booking ที่เกี่ยวข้อง->|
#   |                        |   SELECT COUNT(*) FROM bookings|
#   |                        |   WHERE user_id = ?            |
#   |                        |                                |
#   |                        |<-------[count = 0]-------------|
#   |                        |                                |
#   |                        |--ลบผู้ใช้--------------------->|
#   |                        |   DELETE FROM users            |
#   |                        |   WHERE user_id = ?            |
#   |                        |                                |
#   |<--แสดงความสำเร็จ-------|                                |
#   |                        |                                |
# ```
#
# **[กรณีมี Booking - alt]**
# ```
#   |                        |<-------[count > 0]-------------|
#   |                        |                                |
#   |                        |--Soft Delete ------------------>|
#   |                        |   UPDATE users                 |
#   |                        |   SET is_active = false,       |
#   |                        |   deleted_at = NOW()           |
#   |                        |                                |
#   |<--แสดงข้อความ----------|                                |
#   |  "Deactivate แทนการลบ" |                                |
# ```
#
# **[Assign Role]**
# ```
# Admin                   System                          Database
#   |                        |                                |
#   |--เลือก User + เลือก Role|                               |
#   |  (Customer, Booking,   |                                |
#   |   Accounting, Marketing,|                               |
#   |   Managing Director)   |                                |
#   |                        |                                |
#   |--กด "Assign"---------->|                                |
#   |                        |                                |
#   |                        |--อัพเดท Role------------------>|
#   |                        |   UPDATE users                 |
#   |                        |   SET role = ?,                |
#   |                        |   updated_at = NOW()           |
#   |                        |   WHERE user_id = ?            |
#   |                        |                                |
#   |                        |--Log การเปลี่ยนแปลง----------->|
#   |                        |   INSERT INTO audit_logs(...)  |
#   |                        |                                |
#   |<--แสดงความสำเร็จ-------|                                |
#   |  "เปลี่ยน Role สำเร็จ"  |                                |
#   |                        |                                |
# ```
#
# ---
#
# ### **Scenario 2: Field Management**
#
# ```
# Admin                   System                          Database
#   |                        |                                |
#   |--เข้าหน้า Field Mgmt-->|                                |
#   |                        |                                |
#   |                        |--ดึงรายการสนาม---------------->|
#   |                        |   SELECT * FROM fields         |
#   |                        |                                |
#   |                        |<-------[รายการสนาม]------------|
#   |                        |                                |
#   |<--แสดงตารางสนาม--------|                                |
#   |                        |                                |
# ```
#
# **[Add New Field]**
# ```
# Admin                   System                          Database
#   |                        |                                |
#   |--กดปุ่ม "Add Field"--->|                                |
#   |                        |                                |
#   |<--แสดงฟอร์ม------------|                                |
#   |                        |                                |
#   |--กรอกข้อมูลสนาม------->|                                |
#   |  (name, type, price,   |                                |
#   |   facilities, images)  |                                |
#   |                        |                                |
#   |                        |--บันทึกสนามใหม่--------------->|
#   |                        |   INSERT INTO fields(...)      |
#   |                        |                                |
#   |                        |<-------[fieldId]---------------|
#   |                        |                                |
#   |                        |--สร้าง Time Slots------------->|
#   |                        |   INSERT INTO field_schedules  |
#   |                        |   (field_id, time_slot)        |
#   |                        |                                |
#   |<--แสดงความสำเร็จ-------|                                |
#   |                        |                                |
# ```
#
# **[Edit Field]**
# ```
# Admin                   System                          Database
#   |                        |                                |
#   |--เลือกสนาม + Edit----->|                                |
#   |                        |                                |
#   |                        |--ดึงข้อมูลสนาม---------------->|
#   |                        |   SELECT * FROM fields         |
#   |                        |   WHERE field_id = ?           |
#   |                        |                                |
#   |                        |<-------[ข้อมูลสนาม]------------|
#   |                        |                                |
#   |<--แสดงฟอร์มพร้อมข้อมูล-|                                |
#   |                        |                                |
#   |--แก้ไข + Submit------->|                                |
#   |                        |                                |
#   |                        |--อัพเดทข้อมูล----------------->|
#   |                        |   UPDATE fields SET ...        |
#   |                        |                                |
#   |<--แสดงความสำเร็จ-------|                                |
#   |                        |                                |
# ```
#
# **[Delete Field]**
# ```
# Admin                   System                          Database
#   |                        |                                |
#   |--เลือกสนาม + Delete--->|                                |
#   |                        |                                |
#   |<--Confirmation---------|                                |
#   |                        |                                |
#   |--ยืนยัน--------------->|                                |
#   |                        |                                |
#   |                        |--ตรวจสอบ Booking ในอนาคต------>|
#   |                        |   SELECT COUNT(*) FROM bookings|
#   |                        |   WHERE field_id = ?           |
#   |                        |   AND booking_date >= CURDATE()|
#   |                        |                                |
#   |                        |<-------[count]-----------------|
#   |                        |                                |
# ```
#
# **[alt: มี Booking ในอนาคต]**
# ```
#   |                        |                                |
#   |<--แสดง Error-----------|                                |
#   |  "ไม่สามารถลบได้"      |                                |
#   |  "มี Booking ที่รอดำเนินการ"|                           |
#   |                        |                                |
# ```
#
# **[else: ไม่มี Booking]**
# ```
#   |                        |--ลบสนาม-------------------->|
#   |                        |   DELETE FROM fields         |
#   |                        |   WHERE field_id = ?         |
#   |                        |                              |
#   |<--แสดงความสำเร็จ-------|                              |
# ```
#
# ---
#
# ### **Scenario 3: View All Bookings**
#
# ```
# Admin                   System                          Database
#   |                        |                                |
#   |--เข้าหน้า View Bookings|                               |
#   |                        |                                |
#   |                        |--ดึงรายการ Booking------------>|
#   |                        |   SELECT b.*, f.field_name,    |
#   |                        |   u.username FROM bookings b   |
#   |                        |   JOIN fields f, users u       |
#   |                        |   ORDER BY booking_date DESC   |
#   |                        |                                |
#   |                        |<-------[รายการ Booking]--------|
#   |                        |                                |
#   |<--แสดงตาราง Booking----|                                |
#   |  (แสดงทุก status)      |                                |
#   |                        |                                |
# ```
#
# **[Filter Bookings]**
# ```
# Admin                   System                          Database
#   |                        |                                |
#   |--เลือก Filter--------->|                                |
#   |  (วันที่, status,      |                                |
#   |   field, customer)     |                                |
#   |                        |                                |
#   |                        |--Query ตาม Filter------------->|
#   |                        |   SELECT ... WHERE ...         |
#   |                        |                                |
#   |                        |<-------[ผลลัพธ์]---------------|
#   |                        |                                |
#   |<--แสดงผลกรอง-----------|                                |
#   |                        |                                |
# ```
#
# **[View Booking Details]**
# ```
# Admin                   System                          Database
#   |                        |                                |
#   |--คลิก Booking--------->|                                |
#   |                        |                                |
#   |                        |--ดึงรายละเอียดครบถ้วน--------->|
#   |                        |   SELECT b.*, p.*,             |
#   |                        |   d.tracking_number            |
#   |                        |   FROM bookings b              |
#   |                        |   LEFT JOIN payments p         |
#   |                        |   LEFT JOIN deliveries d       |
#   |                        |                                |
#   |                        |<-------[Full Details]----------|
#   |                        |                                |
#   |<--แสดงรายละเอียด-------|                                |
#   |  (Booking, Payment,    |                                |
#   |   Delivery, Customer)  |                                |
#   |                        |                                |
# ```
#
# ---
#
# ### **Scenario 4: Data Control (Backup & Restore)**
#
# **[Database Backup]**
# ```
# Admin                   System                          Database
#   |                        |                                |
#   |--เข้าหน้า Data Control>|                                |
#   |                        |                                |
#   |<--แสดง Backup Options--|                                |
#   |  - Full Backup         |                                |
#   |  - Incremental Backup  |                                |
#   |                        |                                |
#   |--เลือก Full Backup---->|                                |
#   |                        |                                |
#   |                   [เริ่มกระบวนการ Backup]              |
#   |                        |                                |
#   |                        |--Lock Tables------------------>|
#   |                        |   LOCK TABLES ... READ         |
#   |                        |                                |
#   |                        |--Export Data------------------>|
#   |                        |   mysqldump -u root -p         |
#   |                        |   sports_booking > backup.sql  |
#   |                        |                                |
#   |                        |--Unlock Tables---------------->|
#   |                        |   UNLOCK TABLES                |
#   |                        |                                |
#   |                   [บีบอัดไฟล์]                          |
#   |                   [เก็บไว้ที่ backup folder]            |
#   |                        |                                |
#   |                        |--บันทึก Log------------------->|
#   |                        |   INSERT INTO backup_logs(     |
#   |                        |   backup_type, file_name,      |
#   |                        |   size, created_at)            |
#   |                        |                                |
#   |<--แสดงความสำเร็จ-------|                                |
#   |  "Backup เสร็จสมบูรณ์" |                                |
#   |  "ขนาดไฟล์: 25.3 MB"   |                                |
#   |                        |                                |
# ```
#
# **[View Backup History]**
# ```
# Admin                   System                          Database
#   |                        |                                |
#   |--คลิก "Backup History">|                                |
#   |                        |                                |
#   |                        |--ดึงประวัติ Backup------------>|
#   |                        |   SELECT * FROM backup_logs    |
#   |                        |   ORDER BY created_at DESC     |
#   |                        |                                |
#   |                        |<-------[รายการ Backup]---------|
#   |                        |                                |
#   |<--แสดงตาราง-----------|                                |
#   |  (วันที่, ขนาด,        |                                |
#   |   ประเภท, สถานะ)       |                                |
#   |                        |                                |
# ```
#
# ---
#
# ### **Scenario 5: System Security (Access Control)**
#
# **[View Access Logs]**
# ```
# Admin                   System                          Database
#   |                        |                                |
#   |--เข้าหน้า Security---->|                                |
#   |                        |                                |
#   |                        |--ดึง Access Logs--------------->|
#   |                        |   SELECT * FROM access_logs    |
#   |                        |   ORDER BY timestamp DESC      |
#   |                        |   LIMIT 100                    |
#   |                        |                                |
#   |                        |<-------[Logs]------------------|
#   |                        |                                |
#   |<--แสดงตาราง Log--------|                                |
#   |  (timestamp, user,     |                                |
#   |   action, IP, status)  |                                |
#   |                        |                                |
# ```
#
# **[Reset User Password]**
# ```
# Admin                   System                          Database
#   |                        |                                |
#   |--เลือก User----------->|                                |
#   |--กด "Reset Password"-->|                                |
#   |                        |                                |
#   |<--Confirmation---------|                                |
#   |                        |                                |
#   |--ยืนยัน--------------->|                                |
#   |                        |                                |
#   |                   [สร้างรหัสผ่านชั่วคราว]              |
#   |                   [Hash Password]                       |
#   |                        |                                |
#   |                        |--อัพเดทรหัสผ่าน--------------->|
#   |                        |   UPDATE users                 |
#   |                        |   SET password_hash = ?,       |
#   |                        |   must_change_password = true  |
#   |                        |                                |
#   |                        |--Log Action------------------->|
#   |                        |   INSERT INTO audit_logs(      |
#   |                        |   admin_id, action,            |
#   |                        |   target_user_id)              |
#   |                        |                                |
#   |                   [ส่งอีเมลแจ้งรหัสผ่านใหม่]           |
#   |                        |                                |
#   |<--แสดงรหัสผ่านชั่วคราว--|                                |
#   |  "Temp Password: xxxx" |                                |
#   |                        |                                |
# ```
#
# ---
#
# ### **Alternative Flows**
#
# **[Error: อีเมลซ้ำ (Create User)]**
# ```
# System ----ตรวจสอบ----> Database
#        <----[พบข้อมูล]---
#        ----Error-------> Admin
#            "อีเมลนี้ถูกใช้แล้ว"
# ```
#
# **[Error: ไม่สามารถลบสนามที่มี Booking]**
# ```
# System ----ตรวจสอบ----> Database
#        <----[count > 0]--
#        ----Error-------> Admin
#            "ไม่สามารถลบได้ มี Booking ในอนาคต"
#            "กรุณา Deactivate แทน"
# ```
#
# **[Error: Backup ล้มเหลว]**
# ```
# System ----Export Data----> Database
#        <----[Error]--------
#        ----Rollback------->
#        ----Log Error------>
#        ----แจ้ง Admin----->
#            "Backup ล้มเหลว กรุณาลองใหม่"
# ```
#
# ---
#
# ### **Key Methods**
# ```java
# AdminController: getUserList(), createUser(), updateUser(), deleteUser(), assignRole()
#                  getFieldList(), createField(), updateField(), deleteField()
#                  getAllBookings(), filterBookings(), getBookingDetails()
#                  triggerBackup(), getBackupHistory(), restoreDatabase()
#                  getAccessLogs(), resetUserPassword()
#
# UserDAO: getAllUsers(), getUserById(), createUser(), updateUser(), deleteUser(), updateRole()
# FieldDAO: getAllFields(), getFieldById(), createField(), updateField(), deleteField()
# BackupService: performBackup(), getBackupList(), restoreBackup()
# AuditService: logAction(), getAccessLogs()
# ```
#
# ---
#
# ### **สรุป Key Points**
# - ✅ CRUD operations สำหรับ User และ Field
# - ✅ Soft Delete สำหรับข้อมูลที่มี relationship
# - ✅ Role Assignment พร้อม audit logging
# - ✅ Database Backup/Restore
# - ✅ Access Control และ Security monitoring
# - ✅ Error handling ครบถ้วน

# %% [markdown]
# ---
#
# ## 🔄 Sequence Diagram: UCD-003 (Booking Staff Operations)
#
# ### **Participants**
# ```
# Staff (Booking Staff) | System (BookingController, BookingDAO, PaymentGateway, LogisticSystem) | Database (MySQL)
# ```
#
# ---
#
# ### **Scenario 1: Create New Booking**
#
# ```
# Staff                   System                          Database
#   |                        |                                |
#   |--เข้าหน้า Create Booking|                              |
#   |                        |                                |
#   |                        |--ดึงรายการสนามที่ว่าง--------->|
#   |                        |   SELECT f.* FROM fields f     |
#   |                        |   WHERE NOT EXISTS (           |
#   |                        |   SELECT 1 FROM bookings       |
#   |                        |   WHERE date = ? AND time = ?)  |
#   |                        |                                |
#   |                        |<-------[รายการสนามว่าง]--------|
#   |                        |                                |
#   |<--แสดงรายการสนาม-------|                                |
#   |                        |                                |
#   |--เลือกสนาม + วันที่---->|                                |
#   |--เลือก Time Slot------->|                                |
#   |--เลือกอุปกรณ์ (ถ้ามี)-->|                                |
#   |                        |                                |
#   |                   [คำนวณราคารวม]                        |
#   |                        |                                |
#   |<--แสดงสรุปการจอง-------|                                |
#   |  (สนาม, วันที่, เวลา,  |                                |
#   |   อุปกรณ์, ราคารวม)    |                                |
#   |                        |                                |
#   |--กรอกข้อมูลลูกค้า----->|                                |
#   |  (ชื่อ, เบอร์, อีเมล)  |                                |
#   |                        |                                |
#   |--กด "Create Booking"-->|                                |
#   |                        |                                |
#   |                        |--สร้าง Booking---------------->|
#   |                        |   INSERT INTO bookings(        |
#   |                        |   customer_name, field_id,     |
#   |                        |   booking_date, time_slot,     |
#   |                        |   total_price, status,         |
#   |                        |   created_by)                  |
#   |                        |                                |
#   |                        |<-------[bookingId]-------------|
#   |                        |                                |
#   |                        |--บันทึกอุปกรณ์ (ถ้ามี)-------->|
#   |                        |   INSERT INTO booking_equipment|
#   |                        |                                |
#   |<--แสดง Booking ID------|                                |
#   |  "BK_12345"            |                                |
#   |                        |                                |
#   |                   [ส่งการแจ้งเตือนให้ลูกค้า]           |
#   |                        |                                |
# ```
#
# ---
#
# ### **Scenario 2: Edit Booking**
#
# ```
# Staff                   System                          Database
#   |                        |                                |
#   |--ค้นหา Booking-------->|                                |
#   |  (Booking ID / ชื่อ)   |                                |
#   |                        |                                |
#   |                        |--ค้นหา Booking---------------->|
#   |                        |   SELECT * FROM bookings       |
#   |                        |   WHERE booking_id = ?         |
#   |                        |   OR customer_name LIKE ?      |
#   |                        |                                |
#   |                        |<-------[ข้อมูล Booking]--------|
#   |                        |                                |
#   |<--แสดงรายละเอียด-------|                                |
#   |                        |                                |
#   |--กด "Edit"------------>|                                |
#   |                        |                                |
#   |<--แสดงฟอร์มแก้ไข-------|                                |
#   |                        |                                |
#   |--แก้ไขข้อมูล---------->|                                |
#   |  (วันที่, เวลา,        |                                |
#   |   อุปกรณ์)             |                                |
#   |                        |                                |
#   |                        |--ตรวจสอบความว่างใหม่---------->|
#   |                        |   SELECT ... WHERE date = ?    |
#   |                        |                                |
#   |                        |<-------[available]-------------|
#   |                        |                                |
#   |                   [คำนวณราคาใหม่]                       |
#   |                        |                                |
#   |--ยืนยันการแก้ไข------->|                                |
#   |                        |                                |
#   |                        |--อัพเดท Booking--------------->|
#   |                        |   UPDATE bookings SET ...      |
#   |                        |   WHERE booking_id = ?         |
#   |                        |                                |
#   |                        |--บันทึก Log การแก้ไข---------->|
#   |                        |   INSERT INTO booking_logs     |
#   |                        |                                |
#   |<--แสดงความสำเร็จ-------|                                |
#   |                        |                                |
#   |                   [แจ้งเตือนลูกค้าเกี่ยวกับการเปลี่ยนแปลง]|
#   |                        |                                |
# ```
#
# ---
#
# ### **Scenario 3: Approve/Reject Booking**
#
# ```
# Staff                   System                          Database
#   |                        |                                |
#   |--ดู Pending Bookings-->|                                |
#   |                        |                                |
#   |                        |--ดึง Bookings ที่รอตรวจสอบ---->|
#   |                        |   SELECT * FROM bookings       |
#   |                        |   WHERE status = 'pending'     |
#   |                        |   ORDER BY created_at          |
#   |                        |                                |
#   |                        |<-------[รายการ Pending]--------|
#   |                        |                                |
#   |<--แสดงรายการ-----------|                                |
#   |                        |                                |
#   |--เลือก Booking-------->|                                |
#   |                        |                                |
#   |<--แสดงรายละเอียดครบ----|                                |
#   |  (ข้อมูลลูกค้า, สนาม,  |                                |
#   |   การชำระเงิน)         |                                |
#   |                        |                                |
# ```
#
# **[Approve Booking]**
# ```
# Staff                   System                          Database
#   |                        |                                |
#   |--กด "Approve"--------->|                                |
#   |                        |                                |
#   |                        |--ตรวจสอบการชำระเงิน----------->|
#   |                        |   SELECT * FROM payments       |
#   |                        |   WHERE booking_id = ?         |
#   |                        |                                |
#   |                        |<-------[payment verified]------|
#   |                        |                                |
#   |                        |--อัพเดทสถานะ------------------>|
#   |                        |   UPDATE bookings              |
#   |                        |   SET status = 'confirmed',    |
#   |                        |   approved_by = ?,             |
#   |                        |   approved_at = NOW()          |
#   |                        |                                |
#   |<--แสดงความสำเร็จ-------|                                |
#   |  "อนุมัติ Booking แล้ว"|                                |
#   |                        |                                |
#   |                   [ส่งการยืนยันให้ลูกค้า]              |
#   |                        |                                |
# ```
#
# **[Reject Booking]**
# ```
# Staff                   System                          Database
#   |                        |                                |
#   |--กด "Reject"---------->|                                |
#   |                        |                                |
#   |<--แสดงฟอร์มเหตุผล------|                                |
#   |                        |                                |
#   |--กรอกเหตุผล + Submit-->|                                |
#   |                        |                                |
#   |                        |--อัพเดทสถานะ------------------>|
#   |                        |   UPDATE bookings              |
#   |                        |   SET status = 'rejected',     |
#   |                        |   reject_reason = ?,           |
#   |                        |   rejected_by = ?              |
#   |                        |                                |
#   |                        |--คืนเงิน (ถ้ามีการชำระแล้ว)---->|
#   |                        |   Process Refund               |
#   |                        |                                |
#   |<--แสดงความสำเร็จ-------|                                |
#   |                        |                                |
#   |                   [แจ้งลูกค้าพร้อมเหตุผล]             |
#   |                        |                                |
# ```
#
# ---
#
# ### **Scenario 4: Process Payment**
#
# ```
# Staff                   System                          Database
#   |                        |                                |
#   |--เลือก Booking-------->|                                |
#   |--กด "Process Payment"->|                                |
#   |                        |                                |
#   |<--แสดงยอดที่ต้องชำระ----|                                |
#   |                        |                                |
#   |--เลือกวิธีชำระเงิน---->|                                |
#   |  (เงินสด/โอน/บัตร)     |                                |
#   |                        |                                |
#   |--กรอกข้อมูลการชำระ---->|                                |
#   |                        |                                |
#   |                        |--ส่งข้อมูลไป Payment Gateway-->|
#   |                        |                                |
#   |                   [รอการตอบกลับ]                        |
#   |                        |                                |
#   |                        |<--Payment Confirmed------------|
#   |                   (Payment Gateway)                     |
#   |                        |                                |
#   |                        |--บันทึกการชำระเงิน------------>|
#   |                        |   INSERT INTO payments(        |
#   |                        |   booking_id, amount,          |
#   |                        |   payment_method, status,      |
#   |                        |   transaction_id)              |
#   |                        |                                |
#   |                        |--อัพเดทสถานะ Booking---------->|
#   |                        |   UPDATE bookings              |
#   |                        |   SET payment_status = 'paid'  |
#   |                        |                                |
#   |                        |--สร้างใบเสร็จ------------------>|
#   |                        |   Generate Receipt PDF         |
#   |                        |                                |
#   |<--แสดงใบเสร็จ----------|                                |
#   |  พร้อมปุ่ม Print       |                                |
#   |                        |                                |
# ```
#
# ---
#
# ### **Scenario 5: Track Delivery**
#
# ```
# Staff                   System                          Database
#   |                        |                                |
#   |--ค้นหา Booking ที่มีอุปกรณ์|                            |
#   |                        |                                |
#   |                        |--ดึงรายการ--------------------->|
#   |                        |   SELECT b.*, d.*              |
#   |                        |   FROM bookings b              |
#   |                        |   LEFT JOIN deliveries d       |
#   |                        |   WHERE has_equipment = true   |
#   |                        |                                |
#   |                        |<-------[รายการ]----------------|
#   |                        |                                |
#   |<--แสดงรายการ-----------|                                |
#   |  พร้อม Tracking Number |                                |
#   |                        |                                |
#   |--คลิก Booking--------->|                                |
#   |                        |                                |
#   |                        |--Query Logistic System-------->|
#   |                        |   GET /tracking/{trackingNo}   |
#   |                   (External API)                        |
#   |                        |                                |
#   |                        |<--Delivery Status--------------|
#   |                        |  (Confirmed/Processing/        |
#   |                        |   In-Transit/Delivered)        |
#   |                        |                                |
#   |<--แสดงสถานะปัจจุบัน----|                                |
#   |  + Timeline            |                                |
#   |  + Location (ถ้ามี)    |                                |
#   |                        |                                |
# ```
#
# **[Update Delivery Status Manually]**
# ```
# Staff                   System                          Database
#   |                        |                                |
#   |--กด "Update Status"---->|                               |
#   |                        |                                |
#   |<--แสดงตัวเลือกสถานะ----|                                |
#   |                        |                                |
#   |--เลือกสถานะใหม่------->|                                |
#   |--กรอกหมายเหตุ--------->|                                |
#   |                        |                                |
#   |                        |--บันทึกการอัพเดท-------------->|
#   |                        |   UPDATE deliveries            |
#   |                        |   SET status = ?,              |
#   |                        |   note = ?,                    |
#   |                        |   updated_at = NOW()           |
#   |                        |                                |
#   |                        |--แจ้งลูกค้า-------------------->|
#   |                        |   Send SMS/Email notification  |
#   |                        |                                |
#   |<--แสดงความสำเร็จ-------|                                |
#   |                        |                                |
# ```
#
# ---
#
# ### **Scenario 6: Customer Support (Answer Inquiry)**
#
# ```
# Staff                   System                          Database
#   |                        |                                |
#   |--เข้าหน้า Support----->|                                |
#   |                        |                                |
#   |                        |--ดึงคำถามที่รอตอบ------------->|
#   |                        |   SELECT * FROM inquiries      |
#   |                        |   WHERE status = 'pending'     |
#   |                        |   ORDER BY created_at          |
#   |                        |                                |
#   |                        |<-------[รายการคำถาม]-----------|
#   |                        |                                |
#   |<--แสดงรายการ-----------|                                |
#   |                        |                                |
#   |--เลือกคำถาม----------->|                                |
#   |                        |                                |
#   |                        |--ดึงรายละเอียดครบถ้วน--------->|
#   |                        |   SELECT i.*, u.*, b.*         |
#   |                        |   FROM inquiries i             |
#   |                        |   LEFT JOIN users u            |
#   |                        |   LEFT JOIN bookings b         |
#   |                        |                                |
#   |                        |<-------[ข้อมูลครบถ้วน]---------|
#   |                        |                                |
#   |<--แสดงรายละเอียด-------|                                |
#   |  (คำถาม, ลูกค้า,       |                                |
#   |   Booking ที่เกี่ยวข้อง)|                                |
#   |                        |                                |
#   |--พิมพ์คำตอบ----------->|                                |
#   |--กด "Send"------------>|                                |
#   |                        |                                |
#   |                        |--บันทึกคำตอบ------------------>|
#   |                        |   INSERT INTO inquiry_replies  |
#   |                        |   (inquiry_id, staff_id,       |
#   |                        |    message, created_at)        |
#   |                        |                                |
#   |                        |--อัพเดทสถานะ------------------>|
#   |                        |   UPDATE inquiries             |
#   |                        |   SET status = 'answered'      |
#   |                        |                                |
#   |                        |--ส่งการแจ้งเตือนให้ลูกค้า------>|
#   |                        |   Send Email notification      |
#   |                        |                                |
#   |<--แสดงความสำเร็จ-------|                                |
#   |                        |                                |
# ```
#
# ---
#
# ### **Alternative Flows**
#
# **[Error: สนามไม่ว่าง (Create Booking)]**
# ```
# System ----ตรวจสอบ----> Database
#        <----[มี Booking แล้ว]---
#        ----Error-------> Staff
#            "สนามไม่ว่างในช่วงเวลานี้"
#            "กรุณาเลือกเวลาอื่น"
# ```
#
# **[Error: Payment Failed]**
# ```
# System ----Process----> Payment Gateway
#        <----[Failed]----
#        ----บันทึก Failed Status--> Database
#        ----Error-------> Staff
#            "การชำระเงินล้มเหลว"
#            "กรุณาลองใหม่หรือเปลี่ยนวิธีชำระ"
# ```
#
# **[Warning: Delivery Delayed]**
# ```
# Logistic System ----Status Update----> System
#                      [Delayed]
#                          |
#                     แจ้ง Staff
#                          |
#                     แจ้งลูกค้า
#                 "การจัดส่งล่าช้า กำลังดำเนินการ"
# ```
#
# ---
#
# ### **สรุป Key Points**
# - ✅ Create/Edit/Delete Booking operations
# - ✅ Approve/Reject workflow พร้อม payment verification
# - ✅ Payment processing ผ่าน Payment Gateway
# - ✅ Delivery tracking integration กับ Logistic System
# - ✅ Customer support และ inquiry management
# - ✅ Real-time notifications ให้ลูกค้า

# %% [markdown]
# ---
#
# ## 🔄 Sequence Diagram: UCD-004 (Accounting Staff)
#
# ### **Participants**
# ```
# Accountant (Accounting Staff) | System (AccountingController, PaymentDAO, ReportService) | Database (MySQL)
# ```
#
# ---
#
# ### **Scenario 1: Manage Payment Records**
#
# ```
# Accountant              System                          Database
#   |                        |                                |
#   |--เข้าหน้า Payment Mgmt>|                                |
#   |                        |                                |
#   |                        |--ดึงรายการ Payments----------->|
#   |                        |   SELECT p.*, b.booking_id,    |
#   |                        |   u.customer_name              |
#   |                        |   FROM payments p              |
#   |                        |   JOIN bookings b              |
#   |                        |   JOIN users u                 |
#   |                        |   ORDER BY payment_date DESC   |
#   |                        |                                |
#   |                        |<-------[รายการ Payments]-------|
#   |                        |                                |
#   |<--แสดงตาราง-----------|                                |
#   |  (วันที่, จำนวน,       |                                |
#   |   วิธีชำระ, สถานะ)     |                                |
#   |                        |                                |
# ```
#
# **[Verify Payment Status]**
# ```
# Accountant              System                          Database
#   |                        |                                |
#   |--เลือก Payment-------->|                                |
#   |--กด "Verify"---------->|                                |
#   |                        |                                |
#   |                        |--ดึงข้อมูลครบถ้วน------------->|
#   |                        |   SELECT p.*, pg.*             |
#   |                        |   FROM payments p              |
#   |                        |   LEFT JOIN payment_gateway_logs pg|
#   |                        |                                |
#   |                        |<-------[ข้อมูล Payment]--------|
#   |                        |                                |
#   |                        |--Query Payment Gateway-------->|
#   |                        |   GET /verify/{transactionId}  |
#   |                   (External API)                        |
#   |                        |                                |
#   |                        |<--Verification Result----------|
#   |                        |  (Status, Amount, Date)        |
#   |                        |                                |
#   |<--แสดงผลการตรวจสอบ----|                                |
#   |  ✅ Verified           |                                |
#   |  หรือ ❌ Mismatch      |                                |
#   |                        |                                |
# ```
#
# **[Process Refund]**
# ```
# Accountant              System                          Database
#   |                        |                                |
#   |--เลือก Payment-------->|                                |
#   |--กด "Refund"---------->|                                |
#   |                        |                                |
#   |<--แสดงฟอร์ม Refund-----|                                |
#   |                        |                                |
#   |--กรอกจำนวนเงิน-------->|                                |
#   |--กรอกเหตุผล----------->|                                |
#   |--ยืนยัน--------------->|                                |
#   |                        |                                |
#   |                        |--ส่งคำขอ Refund--------------->|
#   |                        |   POST /refund                 |
#   |                   (Payment Gateway)                     |
#   |                        |                                |
#   |                        |<--Refund Confirmed-------------|
#   |                        |                                |
#   |                        |--บันทึก Refund---------------->|
#   |                        |   INSERT INTO refunds(         |
#   |                        |   payment_id, amount,          |
#   |                        |   reason, status,              |
#   |                        |   processed_by)                |
#   |                        |                                |
#   |                        |--อัพเดทสถานะ Payment---------->|
#   |                        |   UPDATE payments              |
#   |                        |   SET status = 'refunded'      |
#   |                        |                                |
#   |<--แสดงความสำเร็จ-------|                                |
#   |  "คืนเงินเรียบร้อย"    |                                |
#   |                        |                                |
#   |                   [แจ้งลูกค้า]                         |
#   |                        |                                |
# ```
#
# ---
#
# ### **Scenario 2: Generate Invoice**
#
# ```
# Accountant              System                          Database
#   |                        |                                |
#   |--เลือก Booking-------->|                                |
#   |--กด "Generate Invoice">|                                |
#   |                        |                                |
#   |                        |--ดึงข้อมูลครบถ้วน------------->|
#   |                        |   SELECT b.*, p.*, u.*,        |
#   |                        |   f.field_name, e.*            |
#   |                        |   FROM bookings b              |
#   |                        |   JOIN payments p              |
#   |                        |   JOIN users u                 |
#   |                        |   JOIN fields f                |
#   |                        |   LEFT JOIN booking_equipment e|
#   |                        |                                |
#   |                        |<-------[ข้อมูลครบถ้วน]---------|
#   |                        |                                |
#   |                   [สร้างใบแจ้งหนี้]                     |
#   |                   [รวมรายละเอียด:]                      |
#   |                   - ข้อมูลบริษัท                        |
#   |                   - ข้อมูลลูกค้า                        |
#   |                   - รายการสนาม + อุปกรณ์                |
#   |                   - ภาษี (VAT 7%)                       |
#   |                   - ยอดรวม                              |
#   |                        |                                |
#   |                        |--บันทึก Invoice--------------->|
#   |                        |   INSERT INTO invoices(        |
#   |                        |   booking_id, invoice_no,      |
#   |                        |   total_amount, tax_amount,    |
#   |                        |   generated_by, generated_at)  |
#   |                        |                                |
#   |                        |<-------[invoiceId]-------------|
#   |                        |                                |
#   |                   [สร้าง PDF]                           |
#   |                        |                                |
#   |<--แสดง Invoice PDF-----|                                |
#   |  พร้อมปุ่ม Download/Print|                             |
#   |                        |                                |
#   |--กด "Send to Customer">|                                |
#   |                        |                                |
#   |                   [ส่ง Invoice ทางอีเมล]               |
#   |                        |                                |
#   |<--แสดงความสำเร็จ-------|                                |
#   |                        |                                |
# ```
#
# ---
#
# ### **Scenario 3: Reconcile Transactions**
#
# ```
# Accountant              System                          Database
#   |                        |                                |
#   |--เข้าหน้า Reconcile--->|                                |
#   |                        |                                |
#   |<--แสดงตัวเลือก---------|                                |
#   |  - เลือกวันที่         |                                |
#   |  - เลือก Payment Method|                                |
#   |                        |                                |
#   |--เลือกเงื่อนไข-------->|                                |
#   |                        |                                |
#   |                        |--ดึงข้อมูลจากระบบ------------->|
#   |                        |   SELECT * FROM payments       |
#   |                        |   WHERE DATE(payment_date)     |
#   |                        |   BETWEEN ? AND ?              |
#   |                        |                                |
#   |                        |<-------[รายการจากระบบ]---------|
#   |                        |                                |
#   |                        |--ดึงข้อมูลจาก Payment Gateway->|
#   |                        |   GET /transactions?date=...   |
#   |                   (External API)                        |
#   |                        |                                |
#   |                        |<--รายการจาก Gateway-----------|
#   |                        |                                |
#   |                   [เปรียบเทียบรายการ]                   |
#   |                   [หารายการที่ไม่ตรงกัน]                |
#   |                        |                                |
#   |<--แสดงผลการ Reconcile--|                                |
#   |  ✅ Matched: 150 รายการ|                                |
#   |  ❌ Unmatched: 3 รายการ|                                |
#   |  💰 Total: 45,000 บาท  |                                |
#   |                        |                                |
# ```
#
# **[ตรวจสอบรายการที่ไม่ตรง]**
# ```
# Accountant              System                          Database
#   |                        |                                |
#   |--คลิก "View Unmatched">|                                |
#   |                        |                                |
#   |<--แสดงรายการที่ไม่ตรง---|                                |
#   |  (System มี / Gateway ไม่มี)|                           |
#   |  (Gateway มี / System ไม่มี)|                           |
#   |  (จำนวนเงินไม่ตรง)     |                                |
#   |                        |                                |
#   |--เลือกรายการ---------->|                                |
#   |--ตรวจสอบและแก้ไข------>|                                |
#   |                        |                                |
#   |                        |--บันทึก Reconciliation-------->|
#   |                        |   INSERT INTO                  |
#   |                        |   reconciliation_logs(         |
#   |                        |   date, matched_count,         |
#   |                        |   unmatched_count,             |
#   |                        |   total_amount, status,        |
#   |                        |   reconciled_by)               |
#   |                        |                                |
#   |<--แสดงความสำเร็จ-------|                                |
#   |                        |                                |
# ```
#
# ---
#
# ### **Scenario 4: View Revenue Analytics**
#
# ```
# Accountant              System                          Database
#   |                        |                                |
#   |--เข้าหน้า Analytics--->|                                |
#   |                        |                                |
#   |<--แสดง Dashboard-------|                                |
#   |  - รายได้วันนี้        |                                |
#   |  - รายได้เดือนนี้      |                                |
#   |  - เปรียบเทียบเดือนก่อน|                                |
#   |  - กราฟแสดงแนวโน้ม     |                                |
#   |                        |                                |
# ```
#
# **[Daily Revenue]**
# ```
# Accountant              System                          Database
#   |                        |                                |
#   |--คลิก "Daily Revenue"->|                                |
#   |                        |                                |
#   |                        |--คำนวณรายได้ประจำวัน---------->|
#   |                        |   SELECT DATE(payment_date),   |
#   |                        |   SUM(amount) as daily_revenue,|
#   |                        |   COUNT(*) as transaction_count|
#   |                        |   FROM payments                |
#   |                        |   WHERE status = 'completed'   |
#   |                        |   AND payment_date >= DATE_SUB(|
#   |                        |   CURDATE(), INTERVAL 30 DAY)  |
#   |                        |   GROUP BY DATE(payment_date)  |
#   |                        |                                |
#   |                        |<-------[ข้อมูลรายได้]-----------|
#   |                        |                                |
#   |<--แสดงกราฟและตาราง-----|                                |
#   |  Bar Chart 30 วัน      |                                |
#   |                        |                                |
# ```
#
# **[Monthly Revenue]**
# ```
# Accountant              System                          Database
#   |                        |                                |
#   |--คลิก "Monthly Revenue"|                               |
#   |                        |                                |
#   |                        |--คำนวณรายได้รายเดือน---------->|
#   |                        |   SELECT                       |
#   |                        |   DATE_FORMAT(payment_date,    |
#   |                        |   '%Y-%m') as month,           |
#   |                        |   SUM(amount) as revenue,      |
#   |                        |   COUNT(*) as transactions,    |
#   |                        |   AVG(amount) as avg_transaction|
#   |                        |   FROM payments                |
#   |                        |   WHERE status = 'completed'   |
#   |                        |   GROUP BY month               |
#   |                        |   ORDER BY month DESC          |
#   |                        |                                |
#   |                        |<-------[ข้อมูล 12 เดือน]-------|
#   |                        |                                |
#   |<--แสดงกราฟเปรียบเทียบ---|                                |
#   |  Line Chart + Table    |                                |
#   |                        |                                |
# ```
#
# **[Yearly Revenue]**
# ```
# Accountant              System                          Database
#   |                        |                                |
#   |--คลิก "Yearly Revenue">|                                |
#   |                        |                                |
#   |                        |--คำนวณรายได้รายปี------------->|
#   |                        |   SELECT YEAR(payment_date),   |
#   |                        |   SUM(amount) as yearly_revenue,|
#   |                        |   FROM payments                |
#   |                        |   GROUP BY YEAR(payment_date)  |
#   |                        |                                |
#   |                        |<-------[ข้อมูลรายปี]-----------|
#   |                        |                                |
#   |<--แสดงสรุปรายปี--------|                                |
#   |  + เปรียบเทียบ Growth Rate|                            |
#   |                        |                                |
# ```
#
# ---
#
# ### **Scenario 5: Generate Financial Reports**
#
# ```
# Accountant              System                          Database
#   |                        |                                |
#   |--เข้าหน้า Reports----->|                                |
#   |                        |                                |
#   |<--แสดงประเภท Reports---|                                |
#   |  - Income Statement    |                                |
#   |  - Payment Summary     |                                |
#   |  - Refund Report       |                                |
#   |  - Tax Report          |                                |
#   |                        |                                |
#   |--เลือก "Income Statement"|                             |
#   |--เลือกช่วงเวลา-------->|                                |
#   |  (เริ่ม - สิ้นสุด)     |                                |
#   |                        |                                |
#   |--กด "Generate"-------->|                                |
#   |                        |                                |
#   |                        |--ดึงข้อมูล Revenue------------>|
#   |                        |   SELECT ... FROM payments     |
#   |                        |                                |
#   |                        |--ดึงข้อมูล Expenses----------->|
#   |                        |   SELECT ... FROM expenses     |
#   |                        |                                |
#   |                        |--คำนวณ Net Income------------->|
#   |                        |   Revenue - Expenses           |
#   |                        |                                |
#   |                   [สร้างรายงาน]                         |
#   |                   - รายได้ตาม Category                  |
#   |                   - ค่าใช้จ่าย                          |
#   |                   - กำไรสุทธิ                           |
#   |                   - Profit Margin                       |
#   |                        |                                |
#   |<--แสดงรายงาน-----------|                                |
#   |  พร้อมกราฟและตาราง     |                                |
#   |                        |                                |
# ```
#
# **[Export Report]**
# ```
# Accountant              System                          Database
#   |                        |                                |
#   |--เลือกรูปแบบ Export--->|                                |
#   |  (PDF / Excel / CSV)   |                                |
#   |                        |                                |
#   |--กด "Export"---------->|                                |
#   |                        |                                |
#   |                   [สร้างไฟล์ตามรูปแบบที่เลือก]         |
#   |                        |                                |
#   |                        |--บันทึก Log การ Export-------->|
#   |                        |   INSERT INTO export_logs      |
#   |                        |                                |
#   |<--ดาวน์โหลดไฟล์--------|                                |
#   |                        |                                |
# ```
#
# ---
#
# ### **Alternative Flows**
#
# **[Error: Payment Verification Failed]**
# ```
# System ----Verify----> Payment Gateway
#        <----[Error/Mismatch]---
#        ----Flag as Suspicious--> Database
#        ----Alert--------> Accountant
#            "การชำระเงินมีปัญหา ต้องตรวจสอบ"
# ```
#
# **[Error: Refund Failed]**
# ```
# System ----Process Refund----> Payment Gateway
#        <----[Failed]------------
#        ----บันทึก Failed Status--> Database
#        ----Error--------> Accountant
#            "ไม่สามารถคืนเงินได้ กรุณาติดต่อ Payment Gateway"
# ```
#
# **[Warning: Reconciliation Mismatch]**
# ```
# System ----Compare----> รายการระบบ vs Gateway
#        ----พบความไม่ตรง--->
#        ----Highlight Differences--->
#        ----แจ้ง Accountant--->
#            "พบรายการที่ไม่ตรง 3 รายการ"
# ```
#
# ---
#
# ### **สรุป Key Points**
# - ✅ Payment verification กับ Payment Gateway
# - ✅ Process refund พร้อม audit trail
# - ✅ Invoice generation (PDF/Email)
# - ✅ Transaction reconciliation (auto-matching)
# - ✅ Revenue analytics (Daily/Monthly/Yearly)
# - ✅ Financial reporting พร้อม export (PDF/Excel/CSV)

# %% [markdown]
# ---
#
# ## 🔄 Sequence Diagram: UCD-005 (Managing Director)
#
# ### **Participants**
# ```
# Director (Managing Director) | System (DirectorController, DashboardService, ReportService) | Database (MySQL)
# ```
#
# ---
#
# ### **Scenario 1: Executive Dashboard**
#
# ```
# Director                System                          Database
#   |                        |                                |
#   |--เข้าสู่ระบบ---------->|                                |
#   |                        |                                |
#   |                   [Auto-redirect to Dashboard]          |
#   |                        |                                |
#   |                        |--ดึงข้อมูล KPIs--------------->|
#   |                        |   SELECT                       |
#   |                        |   - Today's Revenue            |
#   |                        |   - This Month Revenue         |
#   |                        |   - Active Bookings            |
#   |                        |   - Total Customers            |
#   |                        |   - Field Utilization Rate     |
#   |                        |   FROM multiple tables         |
#   |                        |                                |
#   |                        |<-------[KPI Data]--------------|
#   |                        |                                |
#   |<--แสดง Executive Dashboard|                             |
#   |  📊 Revenue Overview   |                                |
#   |  📈 Growth Trend       |                                |
#   |  👥 Customer Stats     |                                |
#   |  🏟️ Field Performance  |                                |
#   |  ⚠️ Alerts/Issues      |                                |
#   |                        |                                |
# ```
#
# ---
#
# ### **Scenario 2: View Revenue Reports**
#
# ```
# Director                System                          Database
#   |                        |                                |
#   |--คลิก "Revenue Reports"|                               |
#   |                        |                                |
#   |<--แสดงตัวเลือก---------|                                |
#   |  - Daily Revenue       |                                |
#   |  - Monthly Revenue     |                                |
#   |  - Yearly Revenue      |                                |
#   |  - Revenue by Field    |                                |
#   |  - Revenue by Service  |                                |
#   |                        |                                |
#   |--เลือก "Monthly Revenue"|                              |
#   |--เลือกปี (2025)------->|                                |
#   |                        |                                |
#   |                        |--ดึงข้อมูลรายได้-------------->|
#   |                        |   SELECT                       |
#   |                        |   MONTH(payment_date) as month,|
#   |                        |   SUM(amount) as revenue,      |
#   |                        |   COUNT(*) as transactions     |
#   |                        |   FROM payments                |
#   |                        |   WHERE YEAR(payment_date)=2025|
#   |                        |   AND status = 'completed'     |
#   |                        |   GROUP BY MONTH(payment_date) |
#   |                        |                                |
#   |                        |<-------[ข้อมูล 12 เดือน]-------|
#   |                        |                                |
#   |                   [คำนวณ:]                             |
#   |                   - Total Revenue                       |
#   |                   - Average per Month                   |
#   |                   - Growth Rate (YoY)                   |
#   |                   - Peak Month                          |
#   |                        |                                |
#   |<--แสดงรายงานพร้อมกราฟ--|                                |
#   |  📊 Bar Chart         |                                |
#   |  📈 Line Chart (Trend)|                                |
#   |  📋 Summary Table     |                                |
#   |                        |                                |
# ```
#
# ---
#
# ### **Scenario 3: Analyze Business Performance**
#
# ```
# Director                System                          Database
#   |                        |                                |
#   |--คลิก "Performance Analysis"|                         |
#   |                        |                                |
#   |                        |--ดึงข้อมูลทั้งหมด------------->|
#   |                        |   Revenue Data                 |
#   |                        |   Booking Data                 |
#   |                        |   Customer Data                |
#   |                        |   Field Utilization            |
#   |                        |                                |
#   |                        |<-------[Comprehensive Data]----|
#   |                        |                                |
#   |                   [วิเคราะห์:]                         |
#   |                   - Revenue Trend                       |
#   |                   - Customer Acquisition Cost           |
#   |                   - Customer Lifetime Value             |
#   |                   - Booking Conversion Rate             |
#   |                   - Field Occupancy Rate                |
#   |                   - Popular Time Slots                  |
#   |                        |                                |
#   |<--แสดง Analytics Dashboard|                            |
#   |  🎯 Key Metrics       |                                |
#   |  📊 Comparison Charts |                                |
#   |  🔍 Insights          |                                |
#   |  💡 Recommendations   |                                |
#   |                        |                                |
# ```
#
# ---
#
# ### **Scenario 4: Monitor System Usage**
#
# ```
# Director                System                          Database
#   |                        |                                |
#   |--คลิก "System Monitoring"|                            |
#   |                        |                                |
#   |                        |--ดึงข้อมูล Usage Stats-------->|
#   |                        |   SELECT                       |
#   |                        |   - Active Users (by role)     |
#   |                        |   - Login Activity (last 30d)  |
#   |                        |   - Feature Usage              |
#   |                        |   - API Calls Count            |
#   |                        |   - Error Rates                |
#   |                        |   FROM access_logs, api_logs   |
#   |                        |                                |
#   |                        |<-------[Usage Statistics]------|
#   |                        |                                |
#   |<--แสดง System Metrics--|                                |
#   |  👤 User Activity     |                                |
#   |  📱 API Performance   |                                |
#   |  🐛 Error Logs        |                                |
#   |  ⏱️ Response Times    |                                |
#   |                        |                                |
# ```
#
# ---
#
# ### **Scenario 5: Field Management (View/Manage)**
#
# ```
# Director                System                          Database
#   |                        |                                |
#   |--คลิก "Field Management"|                             |
#   |                        |                                |
#   |                        |--ดึงข้อมูลสนามทั้งหมด--------->|
#   |                        |   SELECT f.*,                  |
#   |                        |   COUNT(b.booking_id) as total_bookings,|
#   |                        |   SUM(p.amount) as total_revenue|
#   |                        |   FROM fields f                |
#   |                        |   LEFT JOIN bookings b         |
#   |                        |   LEFT JOIN payments p         |
#   |                        |   GROUP BY f.field_id          |
#   |                        |                                |
#   |                        |<-------[Field Performance]-----|
#   |                        |                                |
#   |<--แสดงรายการสนาม-------|                                |
#   |  (ชื่อ, ประเภท,        |                                |
#   |   Occupancy Rate,      |                                |
#   |   Revenue, Rating)     |                                |
#   |                        |                                |
#   |--คลิกดูรายละเอียด----->|                                |
#   |                        |                                |
#   |<--แสดง Field Analytics-|                                |
#   |  📊 Booking Trends    |                                |
#   |  💰 Revenue by Period |                                |
#   |  ⭐ Customer Reviews  |                                |
#   |  📅 Popular Time Slots|                                |
#   |                        |                                |
# ```
#
# ---
#
# ### **Scenario 6: Customer Management (View)**
#
# ```
# Director                System                          Database
#   |                        |                                |
#   |--คลิก "Customer Insights"|                            |
#   |                        |                                |
#   |                        |--ดึงข้อมูลลูกค้า-------------->|
#   |                        |   SELECT u.*,                  |
#   |                        |   COUNT(b.booking_id) as total_bookings,|
#   |                        |   SUM(p.amount) as total_spent,|
#   |                        |   MAX(b.booking_date) as last_booking|
#   |                        |   FROM users u                 |
#   |                        |   LEFT JOIN bookings b         |
#   |                        |   LEFT JOIN payments p         |
#   |                        |   WHERE u.role = 'customer'    |
#   |                        |   GROUP BY u.user_id           |
#   |                        |                                |
#   |                        |<-------[Customer Data]---------|
#   |                        |                                |
#   |<--แสดง Customer Segments|                               |
#   |  🌟 VIP Customers     |                                |
#   |  💎 High Value        |                                |
#   |  🎯 Active            |                                |
#   |  😴 Inactive          |                                |
#   |  🆕 New Customers     |                                |
#   |                        |                                |
# ```
#
# **[View Customer Details]**
# ```
# Director                System                          Database
#   |                        |                                |
#   |--เลือกลูกค้า---------->|                                |
#   |                        |                                |
#   |                        |--ดึงประวัติครบถ้วน------------>|
#   |                        |   SELECT * FROM bookings       |
#   |                        |   WHERE user_id = ?            |
#   |                        |   ORDER BY booking_date DESC   |
#   |                        |                                |
#   |                        |<-------[Booking History]-------|
#   |                        |                                |
#   |<--แสดงรายละเอียด-------|                                |
#   |  👤 Profile Info      |                                |
#   |  📅 Booking History   |                                |
#   |  💰 Spending Pattern  |                                |
#   |  ⭐ Preferences       |                                |
#   |                        |                                |
# ```
#
# ---
#
# ### **Scenario 7: Review Strategic Plans**
#
# ```
# Director                System                          Database
#   |                        |                                |
#   |--คลิก "Strategic Planning"|                          |
#   |                        |                                |
#   |<--แสดง Planning Tools--|                                |
#   |  - Market Analysis    |                                |
#   |  - Competitor Comparison|                              |
#   |  - Growth Projections |                                |
#   |  - Investment Plans   |                                |
#   |                        |                                |
#   |--คลิก "Growth Projections"|                           |
#   |                        |                                |
#   |                        |--ดึงข้อมูลย้อนหลัง 2 ปี------->|
#   |                        |   SELECT ... FROM payments     |
#   |                        |   WHERE payment_date >= ...    |
#   |                        |                                |
#   |                        |<-------[Historical Data]-------|
#   |                        |                                |
#   |                   [คำนวณการคาดการณ์:]                  |
#   |                   - Linear Regression                   |
#   |                   - Seasonal Adjustment                 |
#   |                   - Growth Rate Projection              |
#   |                        |                                |
#   |<--แสดงการคาดการณ์------|                                |
#   |  📈 Revenue Forecast  |                                |
#   |  👥 Customer Growth   |                                |
#   |  🏟️ Capacity Planning |                                |
#   |                        |                                |
# ```
#
# ---
#
# ### **Scenario 8: Approve Major Decisions**
#
# ```
# Director                System                          Database
#   |                        |                                |
#   |--คลิก "Pending Approvals"|                            |
#   |                        |                                |
#   |                        |--ดึงรายการที่รออนุมัติ--------->|
#   |                        |   SELECT * FROM approvals      |
#   |                        |   WHERE status = 'pending'     |
#   |                        |   AND requires_director = true |
#   |                        |                                |
#   |                        |<-------[Pending Items]---------|
#   |                        |                                |
#   |<--แสดงรายการ-----------|                                |
#   |  - Large Refunds (>5000฿)|                             |
#   |  - New Field Addition |                                |
#   |  - Budget Changes     |                                |
#   |  - Policy Updates     |                                |
#   |                        |                                |
#   |--เลือกรายการ---------->|                                |
#   |                        |                                |
#   |<--แสดงรายละเอียดครบ----|                                |
#   |  พร้อมเอกสารประกอบ     |                                |
#   |                        |                                |
#   |--กด "Approve"--------->|                                |
#   |  หรือ "Reject"         |                                |
#   |--กรอกหมายเหตุ--------->|                                |
#   |                        |                                |
#   |                        |--อัพเดทสถานะ------------------>|
#   |                        |   UPDATE approvals             |
#   |                        |   SET status = 'approved',     |
#   |                        |   approved_by = ?,             |
#   |                        |   approved_at = NOW(),         |
#   |                        |   note = ?                     |
#   |                        |                                |
#   |                        |--บันทึก Audit Log------------->|
#   |                        |   INSERT INTO audit_logs       |
#   |                        |                                |
#   |                   [แจ้งผู้เกี่ยวข้อง]                  |
#   |                        |                                |
#   |<--แสดงความสำเร็จ-------|                                |
#   |                        |                                |
# ```
#
# ---
#
# ### **Scenario 9: Access Control & Audit**
#
# ```
# Director                System                          Database
#   |                        |                                |
#   |--คลิก "Audit Reports"->|                                |
#   |                        |                                |
#   |                        |--ดึง Audit Logs--------------->|
#   |                        |   SELECT * FROM audit_logs     |
#   |                        |   ORDER BY created_at DESC     |
#   |                        |   LIMIT 100                    |
#   |                        |                                |
#   |                        |<-------[Audit Trail]-----------|
#   |                        |                                |
#   |<--แสดง Audit Logs------|                                |
#   |  (เวลา, ผู้ใช้, Action,|                               |
#   |   รายละเอียด, IP)      |                                |
#   |                        |                                |
#   |--Filter ตามเงื่อนไข--->|                                |
#   |  (วันที่, ผู้ใช้, Action)|                             |
#   |                        |                                |
#   |                        |--Query ตาม Filter------------->|
#   |                        |                                |
#   |                        |<-------[Filtered Results]------|
#   |                        |                                |
#   |<--แสดงผลกรอง-----------|                                |
#   |                        |                                |
# ```
#
# ---
#
# ### **Alternative Flows**
#
# **[Warning: Low Revenue Alert]**
# ```
# System ----Monitor Daily Revenue----> Database
#        <----[Below Threshold]--------
#        ----Generate Alert----------->
#        ----Notify Director---------->
#            "📉 Revenue ต่ำกว่าเป้า 20%"
# ```
#
# **[Alert: Suspicious Activity]**
# ```
# System ----Monitor Audit Logs----> Database
#        <----[Unusual Pattern]------
#        ----Flag as Suspicious----->
#        ----Alert Director--------->
#            "⚠️ ตรวจพบกิจกรรมผิดปกติ"
# ```
#
# ---
#
# ### **สรุป Key Points**
# - ✅ Executive Dashboard พร้อม real-time KPIs
# - ✅ Comprehensive revenue reporting (Daily/Monthly/Yearly)
# - ✅ Business performance analytics
# - ✅ System monitoring และ usage statistics
# - ✅ Field performance tracking
# - ✅ Customer insights และ segmentation
# - ✅ Strategic planning tools
# - ✅ Approval workflow สำหรับ major decisions
# - ✅ Audit trail และ access control

# %% [markdown]
# ---
#
# ## 🔄 Sequence Diagram: UCD-006 (Marketing Staff)
#
# ### **Participants**
# ```
# Marketer (Marketing Staff) | System (MarketingController, PromotionDAO, CampaignService, AnalyticsService) | Database (MySQL)
# ```
#
# ---
#
# ### **Scenario 1: Create Promotion**
#
# ```
# Marketer                System                          Database
#   |                        |                                |
#   |--เข้าหน้า Promotions-->|                                |
#   |                        |                                |
#   |<--แสดง Promotions List-|                                |
#   |  (Active / Scheduled / Expired)|                        |
#   |                        |                                |
#   |--กด "Create Promotion">|                                |
#   |                        |                                |
#   |<--แสดงฟอร์ม------------|                                |
#   |                        |                                |
#   |--กรอกข้อมูล----------->|                                |
#   |  - ชื่อโปรโมชั่น       |                                |
#   |  - ประเภท (Daily/Monthly/Special)|                     |
#   |  - Discount (% หรือ บาท)|                              |
#   |  - เงื่อนไข (min booking)|                             |
#   |  - วันเริ่ม - สิ้นสุด  |                                |
#   |  - Code (ถ้ามี)        |                                |
#   |                        |                                |
#   |--กด "Create"---------->|                                |
#   |                        |                                |
#   |                        |--ตรวจสอบ Code ซ้ำ (ถ้ามี)----->|
#   |                        |   SELECT * FROM promotions     |
#   |                        |   WHERE promo_code = ?         |
#   |                        |                                |
#   |                        |<-------[ไม่พบ]-----------------|
#   |                        |                                |
#   |                        |--บันทึกโปรโมชั่น--------------->|
#   |                        |   INSERT INTO promotions(      |
#   |                        |   name, type, discount_type,   |
#   |                        |   discount_value, start_date,  |
#   |                        |   end_date, promo_code,        |
#   |                        |   min_booking_amount,          |
#   |                        |   status, created_by)          |
#   |                        |                                |
#   |                        |<-------[promotionId]-----------|
#   |                        |                                |
#   |<--แสดงความสำเร็จ-------|                                |
#   |  "สร้างโปรโมชั่นแล้ว"  |                                |
#   |                        |                                |
# ```
#
# **[Activate Promotion]**
# ```
# Marketer                System                          Database
#   |                        |                                |
#   |--เลือก Promotion------>|                                |
#   |--กด "Activate"-------->|                                |
#   |                        |                                |
#   |                        |--อัพเดทสถานะ------------------>|
#   |                        |   UPDATE promotions            |
#   |                        |   SET status = 'active',       |
#   |                        |   activated_at = NOW()         |
#   |                        |                                |
#   |                   [แจ้งเตือนลูกค้า]                    |
#   |                   [อัพเดทบนเว็บไซต์]                   |
#   |                        |                                |
#   |<--แสดงความสำเร็จ-------|                                |
#   |                        |                                |
# ```
#
# ---
#
# ### **Scenario 2: Campaign Management**
#
# ```
# Marketer                System                          Database
#   |                        |                                |
#   |--เข้าหน้า Campaigns--->|                                |
#   |                        |                                |
#   |<--แสดง Campaign List---|                                |
#   |                        |                                |
#   |--กด "Create Campaign"->|                                |
#   |                        |                                |
#   |<--แสดงฟอร์ม------------|                                |
#   |                        |                                |
#   |--กรอกข้อมูล Campaign-->|                                |
#   |  - ชื่อแคมเปญ          |                                |
#   |  - ประเภท (Seasonal/Event/Special)|                    |
#   |  - Target Audience     |                                |
#   |  - Duration            |                                |
#   |  - Budget              |                                |
#   |  - Promotions ที่เกี่ยวข้อง|                           |
#   |                        |                                |
#   |--กด "Create"---------->|                                |
#   |                        |                                |
#   |                        |--สร้าง Campaign--------------->|
#   |                        |   INSERT INTO campaigns(...)   |
#   |                        |                                |
#   |                        |<-------[campaignId]------------|
#   |                        |                                |
#   |                        |--Link Promotions--------------->|
#   |                        |   INSERT INTO                  |
#   |                        |   campaign_promotions(...)     |
#   |                        |                                |
#   |<--แสดงความสำเร็จ-------|                                |
#   |                        |                                |
# ```
#
# **[Launch Campaign]**
# ```
# Marketer                System                          Database
#   |                        |                                |
#   |--เลือก Campaign------->|                                |
#   |--กด "Launch"---------->|                                |
#   |                        |                                |
#   |                        |--อัพเดทสถานะ------------------>|
#   |                        |   UPDATE campaigns             |
#   |                        |   SET status = 'active',       |
#   |                        |   launched_at = NOW()          |
#   |                        |                                |
#   |                        |--Activate ทุก Promotions------>|
#   |                        |   UPDATE promotions SET...     |
#   |                        |                                |
#   |                   [ส่ง Email Marketing]                |
#   |                   [Post บน Social Media]               |
#   |                   [แจ้งเตือน Push Notification]        |
#   |                        |                                |
#   |<--แสดงความสำเร็จ-------|                                |
#   |  "Launch Campaign แล้ว"|                                |
#   |                        |                                |
# ```
#
# ---
#
# ### **Scenario 3: Field Popularity Analysis**
#
# ```
# Marketer                System                          Database
#   |                        |                                |
#   |--คลิก "Field Analytics"|                               |
#   |                        |                                |
#   |                        |--วิเคราะห์ความนิยมสนาม-------->|
#   |                        |   SELECT f.field_name,         |
#   |                        |   COUNT(b.booking_id) as bookings,|
#   |                        |   SUM(p.amount) as revenue,    |
#   |                        |   AVG(r.rating) as avg_rating, |
#   |                        |   FROM fields f                |
#   |                        |   JOIN bookings b              |
#   |                        |   JOIN payments p              |
#   |                        |   LEFT JOIN reviews r          |
#   |                        |   GROUP BY f.field_id          |
#   |                        |   ORDER BY bookings DESC       |
#   |                        |                                |
#   |                        |<-------[Field Statistics]------|
#   |                        |                                |
#   |<--แสดงการจัดอันดับ-----|                                |
#   |  🥇 Top 3 Fields      |                                |
#   |  📊 Booking Trends    |                                |
#   |  ⭐ Rating vs Booking |                                |
#   |  💰 Revenue Analysis  |                                |
#   |                        |                                |
# ```
#
# ---
#
# ### **Scenario 4: Customer Analytics**
#
# **[Customer Segmentation]**
# ```
# Marketer                System                          Database
#   |                        |                                |
#   |--คลิก "Customer Segments"|                            |
#   |                        |                                |
#   |                        |--วิเคราะห์และแบ่งกลุ่มลูกค้า--->|
#   |                        |   SELECT u.*,                  |
#   |                        |   COUNT(b.booking_id) as frequency,|
#   |                        |   SUM(p.amount) as total_spent,|
#   |                        |   MAX(b.booking_date) as last_visit|
#   |                        |   FROM users u                 |
#   |                        |   JOIN bookings b              |
#   |                        |   JOIN payments p              |
#   |                        |   GROUP BY u.user_id           |
#   |                        |                                |
#   |                        |<-------[Customer Data]---------|
#   |                        |                                |
#   |                   [RFM Segmentation:]                   |
#   |                   - VIP (High Frequency + High Value)   |
#   |                   - Regular (Medium F + M V)            |
#   |                   - At Risk (Low Recency)               |
#   |                   - New (Recent but Low F)              |
#   |                        |                                |
#   |<--แสดง Segments--------|                                |
#   |  📊 Pie Chart         |                                |
#   |  📋 List by Segment   |                                |
#   |  💡 Recommendations   |                                |
#   |                        |                                |
# ```
#
# **[Analyze Customer Behavior]**
# ```
# Marketer                System                          Database
#   |                        |                                |
#   |--คลิก "Behavior Analysis"|                            |
#   |                        |                                |
#   |                        |--วิเคราะห์พฤติกรรม------------>|
#   |                        |   - Booking Patterns           |
#   |                        |   - Preferred Time Slots       |
#   |                        |   - Preferred Field Types      |
#   |                        |   - Equipment Rental Patterns  |
#   |                        |   - Payment Methods            |
#   |                        |                                |
#   |                        |<-------[Behavioral Insights]---|
#   |                        |                                |
#   |<--แสดงการวิเคราะห์-----|                                |
#   |  🕐 Peak Booking Times|                                |
#   |  🏟️ Popular Field Types|                               |
#   |  💳 Payment Preferences|                               |
#   |  📈 Seasonal Trends   |                                |
#   |                        |                                |
# ```
#
# ---
#
# ### **Scenario 5: View Analytics Dashboard**
#
# ```
# Marketer                System                          Database
#   |                        |                                |
#   |--เข้า Marketing Dashboard|                            |
#   |                        |                                |
#   |                        |--ดึงข้อมูล KPIs--------------->|
#   |                        |   - Active Promotions          |
#   |                        |   - Campaign Performance       |
#   |                        |   - Promotion Usage Rate       |
#   |                        |   - Customer Acquisition       |
#   |                        |   - Engagement Metrics         |
#   |                        |                                |
#   |                        |<-------[Marketing Metrics]-----|
#   |                        |                                |
#   |<--แสดง Dashboard-------|                                |
#   |  📊 Promotion Stats   |                                |
#   |  📈 Campaign ROI      |                                |
#   |  👥 Customer Growth   |                                |
#   |  💰 Revenue Impact    |                                |
#   |  🎯 Conversion Rates  |                                |
#   |                        |                                |
# ```
#
# ---
#
# ### **Scenario 6: Generate Reports**
#
# ```
# Marketer                System                          Database
#   |                        |                                |
#   |--คลิก "Reports"------->|                                |
#   |                        |                                |
#   |<--แสดงประเภท Reports---|                                |
#   |  - Sales Report       |                                |
#   |  - Marketing Report   |                                |
#   |  - Promotion Performance|                              |
#   |  - Campaign Results   |                                |
#   |                        |                                |
#   |--เลือก "Promotion Performance"|                        |
#   |--เลือกช่วงเวลา-------->|                                |
#   |                        |                                |
#   |                        |--ดึงข้อมูลโปรโมชั่น----------->|
#   |                        |   SELECT p.*,                  |
#   |                        |   COUNT(b.booking_id) as usage_count,|
#   |                        |   SUM(b.discount_amount) as total_discount,|
#   |                        |   SUM(pay.amount) as revenue_generated|
#   |                        |   FROM promotions p            |
#   |                        |   LEFT JOIN bookings b         |
#   |                        |   LEFT JOIN payments pay       |
#   |                        |   GROUP BY p.promotion_id      |
#   |                        |                                |
#   |                        |<-------[Promotion Data]--------|
#   |                        |                                |
#   |                   [คำนวณ:]                             |
#   |                   - Usage Rate                          |
#   |                   - ROI (Revenue - Discount)            |
#   |                   - Customer Attraction Rate            |
#   |                   - Repeat Usage                        |
#   |                        |                                |
#   |<--แสดงรายงาน-----------|                                |
#   |  พร้อมกราฟและตาราง     |                                |
#   |                        |                                |
# ```
#
# **[Export Report]**
# ```
# Marketer                System                          Database
#   |                        |                                |
#   |--เลือกรูปแบบ Export--->|                                |
#   |  (PDF / Excel)         |                                |
#   |                        |                                |
#   |--กด "Export"---------->|                                |
#   |                        |                                |
#   |                   [สร้างไฟล์]                          |
#   |                        |                                |
#   |<--ดาวน์โหลดไฟล์--------|                                |
#   |                        |                                |
# ```
#
# **[Send Email Report]**
# ```
# Marketer                System                          Database
#   |                        |                                |
#   |--กด "Email Report"---->|                                |
#   |                        |                                |
#   |<--แสดงฟอร์มอีเมล-------|                                |
#   |                        |                                |
#   |--กรอก Recipients------>|                                |
#   |  (Managing Director,   |                                |
#   |   Marketing Team)      |                                |
#   |                        |                                |
#   |--กด "Send"------------>|                                |
#   |                        |                                |
#   |                   [สร้าง PDF Report]                   |
#   |                   [แนบไฟล์และส่งอีเมล]                 |
#   |                        |                                |
#   |<--แสดงความสำเร็จ-------|                                |
#   |                        |                                |
# ```
#
# ---
#
# ### **Scenario 7: Coordinate with Booking Staff**
#
# ```
# Marketer                System                          Database
#   |                        |                                |
#   |--สร้าง Marketing Request|                              |
#   |  (Feature Promotion,   |                                |
#   |   Special Arrangement) |                                |
#   |                        |                                |
#   |                        |--บันทึก Request--------------->|
#   |                        |   INSERT INTO marketing_requests|
#   |                        |   (request_type, details,      |
#   |                        |   priority, created_by)        |
#   |                        |                                |
#   |                        |--แจ้ง Booking Staff----------->|
#   |                        |   Send Notification            |
#   |                        |                                |
#   |<--แสดงความสำเร็จ-------|                                |
#   |                        |                                |
#   |                   [Booking Staff ดำเนินการ]           |
#   |                        |                                |
#   |                        |<--Status Update---------------|
#   |                   (from Booking Staff)                 |
#   |                        |                                |
#   |<--รับการแจ้งเตือน------|                                |
#   |  "Request Completed"   |                                |
#   |                        |                                |
# ```
#
# ---
#
# ### **Alternative Flows**
#
# **[Error: Promotion Code ซ้ำ]**
# ```
# System ----ตรวจสอบ----> Database
#        <----[Code exists]---
#        ----Error-------> Marketer
#            "Promotion Code นี้ถูกใช้แล้ว"
#            "กรุณาใช้ Code อื่น"
# ```
#
# **[Warning: Low Promotion Usage]**
# ```
# System ----Monitor Usage----> Database
#        <----[Usage < 10%]-----
#        ----Alert--------> Marketer
#            "⚠️ โปรโมชั่นใช้งานต่ำ"
#            "💡 พิจารณาปรับเงื่อนไข"
# ```
#
# **[Insight: Campaign Success]**
# ```
# System ----Analyze Campaign----> Database
#        <----[ROI > 200%]----------
#        ----Notification--------> Marketer
#            "🎉 Campaign ประสบความสำเร็จ!"
#            "Revenue เพิ่ม 250%"
# ```
#
# ---
#
# ### **สรุป Key Points**
# - ✅ Promotion Management (Create/Edit/Activate/Deactivate)
# - ✅ Campaign Management (Create/Launch/Monitor)
# - ✅ Field popularity analysis
# - ✅ Customer segmentation (RFM model)
# - ✅ Behavioral analytics (booking patterns, preferences)
# - ✅ Marketing dashboard พร้อม KPIs
# - ✅ Comprehensive reporting (Sales/Marketing/Promotion)
# - ✅ Export และ Email reporting
# - ✅ Coordination กับ Booking Staff

# %% [markdown]
# ---
#
# ## 🔄 Sequence Diagram: UCD-007 (Payment Gateway Integration)
#
# ### **Participants**
# ```
# Customer/Staff | System (PaymentController) | Payment Gateway (External) | Database (MySQL)
# ```
#
# ---
#
# ### **Scenario 1: Process Payment**
#
# ```
# User                    System                  Payment Gateway         Database
#   |                        |                          |                      |
#   |--เลือกวิธีชำระเงิน---->|                          |                      |
#   |  (QR/Transfer/Card)    |                          |                      |
#   |                        |                          |                      |
#   |                        |--สร้าง Payment Record-->|                      |
#   |                        |                          |    INSERT INTO payments
#   |                        |                          |    (booking_id, amount,
#   |                        |                          |     payment_method,
#   |                        |                          |     status='pending')
#   |                        |                          |                      |
#   |                        |                          |<-----[paymentId]-----|
#   |                        |                          |                      |
#   |                        |--ส่งข้อมูล-------------->|                      |
#   |                        |   POST /payment          |                      |
#   |                        |   {                      |                      |
#   |                        |     amount: 1500,        |                      |
#   |                        |     method: "qr_code",   |                      |
#   |                        |     booking_id: "BK_123" |                      |
#   |                        |   }                      |                      |
#   |                        |                          |                      |
#   |                        |                      [ประมวลผล]                 |
#   |                        |                      [Validate]                 |
#   |                        |                      [Generate QR/Form]         |
#   |                        |                          |                      |
#   |                        |<--Payment Interface------|                      |
#   |                        |   (QR Code/Payment Form) |                      |
#   |                        |                          |                      |
#   |<--แสดง Payment UI------|                          |                      |
#   |  (QR Code หรือฟอร์ม)   |                          |                      |
#   |                        |                          |                      |
#   |--ชำระเงิน--------------|--[ผ่าน Gateway UI]----->|                      |
#   |                        |                          |                      |
#   |                        |                      [Process Payment]          |
#   |                        |                      [Verify Payment]           |
#   |                        |                          |                      |
#   |                        |<--Payment Confirmation---|                      |
#   |                        |   {                      |                      |
#   |                        |     status: "success",   |                      |
#   |                        |     transaction_id: "...",|                     |
#   |                        |     amount: 1500         |                      |
#   |                        |   }                      |                      |
#   |                        |                          |                      |
#   |                        |--อัพเดทสถานะ-------------|-------------------->|
#   |                        |                          |  UPDATE payments    |
#   |                        |                          |  SET status='completed',
#   |                        |                          |  transaction_id=?,  |
#   |                        |                          |  paid_at=NOW()      |
#   |                        |                          |                      |
#   |                        |--สร้างใบเสร็จ------------|-------------------->|
#   |                        |                          |  INSERT INTO receipts
#   |                        |                          |                      |
#   |<--แสดงความสำเร็จ-------|                          |                      |
#   |  "ชำระเงินสำเร็จ"      |                          |                      |
#   |  พร้อมใบเสร็จ          |                          |                      |
#   |                        |                          |                      |
#   |                   [ส่ง Email พร้อมใบเสร็จ]                              |
#   |                        |                          |                      |
# ```
#
# ---
#
# ### **Scenario 2: Verify Payment Status**
#
# ```
# System                  Payment Gateway         Database
#   |                          |                      |
#   |--Query Payment Status--->|                      |
#   |   GET /verify            |                      |
#   |   {transaction_id: "..."}|                      |
#   |                          |                      |
#   |                      [ตรวจสอบสถานะ]               |
#   |                          |                      |
#   |<--Verification Result----|                      |
#   |   {                      |                      |
#   |     status: "completed", |                      |
#   |     amount: 1500,        |                      |
#   |     paid_at: "..."       |                      |
#   |   }                      |                      |
#   |                          |                      |
#   |--บันทึก Verification----|-------------------->|
#   |                          |  UPDATE payments    |
#   |                          |  SET verified=true, |
#   |                          |  verified_at=NOW()  |
#   |                          |                      |
# ```
#
# ---
#
# ### **Scenario 3: Process Refund**
#
# ```
# Accountant              System                  Payment Gateway         Database
#   |                        |                          |                      |
#   |--Request Refund------->|                          |                      |
#   |  (payment_id, amount,  |                          |                      |
#   |   reason)              |                          |                      |
#   |                        |                          |                      |
#   |                        |--ดึงข้อมูล Payment------|-------------------->|
#   |                        |                          |  SELECT * FROM      |
#   |                        |                          |  payments WHERE ... |
#   |                        |                          |                      |
#   |                        |                          |<-----[payment data]--|
#   |                        |                          |                      |
#   |                        |--ส่งคำขอ Refund-------->|                      |
#   |                        |   POST /refund           |                      |
#   |                        |   {                      |                      |
#   |                        |     transaction_id: "...",|                     |
#   |                        |     amount: 1500,        |                      |
#   |                        |     reason: "..."        |                      |
#   |                        |   }                      |                      |
#   |                        |                          |                      |
#   |                        |                      [ประมวลผล Refund]          |
#   |                        |                      [ตรวจสอบสิทธิ์]            |
#   |                        |                          |                      |
#   |                        |<--Refund Confirmation----|                      |
#   |                        |   {                      |                      |
#   |                        |     status: "refunded",  |                      |
#   |                        |     refund_id: "...",    |                      |
#   |                        |     amount: 1500         |                      |
#   |                        |   }                      |                      |
#   |                        |                          |                      |
#   |                        |--บันทึก Refund----------|-------------------->|
#   |                        |                          |  INSERT INTO refunds|
#   |                        |                          |  UPDATE payments    |
#   |                        |                          |  SET status='refunded'
#   |                        |                          |                      |
#   |<--แสดงความสำเร็จ-------|                          |                      |
#   |  "คืนเงินสำเร็จ"       |                          |                      |
#   |                        |                          |                      |
#   |                   [แจ้ง Customer]                                       |
#   |                        |                          |                      |
# ```
#
# ---
#
# ### **Scenario 4: Handle Payment Webhook (Real-time Update)**
#
# ```
# Payment Gateway         System                          Database
#   |                        |                                |
#   |--Webhook Notification->|                                |
#   |   POST /webhook        |                                |
#   |   {                    |                                |
#   |     event: "payment.success",                          |
#   |     transaction_id: "...",                             |
#   |     booking_id: "BK_123",                              |
#   |     amount: 1500,      |                                |
#   |     status: "completed"|                               |
#   |   }                    |                                |
#   |                        |                                |
#   |                   [Validate Webhook]                   |
#   |                   [Verify Signature]                   |
#   |                        |                                |
#   |                        |--อัพเดทสถานะ Real-time------->|
#   |                        |   UPDATE payments              |
#   |                        |   SET status='completed',      |
#   |                        |   webhook_received_at=NOW()    |
#   |                        |                                |
#   |                        |--อัพเดท Booking--------------->|
#   |                        |   UPDATE bookings              |
#   |                        |   SET payment_status='paid'    |
#   |                        |                                |
#   |                        |--แจ้ง Customer---------------->|
#   |                        |   Send Email/SMS Notification  |
#   |                        |                                |
#   |<--Webhook Response-----|                                |
#   |   200 OK               |                                |
#   |                        |                                |
# ```
#
# ---
#
# ### **Scenario 5: Handle Payment Failure**
#
# ```
# User                    System                  Payment Gateway         Database
#   |                        |                          |                      |
#   |--ชำระเงิน--------------|------------------------>|                      |
#   |                        |                          |                      |
#   |                        |                      [Process Payment]          |
#   |                        |                      [Payment Failed]           |
#   |                        |                      - เงินไม่พอ                |
#   |                        |                      - บัตรหมดอายุ              |
#   |                        |                      - การยืนยันล้มเหลว          |
#   |                        |                          |                      |
#   |                        |<--Payment Failed---------|                      |
#   |                        |   {                      |                      |
#   |                        |     status: "failed",    |                      |
#   |                        |     error_code: "...",   |                      |
#   |                        |     message: "..."       |                      |
#   |                        |   }                      |                      |
#   |                        |                          |                      |
#   |                        |--บันทึก Failed Status---|-------------------->|
#   |                        |                          |  UPDATE payments    |
#   |                        |                          |  SET status='failed',
#   |                        |                          |  error_message=?    |
#   |                        |                          |                      |
#   |                        |--Log Error---------------|-------------------->|
#   |                        |                          |  INSERT INTO        |
#   |                        |                          |  payment_errors     |
#   |                        |                          |                      |
#   |<--แสดง Error Message---|                          |                      |
#   |  "การชำระเงินล้มเหลว"  |                          |                      |
#   |  "กรุณาลองใหม่หรือ     |                          |                      |
#   |   เปลี่ยนวิธีชำระ"     |                          |                      |
#   |                        |                          |                      |
# ```
#
# ---
#
# ### **Alternative Flows**
#
# **[Payment Timeout]**
# ```
# Payment Gateway ----No Response (5 min)----> System
#                                               |
#                                          [Retry 3 times]
#                                               |
#                                          [Still Failed]
#                                               |
#                                         Mark as "timeout"
#                                               |
#                                         Alert User & Staff
#                                         "การชำระเงินหมดเวลา"
# ```
#
# **[Duplicate Payment]**
# ```
# System ----ตรวจสอบ Transaction ID----> Database
#        <----[พบ Transaction ซ้ำ]--------
#        ----Block Payment--------------->
#        ----Process Refund-------------->
#        ----Notify Customer------------->
#            "ตรวจพบการชำระซ้ำ จะคืนเงินให้"
# ```
#
# **[Partial Payment]**
# ```
# Payment Gateway ----Amount Mismatch----> System
#                     (จำนวนไม่ครบ)
#                                           |
#                                     Mark as "partial"
#                                           |
#                                     Calculate Remaining
#                                           |
#                                     Send Payment Reminder
#                                     "ชำระเงินไม่ครบ เหลือ XXX บาท"
# ```
#
# **[Suspicious Transaction]**
# ```
# Payment Gateway ----Fraud Alert----> System
#                                       |
#                                  Flag Transaction
#                                       |
#                                  Hold Payment
#                                       |
#                                  Notify Admin
#                                  "ตรวจพบรายการผิดปกติ"
#                                       |
#                                  Require Manual Review
# ```
#
# ---
#
# ### **สรุป Key Points**
# - ✅ Multi-payment method support (QR/Transfer/Card)
# - ✅ Real-time payment processing
# - ✅ Payment verification mechanism
# - ✅ Refund processing พร้อม audit trail
# - ✅ Webhook integration สำหรับ real-time updates
# - ✅ Error handling ครบถ้วน (timeout, failure, duplicate)
# - ✅ Transaction security (signature verification)
# - ✅ Automatic receipt generation
# - ✅ Payment notifications (Email/SMS)

# %% [markdown]
# ---
#
# ## 🔄 Sequence Diagram: UCD-008 (Logistic System Integration)
#
# ### **Participants**
# ```
# Staff/Customer | System (OrderController, DeliveryService) | Logistic System (External) | Database (MySQL)
# ```
#
# ---
#
# ### **Scenario 1: Generate Order-ID & Send to Logistic**
#
# ```
# Booking Staff           System                  Logistic System         Database
#   |                        |                          |                      |
#   |--Approve Booking------>|                          |                      |
#   |  (ที่มีการเช่าอุปกรณ์) |                          |                      |
#   |                        |                          |                      |
#   |                        |--สร้าง Order-ID---------|-------------------->|
#   |                        |                          |  INSERT INTO orders |
#   |                        |                          |  (booking_id,       |
#   |                        |                          |   order_id='ORD_XXX',
#   |                        |                          |   status='created') |
#   |                        |                          |                      |
#   |                        |                          |<-----[orderId]------|
#   |                        |                          |                      |
#   |                        |--ส่ง Order-ID----------->|                      |
#   |                        |   POST /create-order     |                      |
#   |                        |   {                      |                      |
#   |                        |     order_id: "ORD_001", |                      |
#   |                        |     customer_name: "...",|                      |
#   |                        |     delivery_address: "...",                    |
#   |                        |     phone: "...",        |                      |
#   |                        |     equipment_list: [...],                      |
#   |                        |     delivery_date: "..." |                      |
#   |                        |   }                      |                      |
#   |                        |                          |                      |
#   |                        |                      [รับ Order]                |
#   |                        |                      [Validate ข้อมูล]          |
#   |                        |                      [สร้างใบงาน]              |
#   |                        |                          |                      |
#   |                        |<--Order Confirmation-----|                      |
#   |                        |   {                      |                      |
#   |                        |     status: "confirmed", |                      |
#   |                        |     order_id: "ORD_001",|                      |
#   |                        |     estimated_date: "..." |                     |
#   |                        |   }                      |                      |
#   |                        |                          |                      |
#   |                        |--บันทึกการยืนยัน--------|-------------------->|
#   |                        |                          |  UPDATE orders      |
#   |                        |                          |  SET status='confirmed'
#   |                        |                          |                      |
#   |<--แสดงความสำเร็จ-------|                          |                      |
#   |  "ส่งข้อมูลไป Logistic"|                          |                      |
#   |                        |                          |                      |
# ```
#
# ---
#
# ### **Scenario 2: Receive Tracking Number**
#
# ```
# System                  Logistic System         Database
#   |                          |                      |
#   |                      [เตรียมการจัดส่ง]            |
#   |                      [สร้าง Tracking Number]     |
#   |                          |                      |
#   |<--Tracking Number--------|                      |
#   |   POST /webhook          |                      |
#   |   (or GET /tracking)     |                      |
#   |   {                      |                      |
#   |     order_id: "ORD_001", |                      |
#   |     tracking_number: "TRK_ABC123",              |
#   |     status: "processing" |                      |
#   |   }                      |                      |
#   |                          |                      |
#   |--บันทึก Tracking No.-----|-------------------->|
#   |                          |  UPDATE orders      |
#   |                          |  SET tracking_number=?,
#   |                          |  status='processing'|
#   |                          |                      |
#   |                          |  INSERT INTO deliveries
#   |                          |  (order_id, tracking_number,
#   |                          |   status='processing')
#   |                          |                      |
#   |--ส่ง Notification--------|-------------------->|
#   |   Email/SMS to Customer  |                      |
#   |   "Tracking: TRK_ABC123" |                      |
#   |                          |                      |
# ```
#
# ---
#
# ### **Scenario 3: Update Delivery Status (Real-time)**
#
# ```
# Logistic System         System                          Database
#   |                        |                                |
#   |--Status Update-------->|                                |
#   |   POST /webhook        |                                |
#   |   {                    |                                |
#   |     tracking_number: "TRK_ABC123",                      |
#   |     order_id: "ORD_001",                                |
#   |     status: "in_transit",                               |
#   |     current_location: "กทม.",                           |
#   |     updated_at: "..."  |                                |
#   |   }                    |                                |
#   |                        |                                |
#   |                   [Validate Webhook]                   |
#   |                        |                                |
#   |                        |--อัพเดทสถานะ------------------>|
#   |                        |   UPDATE deliveries            |
#   |                        |   SET status='in_transit',     |
#   |                        |   current_location='กทม.',     |
#   |                        |   updated_at=NOW()             |
#   |                        |                                |
#   |                        |--บันทึก Status History-------->|
#   |                        |   INSERT INTO delivery_logs    |
#   |                        |   (delivery_id, status,        |
#   |                        |    location, timestamp)        |
#   |                        |                                |
#   |                        |--แจ้ง Customer---------------->|
#   |                        |   Send Notification            |
#   |                        |   "อุปกรณ์อยู่ระหว่างจัดส่ง"  |
#   |                        |                                |
#   |<--Response-------------|                                |
#   |   200 OK               |                                |
#   |                        |                                |
# ```
#
# **[Status Lifecycle:]**
# ```
# Confirmed → Processing → In-Transit → Out for Delivery → Delivered
# ```
#
# ---
#
# ### **Scenario 4: Track Delivery (Customer/Staff)**
#
# ```
# User                    System                  Logistic System         Database
#   |                        |                          |                      |
#   |--เปิดหน้า Tracking---->|                          |                      |
#   |                        |                          |                      |
#   |                        |--ดึงข้อมูล Delivery-----|-------------------->|
#   |                        |                          |  SELECT d.*, o.*    |
#   |                        |                          |  FROM deliveries d  |
#   |                        |                          |  JOIN orders o      |
#   |                        |                          |  WHERE tracking_number=?
#   |                        |                          |                      |
#   |                        |                          |<-----[delivery data]-|
#   |                        |                          |                      |
#   |                        |--Query Real-time Status->|                      |
#   |                        |   GET /track/{trackingNo}|                      |
#   |                        |                          |                      |
#   |                        |                      [ดึงข้อมูลล่าสุด]          |
#   |                        |                          |                      |
#   |                        |<--Tracking Details-------|                      |
#   |                        |   {                      |                      |
#   |                        |     status: "in_transit",|                      |
#   |                        |     current_location: "...",                    |
#   |                        |     estimated_delivery: "...",                  |
#   |                        |     status_history: [...]|                      |
#   |                        |   }                      |                      |
#   |                        |                          |                      |
#   |<--แสดง Tracking Info---|                          |                      |
#   |  📦 สถานะปัจจุบัน     |                          |                      |
#   |  📍 ตำแหน่งปัจจุบัน   |                          |                      |
#   |  ⏰ วันที่คาดว่าจะถึง  |                          |                      |
#   |  📋 Timeline          |                          |                      |
#   |                        |                          |                      |
# ```
#
# ---
#
# ### **Scenario 5: Schedule Delivery (Customer)**
#
# ```
# Customer                System                  Logistic System         Database
#   |                        |                          |                      |
#   |--เลือก Delivery Slot-->|                          |                      |
#   |                        |                          |                      |
#   |                        |--ดึง Available Slots---->|                      |
#   |                        |   GET /time-slots        |                      |
#   |                        |   {order_id: "ORD_001"}  |                      |
#   |                        |                          |                      |
#   |                        |<--Available Slots--------|                      |
#   |                        |   [                      |                      |
#   |                        |     "09:00-12:00",       |                      |
#   |                        |     "13:00-16:00",       |                      |
#   |                        |     "16:00-19:00"        |                      |
#   |                        |   ]                      |                      |
#   |                        |                          |                      |
#   |<--แสดง Time Slots------|                          |                      |
#   |                        |                          |                      |
#   |--เลือก Slot----------->|                          |                      |
#   |  "13:00-16:00"         |                          |                      |
#   |                        |                          |                      |
#   |                        |--ส่งการยืนยัน----------->|                      |
#   |                        |   POST /schedule         |                      |
#   |                        |   {                      |                      |
#   |                        |     order_id: "ORD_001", |                      |
#   |                        |     time_slot: "13:00-16:00"|                   |
#   |                        |   }                      |                      |
#   |                        |                          |                      |
#   |                        |<--Confirmation-----------|                      |
#   |                        |                          |                      |
#   |                        |--บันทึก Schedule---------|-------------------->|
#   |                        |                          |  UPDATE deliveries  |
#   |                        |                          |  SET delivery_time_slot=?
#   |                        |                          |                      |
#   |<--แสดงความสำเร็จ-------|                          |                      |
#   |  "กำหนดเวลาแล้ว"      |                          |                      |
#   |                        |                          |                      |
# ```
#
# ---
#
# ### **Scenario 6: Delivery Completed**
#
# ```
# Logistic System         System                          Database
#   |                        |                                |
#   |--Delivery Complete---->|                                |
#   |   POST /webhook        |                                |
#   |   {                    |                                |
#   |     tracking_number: "...",                            |
#   |     status: "delivered",                               |
#   |     delivered_at: "...",                               |
#   |     signature: "..."   |                                |
#   |   }                    |                                |
#   |                        |                                |
#   |                        |--อัพเดทสถานะ------------------>|
#   |                        |   UPDATE deliveries            |
#   |                        |   SET status='delivered',      |
#   |                        |   delivered_at=NOW(),          |
#   |                        |   signature=?                  |
#   |                        |                                |
#   |                        |--อัพเดท Booking--------------->|
#   |                        |   UPDATE bookings              |
#   |                        |   SET delivery_status='completed'
#   |                        |                                |
#   |                        |--แจ้ง Customer---------------->|
#   |                        |   Send Email/SMS               |
#   |                        |   "อุปกรณ์ส่งถึงแล้ว"         |
#   |                        |                                |
#   |                        |--Request Review--------------->|
#   |                        |   "กรุณาให้คะแนนการบริการ"    |
#   |                        |                                |
# ```
#
# ---
#
# ### **Alternative Flows**
#
# **[Delivery Delay]**
# ```
# Logistic System ----Delay Notification----> System
#                     {status: "delayed",
#                      reason: "...",
#                      new_estimated_date: "..."}
#                                               |
#                                          Update Database
#                                               |
#                                          Notify Customer & Staff
#                                          "การจัดส่งล่าช้า กำลังดำเนินการ"
# ```
#
# **[Failed Delivery]**
# ```
# Logistic System ----Delivery Failed----> System
#                     {status: "failed",
#                      reason: "ไม่พบผู้รับ"}
#                                           |
#                                      Update Status
#                                           |
#                                      Alert Booking Staff
#                                           |
#                                      Contact Customer
#                                      "กรุณานัดหมายใหม่"
# ```
#
# **[Lost Tracking Number]**
# ```
# System ----No Tracking Number (24h)----> Logistic System
#                                           |
#                                       [Retry 3 times]
#                                           |
#                                       [Still No Response]
#                                           |
#                                      Manual Request
#                                      by Booking Staff
#                                           |
#                                      Alert Admin
# ```
#
# **[Equipment Damaged]**
# ```
# Customer ----Report Damage----> System
#                                   |
#                              Record Complaint
#                                   |
#                              Notify Logistic
#                                   |
#                              Notify Staff
#                                   |
#                              Process Compensation
# ```
#
# ---
#
# ### **สรุป Key Points**
# - ✅ Order-ID generation และส่งไป Logistic System
# - ✅ Tracking Number integration
# - ✅ Real-time delivery status updates (Webhook)
# - ✅ Status lifecycle management (Confirmed→Delivered)
# - ✅ Delivery tracking สำหรับ Customer/Staff
# - ✅ Time slot scheduling
# - ✅ Automatic notifications (SMS/Email)
# - ✅ Error handling (delay, failed delivery)
# - ✅ Proof of delivery (signature)

# %% [markdown]
# ---
#
# ## 🔄 Sequence Diagram: UCD-009 (Customer Experience)
#
# ### **Participants**
# ```
# Customer | System (FieldController, BookingController, PaymentController) | Payment Gateway | Logistic System | Database (MySQL)
# ```
#
# ---
#
# ### **Scenario 1: Browse Available Fields**
#
# ```
# Customer                System                          Database
#   |                        |                                |
#   |--เข้าหน้าแรก---------->|                                |
#   |                        |                                |
#   |                        |--ดึงรายการสนามทั้งหมด--------->|
#   |                        |   SELECT f.*, AVG(r.rating)    |
#   |                        |   FROM fields f                |
#   |                        |   LEFT JOIN reviews r          |
#   |                        |   WHERE f.is_active = true     |
#   |                        |   GROUP BY f.field_id          |
#   |                        |                                |
#   |                        |<-------[รายการสนาม]------------|
#   |                        |                                |
#   |<--แสดงรายการสนาม-------|                                |
#   |  (รูปภาพ, ชื่อ, ราคา,  |                                |
#   |   Rating, สิ่งอำนวยความสะดวก)|                          |
#   |                        |                                |
# ```
#
# **[Search & Filter]**
# ```
# Customer                System                          Database
#   |                        |                                |
#   |--ค้นหาสนาม------------>|                                |
#   |  (ชื่อ, ประเภท)        |                                |
#   |--เลือก Filter-------->|                                |
#   |  (ราคา, สิ่งอำนวยความสะดวก,|                           |
#   |   Rating)              |                                |
#   |                        |                                |
#   |                        |--Query ตาม Filter------------->|
#   |                        |   SELECT * FROM fields         |
#   |                        |   WHERE field_type LIKE ?      |
#   |                        |   AND price BETWEEN ? AND ?    |
#   |                        |   ORDER BY rating DESC         |
#   |                        |                                |
#   |                        |<-------[ผลการค้นหา]------------|
#   |                        |                                |
#   |<--แสดงผลกรอง-----------|                                |
#   |                        |                                |
# ```
#
# **[View Field Details]**
# ```
# Customer                System                          Database
#   |                        |                                |
#   |--คลิกดูรายละเอียด----->|                                |
#   |                        |                                |
#   |                        |--ดึงข้อมูลครบถ้วน------------->|
#   |                        |   SELECT f.*, r.*, p.*         |
#   |                        |   FROM fields f                |
#   |                        |   LEFT JOIN reviews r          |
#   |                        |   LEFT JOIN field_photos p     |
#   |                        |   WHERE field_id = ?           |
#   |                        |                                |
#   |                        |--ดึง Available Time Slots----->|
#   |                        |   SELECT * FROM field_schedules|
#   |                        |   WHERE NOT EXISTS (...)       |
#   |                        |                                |
#   |                        |<-------[Full Details]----------|
#   |                        |                                |
#   |<--แสดงรายละเอียด-------|                                |
#   |  📸 รูปภาพทั้งหมด     |                                |
#   |  📝 รายละเอียด         |                                |
#   |  ⭐ Reviews           |                                |
#   |  📅 ช่วงเวลาว่าง      |                                |
#   |  💰 ราคา              |                                |
#   |                        |                                |
# ```
#
# ---
#
# ### **Scenario 2: Make Booking**
#
# ```
# Customer                System                          Database
#   |                        |                                |
#   |--เลือกสนาม------------>|                                |
#   |--เลือกวันที่---------->|                                |
#   |--เลือกเวลา------------>|                                |
#   |                        |                                |
#   |                        |--ตรวจสอบความว่าง-------------->|
#   |                        |   SELECT * FROM bookings       |
#   |                        |   WHERE field_id = ?           |
#   |                        |   AND booking_date = ?         |
#   |                        |   AND time_slot = ?            |
#   |                        |                                |
#   |                        |<-------[available]-------------|
#   |                        |                                |
#   |<--แสดงตัวเลือกอุปกรณ์---|                                |
#   |  (ถ้ามี)               |                                |
#   |                        |                                |
#   |--เลือกอุปกรณ์--------->|                                |
#   |  (Football x2,         |                                |
#   |   Cone x10)            |                                |
#   |                        |                                |
#   |                   [คำนวณราคารวม]                        |
#   |                   - ค่าสนาม: 1,000                      |
#   |                   - อุปกรณ์: 300                        |
#   |                   - รวม: 1,300                          |
#   |                        |                                |
#   |<--แสดงสรุปการจอง-------|                                |
#   |                        |                                |
#   |--ยืนยันการจอง--------->|                                |
#   |                        |                                |
#   |                        |--สร้าง Booking---------------->|
#   |                        |   INSERT INTO bookings(        |
#   |                        |   user_id, field_id,           |
#   |                        |   booking_date, time_slot,     |
#   |                        |   total_price, status)         |
#   |                        |                                |
#   |                        |<-------[bookingId]-------------|
#   |                        |                                |
#   |                        |--บันทึกอุปกรณ์---------------->|
#   |                        |   INSERT INTO                  |
#   |                        |   booking_equipment(...)       |
#   |                        |                                |
#   |<--Redirect to Payment--|                                |
#   |                        |                                |
# ```
#
# ---
#
# ### **Scenario 3: Make Payment**
#
# ```
# Customer                System          Payment Gateway         Database
#   |                        |                  |                    |
#   |--เลือกวิธีชำระ-------->|                  |                    |
#   |  (QR/Transfer/Card)    |                  |                    |
#   |                        |                  |                    |
#   |                        |--ส่งข้อมูล------>|                    |
#   |                        |                  |   INSERT payments  |
#   |                        |                  |<-------------------|
#   |                        |                  |                    |
#   |<--แสดง QR Code---------|<--QR Code--------|                    |
#   |  หรือฟอร์ม             |                  |                    |
#   |                        |                  |                    |
#   |--ชำระเงิน--------------|----------------->|                    |
#   |                        |                  |                    |
#   |                        |              [Process]                |
#   |                        |                  |                    |
#   |                        |<--Confirmation---|                    |
#   |                        |                  |                    |
#   |                        |--อัพเดท---------|------------------->|
#   |                        |                  |   UPDATE payments  |
#   |                        |                  |   UPDATE bookings  |
#   |                        |                  |                    |
#   |<--แสดงความสำเร็จ-------|                  |                    |
#   |  "ชำระเงินสำเร็จ"      |                  |                    |
#   |  พร้อมใบเสร็จ          |                  |                    |
#   |                        |                  |                    |
# ```
#
# ---
#
# ### **Scenario 4: Track Order (Equipment Delivery)**
#
# ```
# Customer                System          Logistic System         Database
#   |                        |                  |                    |
#   |--เปิดหน้า Track Order->|                  |                    |
#   |                        |                  |                    |
#   |                        |--ดึง Tracking No>|                    |
#   |                        |                  |  SELECT tracking_number
#   |                        |                  |  FROM deliveries   |
#   |                        |                  |<-------------------|
#   |                        |                  |                    |
#   |                        |--Query Status--->|                    |
#   |                        |                  |                    |
#   |                        |<--Status---------|                    |
#   |                        |  (In-Transit)    |                    |
#   |                        |                  |                    |
#   |<--แสดงสถานะ-----------|                  |                    |
#   |  📦 In-Transit        |                  |                    |
#   |  📍 กทม.              |                  |                    |
#   |  ⏰ คาดว่าถึง: วันพรุ่งนี้|                |                    |
#   |  📋 Timeline          |                  |                    |
#   |                        |                  |                    |
# ```
#
# ---
#
# ### **Scenario 5: View Booking History**
#
# ```
# Customer                System                          Database
#   |                        |                                |
#   |--เข้าหน้า My Bookings->|                                |
#   |                        |                                |
#   |                        |--ดึงรายการ Booking------------->|
#   |                        |   SELECT b.*, f.field_name,    |
#   |                        |   p.payment_status,            |
#   |                        |   d.delivery_status            |
#   |                        |   FROM bookings b              |
#   |                        |   JOIN fields f                |
#   |                        |   LEFT JOIN payments p         |
#   |                        |   LEFT JOIN deliveries d       |
#   |                        |   WHERE b.user_id = ?          |
#   |                        |   ORDER BY b.booking_date DESC |
#   |                        |                                |
#   |                        |<-------[Booking List]----------|
#   |                        |                                |
#   |<--แสดงรายการ-----------|                                |
#   |  📅 Upcoming Bookings |                                |
#   |  ✅ Completed         |                                |
#   |  ❌ Cancelled         |                                |
#   |                        |                                |
#   |--คลิกดูรายละเอียด----->|                                |
#   |                        |                                |
#   |<--แสดง Full Details---|                                |
#   |  พร้อมปุ่ม:            |                                |
#   |  - Download Receipt   |                                |
#   |  - Track Delivery     |                                |
#   |  - Cancel (ถ้าได้)    |                                |
#   |  - Rate & Review      |                                |
#   |                        |                                |
# ```
#
# ---
#
# ### **Scenario 6: Cancel Booking**
#
# ```
# Customer                System                          Database
#   |                        |                                |
#   |--เลือก Booking-------->|                                |
#   |--กด "Cancel"---------->|                                |
#   |                        |                                |
#   |                        |--ตรวจสอบ Cancellation Policy-->|
#   |                        |   SELECT booking_date,         |
#   |                        |   created_at, total_price      |
#   |                        |   FROM bookings WHERE ...      |
#   |                        |                                |
#   |                        |<-------[booking data]----------|
#   |                        |                                |
#   |                   [คำนวณค่าปรับ:]                       |
#   |                   - ยกเลิก >24ชม.: คืน 100%            |
#   |                   - ยกเลิก <24ชม.: คืน 50%             |
#   |                   - ยกเลิก <6ชม.: ไม่คืนเงิน            |
#   |                        |                                |
#   |<--แสดง Confirmation----|                                |
#   |  "ยืนยันการยกเลิก?"    |                                |
#   |  "จะได้รับคืน: XXX฿"   |                                |
#   |                        |                                |
#   |--ยืนยัน--------------->|                                |
#   |                        |                                |
#   |                        |--อัพเดทสถานะ------------------>|
#   |                        |   UPDATE bookings              |
#   |                        |   SET status='cancelled',      |
#   |                        |   cancelled_at=NOW()           |
#   |                        |                                |
#   |                        |--Process Refund (ถ้ามี)-------->|
#   |                        |                                |
#   |<--แสดงความสำเร็จ-------|                                |
#   |  "ยกเลิกเรียบร้อย"     |                                |
#   |                        |                                |
# ```
#
# ---
#
# ### **Scenario 7: View Promotions**
#
# ```
# Customer                System                          Database
#   |                        |                                |
#   |--เข้าหน้า Promotions-->|                                |
#   |                        |                                |
#   |                        |--ดึง Active Promotions-------->|
#   |                        |   SELECT * FROM promotions     |
#   |                        |   WHERE status = 'active'      |
#   |                        |   AND start_date <= CURDATE()  |
#   |                        |   AND end_date >= CURDATE()    |
#   |                        |                                |
#   |                        |<-------[Promotions]------------|
#   |                        |                                |
#   |<--แสดงรายการ-----------|                                |
#   |  🎉 Daily Promotions  |                                |
#   |  💎 Monthly Deals     |                                |
#   |  ⚡ Flash Sales       |                                |
#   |                        |                                |
#   |--คลิกดูรายละเอียด----->|                                |
#   |                        |                                |
#   |<--แสดงเงื่อนไข---------|                                |
#   |  - ส่วนลด 20%         |                                |
#   |  - จอง min 1,000฿     |                                |
#   |  - Code: SPORT20      |                                |
#   |  - ใช้ได้ถึง: 31/12/25|                                |
#   |                        |                                |
# ```
#
# **[Apply Promotion Code]**
# ```
# Customer                System                          Database
#   |                        |                                |
#   |(ตอนทำ Booking)         |                                |
#   |--กรอก Promo Code------>|                                |
#   |  "SPORT20"             |                                |
#   |                        |                                |
#   |                        |--Validate Code---------------->|
#   |                        |   SELECT * FROM promotions     |
#   |                        |   WHERE promo_code = ?         |
#   |                        |   AND status = 'active'        |
#   |                        |   AND ... (เงื่อนไข)           |
#   |                        |                                |
#   |                        |<-------[valid]-----------------|
#   |                        |                                |
#   |                   [คำนวณส่วนลด]                         |
#   |                   ราคาเดิม: 1,300                       |
#   |                   ลด 20%: -260                          |
#   |                   ราคาสุทธิ: 1,040                      |
#   |                        |                                |
#   |<--แสดงราคาใหม่---------|                                |
#   |  "ใช้โค้ดสำเร็จ ลด 260฿"|                              |
#   |                        |                                |
# ```
#
# ---
#
# ### **Scenario 8: Rate & Review**
#
# ```
# Customer                System                          Database
#   |                        |                                |
#   |--เลือก Booking ที่เสร็จ>|                               |
#   |--กด "Rate & Review"---->|                               |
#   |                        |                                |
#   |<--แสดงฟอร์ม------------|                                |
#   |                        |                                |
#   |--ให้คะแนน (1-5 ⭐)----->|                                |
#   |--เขียน Review--------->|                                |
#   |--แนบรูปภาพ (ถ้ามี)---->|                                |
#   |--กด "Submit"---------->|                                |
#   |                        |                                |
#   |                        |--บันทึก Review---------------->|
#   |                        |   INSERT INTO reviews(         |
#   |                        |   booking_id, field_id,        |
#   |                        |   user_id, rating, comment,    |
#   |                        |   photos, created_at)          |
#   |                        |                                |
#   |                        |--อัพเดท Field Rating---------->|
#   |                        |   UPDATE fields                |
#   |                        |   SET avg_rating = (           |
#   |                        |     SELECT AVG(rating)...)     |
#   |                        |                                |
#   |<--แสดงความสำเร็จ-------|                                |
#   |  "ขอบคุณสำหรับ Review" |                                |
#   |                        |                                |
# ```
#
# ---
#
# ### **Scenario 9: Contact Support**
#
# ```
# Customer                System                          Database
#   |                        |                                |
#   |--เข้าหน้า Contact----->|                                |
#   |                        |                                |
#   |<--แสดงฟอร์ม------------|                                |
#   |  - ประเภทคำถาม        |                                |
#   |  - Booking ID (ถ้ามี)  |                                |
#   |  - รายละเอียด          |                                |
#   |                        |                                |
#   |--กรอกและส่ง----------->|                                |
#   |                        |                                |
#   |                        |--สร้าง Support Ticket--------->|
#   |                        |   INSERT INTO inquiries(       |
#   |                        |   user_id, booking_id,         |
#   |                        |   category, message,           |
#   |                        |   status='pending')            |
#   |                        |                                |
#   |                        |<-------[ticketId]--------------|
#   |                        |                                |
#   |                        |--แจ้ง Booking Staff----------->|
#   |                        |   Send Notification            |
#   |                        |                                |
#   |<--แสดง Ticket Number---|                                |
#   |  "Ticket #12345"       |                                |
#   |  "จะติดต่อกลับภายใน 24ชม."|                            |
#   |                        |                                |
# ```
#
# ---
#
# ### **Scenario 10: Download Receipt**
#
# ```
# Customer                System                          Database
#   |                        |                                |
#   |--เลือก Booking-------->|                                |
#   |--กด "Download Receipt">|                                |
#   |                        |                                |
#   |                        |--ดึงข้อมูลครบถ้วน------------->|
#   |                        |   SELECT b.*, p.*, f.*,        |
#   |                        |   u.*, e.*                     |
#   |                        |   FROM bookings b              |
#   |                        |   JOIN payments p, fields f,   |
#   |                        |   users u                      |
#   |                        |   LEFT JOIN equipment e        |
#   |                        |                                |
#   |                        |<-------[complete data]---------|
#   |                        |                                |
#   |                   [สร้าง Receipt PDF]                  |
#   |                   - หัวบริษัท                          |
#   |                   - เลขที่ Receipt                     |
#   |                   - รายการสนาม + อุปกรณ์                |
#   |                   - ภาษี (VAT)                         |
#   |                   - ยอดรวม                              |
#   |                   - วิธีชำระเงิน                       |
#   |                   - QR Code (สำหรับตรวจสอบ)            |
#   |                        |                                |
#   |<--ดาวน์โหลด PDF--------|                                |
#   |                        |                                |
# ```
#
# ---
#
# ### **Alternative Flows**
#
# **[Error: No Available Time Slot]**
# ```
# Customer ----เลือกเวลา----> System
#                              |
#                         ตรวจสอบ Database
#                              |
#                         [Fully Booked]
#                              |
#                         แสดง Alternative Slots
#                         "เวลานี้เต็มแล้ว"
#                         "ลองช่วงเวลาอื่น?"
# ```
#
# **[Error: Payment Failed]**
# ```
# Payment Gateway ----Failed----> System
#                                  |
#                             Hold Booking (15 min)
#                                  |
#                             Show Error + Retry Options
#                             "การชำระล้มเหลว"
#                             "ลองใหม่หรือเปลี่ยนวิธีชำระ?"
# ```
#
# **[Warning: Late Cancellation]**
# ```
# Customer ----Cancel (< 6h)----> System
#                                  |
#                             Check Policy
#                                  |
#                             Show Warning
#                             "ยกเลิกสายเกินไป"
#                             "ไม่สามารถคืนเงินได้"
#                                  |
#                             Confirm?
# ```
#
# ---
#
# ### **สรุป Key Points**
# - ✅ Browse fields พร้อม search & filter
# - ✅ Complete booking flow (select→book→pay)
# - ✅ Payment integration พร้อม multiple methods
# - ✅ Order tracking สำหรับ equipment delivery
# - ✅ Booking history management
# - ✅ Cancellation พร้อม refund policy
# - ✅ Promotion code system
# - ✅ Rating & review functionality
# - ✅ Customer support (inquiry/ticket system)
# - ✅ Receipt generation & download
# - ✅ Real-time notifications
# - ✅ Responsive error handling

# %% [markdown]
# # ตัวอย่าง Activity จากโปรเจคอื่น

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ---
#
# ## 📊 Activity Diagram: UCD-001 (Login System)
#
# ```
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                   Activity Diagram: UCD-001 Login System                │
# ├────────────────────────────────┬────────────────────────────────────────┤
# │            User                │         Computer System                │
# ├────────────────────────────────┼────────────────────────────────────────┤
# │                                │                                        │
# │          ⚪ START               │                                        │
# │             ↓                  │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ เปิดหน้า Register/Login │──┼─→ ┌──────────────────────────────┐    │
# │  │ หรือ Forgot Password    │  │   │ แสดงหน้าตามที่เลือก           │    │
# │  └─────────────────────────┘  │   └──────────────────────────────┘    │
# │             ↓                  │                ↓                       │
# │  ┌─────────────────────────┐  │   ┌──────────────────────────────┐    │
# │  │ กรอกข้อมูล Email,       │  │   │ รอรับข้อมูล                  │    │
# │  │ Password (และข้อมูลอื่น  │  │   │                              │    │
# │  │ ถ้า Register)            │  │   │                              │    │
# │  └─────────────────────────┘  │   └──────────────────────────────┘    │
# │             ↓                  │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ กดปุ่ม Submit           │──┼─→ ┌──────────────────────────────┐    │
# │  │ (Register/Login/        │  │   │ ตรวจสอบ Email ใน Database    │    │
# │  │  Forgot Password)       │  │   │ SELECT * FROM users          │    │
# │  └─────────────────────────┘  │   │ WHERE email = ?              │    │
# │                                │   └──────────────────────────────┘    │
# │                                │                ↓                       │
# │                                │   ┌──────────────────────────────┐    │
# │                                │   │ [Decision]                   │    │
# │                                │   │ Action Type?                 │    │
# │                                │   └──────────────────────────────┘    │
# │                                │         /      |        \              │
# │                                │   Register   Login   Forgot            │
# │                                │      ↓         ↓         ↓             │
# │            ─── REGISTER PATH ───────────────────────────────────        │
# │                                │   ┌──────────────────────────────┐    │
# │                                │   │ [Decision]                   │    │
# │                                │   │ Email มีอยู่แล้ว?            │    │
# │                                │   └──────────────────────────────┘    │
# │                                │         /              \               │
# │                                │       YES               NO              │
# │                                │        ↓                ↓              │
# │  ┌─────────────────────────┐  │   ┌─────────┐   ┌─────────────────┐   │
# │  │ แสดง Error:             │←─┼───│ Error   │   │ Hash Password   │   │
# │  │ "Email นี้มีในระบบแล้ว"  │  │   │ Message │   │ (BCrypt)        │   │
# │  └─────────────────────────┘  │   └─────────┘   └─────────────────┘   │
# │                                │                          ↓             │
# │                                │                 ┌─────────────────┐   │
# │                                │                 │ INSERT INTO     │   │
# │                                │                 │ users (...)     │   │
# │                                │                 └─────────────────┘   │
# │                                │                          ↓             │
# │                                │                 ┌─────────────────┐   │
# │                                │                 │ ส่ง Verification│   │
# │                                │                 │ Email           │   │
# │                                │                 └─────────────────┘   │
# │  ┌─────────────────────────┐  │                          ↓             │
# │  │ แสดง Success:           │←─┼───────────────┌─────────────────┐     │
# │  │ "ลงทะเบียนสำเร็จ        │  │               │ Success         │     │
# │  │  กรุณาตรวจสอบ Email"    │  │               └─────────────────┘     │
# │  └─────────────────────────┘  │                                        │
# │                                │                                        │
# │            ─── LOGIN PATH ──────────────────────────────────────        │
# │                                │   ┌──────────────────────────────┐    │
# │                                │   │ [Decision]                   │    │
# │                                │   │ User พบ?                     │    │
# │                                │   └──────────────────────────────┘    │
# │                                │         /              \               │
# │                                │       YES               NO              │
# │  ┌─────────────────────────┐  │        ↓                ↓              │
# │  │ แสดง Error:             │←─┼───────────────────┌─────────┐          │
# │  │ "ไม่พบ Email นี้         │  │                   │ Error   │          │
# │  │  ในระบบ"                │  │                   └─────────┘          │
# │  └─────────────────────────┘  │   ┌──────────────────────────────┐    │
# │                                │   │ ตรวจสอบ Password             │    │
# │                                │   │ BCrypt.compare(input, hash)  │    │
# │                                │   └──────────────────────────────┘    │
# │                                │                ↓                       │
# │                                │   ┌──────────────────────────────┐    │
# │                                │   │ [Decision]                   │    │
# │                                │   │ Password ถูกต้อง?            │    │
# │                                │   └──────────────────────────────┘    │
# │                                │         /              \               │
# │                                │       YES               NO              │
# │                                │        ↓                ↓              │
# │                                │   ┌─────────┐   ┌─────────────────┐   │
# │                                │   │ Check   │   │ Failed Count++  │   │
# │                                │   │ Status  │   └─────────────────┘   │
# │                                │   └─────────┘            ↓             │
# │                                │        ↓        ┌─────────────────┐   │
# │                                │   ┌─────────┐   │ [Decision]      │   │
# │                                │   │[Decision]   │ Failed >= 5?    │   │
# │                                │   │Verified?│   └─────────────────┘   │
# │                                │   └─────────┘       /        \         │
# │                                │     /    \        YES         NO        │
# │                                │   YES     NO       ↓          ↓        │
# │  ┌─────────────────────────┐  │    ↓      ↓   ┌────────┐ ┌────────┐   │
# │  │ Redirect ตาม Role:      │←─┼─┐ │      │   │Lock Acc││Error:  │   │
# │  │ - Admin Dashboard       │  │ │ │      │   └────────┘│Wrong   │   │
# │  │ - Staff Dashboard       │  │ │ │      │              │Pass    │   │
# │  │ - Customer Dashboard    │  │ │ │      │              └────────┘   │
# │  └─────────────────────────┘  │ │ │      │                  ↓         │
# │                                │ │ │      ↓                            │
# │                                │ │ │ ┌────────────────────────────┐   │
# │                                │ │ │ │ Redirect to Email Verify   │   │
# │                                │ │ │ │ Page                       │   │
# │                                │ │ │ └────────────────────────────┘   │
# │  ┌─────────────────────────┐  │ │ │                ↓                   │
# │  │ แสดง "กรุณา Verify      │←─┼─┘ │ ┌────────────────────────────┐   │
# │  │  Email ก่อน"            │  │   │ │ Create Session             │   │
# │  └─────────────────────────┘  │   │ │ SET session_id, user_id    │   │
# │                                │   │ └────────────────────────────┘   │
# │                                │   │              ↓                     │
# │                                │   │ ┌────────────────────────────┐   │
# │                                │   │ │ Get User Role              │   │
# │                                │   │ └────────────────────────────┘   │
# │                                │   │              ↓                     │
# │                                │   │ ┌────────────────────────────┐   │
# │                                │   │ │ [Decision] Role?           │   │
# │                                │   │ │ Admin/Staff/Customer       │   │
# │                                │   │ └────────────────────────────┘   │
# │                                │   │         / | \                     │
# │                                │   └────────────┘                       │
# │                                │                                        │
# │            ─── FORGOT PASSWORD PATH ────────────────────────────        │
# │                                │   ┌──────────────────────────────┐    │
# │                                │   │ [Decision]                   │    │
# │                                │   │ Email พบ?                    │    │
# │                                │   └──────────────────────────────┘    │
# │                                │         /              \               │
# │                                │       YES               NO              │
# │  ┌─────────────────────────┐  │        ↓                ↓              │
# │  │ แสดง Success           │←─┼───────────────────┌─────────┐          │
# │  │ (Security: ไม่บอกว่า    │  │                   │ Success │          │
# │  │  มีหรือไม่มี Email)     │  │                   │(Fake)   │          │
# │  └─────────────────────────┘  │                   └─────────┘          │
# │                                │   ┌──────────────────────────────┐    │
# │                                │   │ Check User Role              │    │
# │                                │   └──────────────────────────────┘    │
# │                                │                ↓                       │
# │                                │   ┌──────────────────────────────┐    │
# │                                │   │ [Decision]                   │    │
# │                                │   │ Customer หรือ Staff?         │    │
# │                                │   └──────────────────────────────┘    │
# │                                │         /              \               │
# │                                │    Customer           Staff            │
# │                                │        ↓                ↓              │
# │                                │   ┌─────────┐   ┌─────────────────┐   │
# │                                │   │ Generate│   │ Create Request  │   │
# │                                │   │ Token   │   │ for Admin       │   │
# │                                │   │(UUID+   │   └─────────────────┘   │
# │                                │   │ Hash)   │            ↓             │
# │                                │   └─────────┘   ┌─────────────────┐   │
# │                                │        ↓        │ INSERT INTO     │   │
# │                                │   ┌─────────┐   │ password_       │   │
# │                                │   │ Save to │   │ requests        │   │
# │                                │   │password_│   └─────────────────┘   │
# │                                │   │ resets  │            ↓             │
# │                                │   └─────────┘   ┌─────────────────┐   │
# │                                │        ↓        │ Notify Admin    │   │
# │                                │   ┌─────────┐   └─────────────────┘   │
# │                                │   │ Send    │            ↓             │
# │                                │   │ Email   │   ┌─────────────────┐   │
# │                                │   │ with    │   │ Success         │   │
# │                                │   │ Reset   │   └─────────────────┘   │
# │                                │   │ Link    │                          │
# │                                │   └─────────┘                          │
# │  ┌─────────────────────────┐  │        ↓                ↓              │
# │  │ แสดง:                   │←─┼────────┴────────────────┘              │
# │  │ "ตรวจสอบ Email" หรือ     │  │                                        │
# │  │ "รอ Admin อนุมัติ"       │  │                                        │
# │  └─────────────────────────┘  │                                        │
# │             ↓                  │                                        │
# │          ⚫ END                 │                                        │
# │                                │                                        │
# └────────────────────────────────┴────────────────────────────────────────┘
# ```
#
# ---
#
# ### **สรุป Activity Diagram UCD-001**
# ✅ **Swimlane แบ่ง 2 คอลัมน์:**
# - **User:** กิจกรรมที่ผู้ใช้ทำ
# - **Computer System:** กระบวนการที่ระบบประมวลผล
#
# ✅ **3 Main Paths:**
# 1. **Register Path:** ตรวจสอบ Email ซ้ำ → Hash Password → บันทึก DB → ส่ง Verification Email
# 2. **Login Path:** ค้นหา User → ตรวจสอบ Password → นับ Failed attempts → Lock Account (ถ้า >= 5) → ตรวจสอบ Email Verified → Create Session → Redirect ตาม Role
# 3. **Forgot Password Path:** ตรวจสอบ Email → แยกตาม Role (Customer: ส่ง Reset Link / Staff: สร้าง Request รอ Admin)
#
# ✅ **Decision Points:**
# - Action Type? (Register/Login/Forgot)
# - Email มีอยู่แล้ว? (Register)
# - User พบ? (Login)
# - Password ถูกต้อง?
# - Failed >= 5?
# - Email Verified?
# - Role? (Admin/Staff/Customer)
# - Customer หรือ Staff? (Forgot Password)

# %% [markdown]
# ---
#
# ## 📊 Activity Diagram: UCD-002 (System Administrator)
#
# ```
# ┌─────────────────────────────────────────────────────────────────────────┐
# │              Activity Diagram: UCD-002 System Administrator             │
# ├────────────────────────────────┬────────────────────────────────────────┤
# │       Admin                    │         Computer System                │
# ├────────────────────────────────┼────────────────────────────────────────┤
# │                                │                                        │
# │          ⚪ START               │                                        │
# │             ↓                  │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ เข้าสู่ระบบ Admin        │──┼─→ ┌──────────────────────────────┐    │
# │  └─────────────────────────┘  │   │ ตรวจสอบ Role = 'admin'       │    │
# │             ↓                  │   └──────────────────────────────┘    │
# │  ┌─────────────────────────┐  │                ↓                       │
# │  │ เลือกเมนูการจัดการ       │──┼─→ ┌──────────────────────────────┐    │
# │  │ - User Management       │  │   │ แสดงหน้าตามที่เลือก           │    │
# │  │ - Field Management      │  │   └──────────────────────────────┘    │
# │  │ - Booking View          │  │                                        │
# │  │ - Data Control          │  │                                        │
# │  │ - Security              │  │                                        │
# │  └─────────────────────────┘  │                                        │
# │             ↓                  │                                        │
# │                                │                                        │
# │      ─── USER MANAGEMENT ───                                           │
# │                                │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ เลือก Action:           │──┼─→ ┌──────────────────────────────┐    │
# │  │ - Add User              │  │   │ [Decision] User Action?      │    │
# │  │ - Edit User             │  │   └──────────────────────────────┘    │
# │  │ - Delete User           │  │         /    |    |    |    \          │
# │  │ - View Users            │  │      Add  Edit  Del  View  Role        │
# │  │ - Assign Role           │  │                                        │
# │  └─────────────────────────┘  │                                        │
# │             ↓                  │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ กรอกข้อมูล User          │──┼─→ ┌──────────────────────────────┐    │
# │  │ (สำหรับ Add/Edit)        │  │   │ ตรวจสอบ Email ใน Database    │    │
# │  └─────────────────────────┘  │   │ SELECT * FROM users          │    │
# │             ↓                  │   │ WHERE email = ?              │    │
# │  ┌─────────────────────────┐  │   └──────────────────────────────┘    │
# │  │ กดปุ่ม Submit           │──┼─→          ↓                           │
# │  └─────────────────────────┘  │   ┌──────────────────────────────┐    │
# │                                │   │ [Decision]                   │    │
# │                                │   │ Email มีอยู่แล้ว?            │    │
# │                                │   │ (สำหรับ Add/Edit)            │    │
# │                                │   └──────────────────────────────┘    │
# │                                │         /              \               │
# │                                │       YES               NO              │
# │  ┌─────────────────────────┐  │        ↓                ↓              │
# │  │ แสดง Error:             │←─┼───┌─────────┐   ┌─────────────────┐   │
# │  │ "Email ซ้ำ"              │  │   │ Error   │   │ Hash Password   │   │
# │  └─────────────────────────┘  │   │ Message │   │ (ถ้าเปลี่ยน)     │   │
# │                                │   └─────────┘   └─────────────────┘   │
# │                                │                          ↓             │
# │                                │                 ┌─────────────────┐   │
# │                                │                 │ INSERT/UPDATE   │   │
# │                                │                 │ users Table     │   │
# │                                │                 └─────────────────┘   │
# │                                │                          ↓             │
# │                                │                 ┌─────────────────┐   │
# │                                │                 │ ส่ง Email แจ้ง  │   │
# │                                │                 │ User (ถ้าเปลี่ยน │   │
# │                                │                 │ Email/Password) │   │
# │  ┌─────────────────────────┐  │                 └─────────────────┘   │
# │  │ แสดง Success:           │←─┼──────────┌──────────────────────┐     │
# │  │ "บันทึกข้อมูลสำเร็จ"     │  │          │ Success              │     │
# │  └─────────────────────────┘  │          └──────────────────────┘     │
# │                                │                                        │
# │      ─── FIELD MANAGEMENT ───                                          │
# │                                │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ เลือก Action:           │──┼─→ ┌──────────────────────────────┐    │
# │  │ - Add Field             │  │   │ [Decision] Field Action?     │    │
# │  │ - Edit Field            │  │   └──────────────────────────────┘    │
# │  │ - Delete Field          │  │         /         |         \          │
# │  └─────────────────────────┘  │       Add       Edit       Delete      │
# │             ↓                  │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ กรอกข้อมูล Field         │──┼─→ ┌──────────────────────────────┐    │
# │  │ - Field Name            │  │   │ รับข้อมูล Field              │    │
# │  │ - Type, Price           │  │   └──────────────────────────────┘    │
# │  │ - Facilities            │  │                ↓                       │
# │  │ - Photos                │  │   ┌──────────────────────────────┐    │
# │  └─────────────────────────┘  │   │ [Decision] Delete Field?     │    │
# │             ↓                  │   └──────────────────────────────┘    │
# │  ┌─────────────────────────┐  │         /              \               │
# │  │ กดปุ่ม Submit           │──┼─→     YES               NO              │
# │  └─────────────────────────┘  │        ↓                ↓              │
# │                                │   ┌──────────┐   ┌─────────────────┐  │
# │                                │   │ Check    │   │ INSERT/UPDATE   │  │
# │                                │   │ Bookings │   │ fields Table    │  │
# │                                │   │ Using    │   └─────────────────┘  │
# │                                │   │ Field    │            ↓            │
# │                                │   └──────────┘   ┌─────────────────┐  │
# │                                │        ↓         │ Upload Photos   │  │
# │                                │   ┌──────────┐   │ (ถ้ามี)          │  │
# │                                │   │[Decision]│   └─────────────────┘  │
# │                                │   │Has Deps? │            ↓            │
# │                                │   └──────────┘   ┌─────────────────┐  │
# │                                │     /      \     │ Success         │  │
# │                                │   YES       NO    └─────────────────┘  │
# │                                │    ↓        ↓                          │
# │                                │  ┌────┐  ┌────┐                       │
# │                                │  │Soft│  │Hard│                       │
# │                                │  │Del │  │Del │                       │
# │  ┌─────────────────────────┐  │  └────┘  └────┘                       │
# │  │ แสดง Success            │←─┼────┴────────┘                          │
# │  └─────────────────────────┘  │                                        │
# │                                │                                        │
# │      ─── DATA CONTROL ───                                              │
# │                                │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ เลือก Action:           │──┼─→ ┌──────────────────────────────┐    │
# │  │ - Backup Database       │  │   │ [Decision] Data Action?      │    │
# │  │ - Restore Database      │  │   └──────────────────────────────┘    │
# │  │ - Delete Old Data       │  │         /         |         \          │
# │  └─────────────────────────┘  │     Backup    Restore    Delete        │
# │             ↓                  │        ↓          ↓          ↓         │
# │  ┌─────────────────────────┐  │   ┌────────┐ ┌────────┐ ┌────────┐   │
# │  │ ยืนยันการทำงาน          │──┼─→ │Execute │ │Restore │ │Delete  │   │
# │  │ (Confirmation Dialog)   │  │   │mysqldmp│ │from    │ │WHERE   │   │
# │  └─────────────────────────┘  │   │        │ │Backup  │ │date<   │   │
# │             ↓                  │   └────────┘ └────────┘ └────────┘   │
# │                                │        ↓          ↓          ↓         │
# │                                │   ┌──────────────────────────────┐    │
# │                                │   │ [Decision] Success?          │    │
# │                                │   └──────────────────────────────┘    │
# │                                │         /              \               │
# │                                │       YES               NO              │
# │  ┌─────────────────────────┐  │        ↓                ↓              │
# │  │ แสดง Success/Error      │←─┼───┌─────────┐   ┌─────────────────┐   │
# │  │ พร้อมรายละเอียด          │  │   │ Success │   │ Error + Log     │   │
# │  └─────────────────────────┘  │   └─────────┘   └─────────────────┘   │
# │                                │                                        │
# │      ─── SECURITY MANAGEMENT ───                                       │
# │                                │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ เลือก Action:           │──┼─→ ┌──────────────────────────────┐    │
# │  │ - View Access Logs      │  │   │ [Decision] Security Action?  │    │
# │  │ - Reset User Password   │  │   └──────────────────────────────┘    │
# │  └─────────────────────────┘  │         /              \               │
# │             ↓                  │      Logs          Reset Pass          │
# │  ┌─────────────────────────┐  │        ↓                ↓              │
# │  │ กรอก Filter (Logs)       │──┼─→ ┌──────────┐   ┌─────────────────┐  │
# │  │ หรือ เลือก User (Reset)  │  │   │ SELECT   │   │ เลือก User       │  │
# │  └─────────────────────────┘  │   │ FROM     │   │ ที่ต้องการ Reset │  │
# │             ↓                  │   │ access_  │   └─────────────────┘  │
# │  ┌─────────────────────────┐  │   │ logs     │            ↓            │
# │  │ ดูรายงาน / ยืนยัน Reset  │──┼─→ │ WHERE... │   ┌─────────────────┐  │
# │  └─────────────────────────┘  │   └──────────┘   │ Generate Temp   │  │
# │                                │        ↓         │ Password        │  │
# │                                │   ┌──────────┐   └─────────────────┘  │
# │                                │   │ Export   │            ↓            │
# │                                │   │ to Excel │   ┌─────────────────┐  │
# │                                │   │ /CSV     │   │ UPDATE users    │  │
# │                                │   └──────────┘   │ SET password    │  │
# │                                │        ↓         └─────────────────┘  │
# │                                │   ┌──────────┐            ↓            │
# │                                │   │ Success  │   ┌─────────────────┐  │
# │  ┌─────────────────────────┐  │   └──────────┘   │ Send Email      │  │
# │  │ แสดงรายงาน / Success    │←─┼────────┴─────────│ with Temp Pass  │  │
# │  └─────────────────────────┘  │                  └─────────────────┘  │
# │             ↓                  │                           ↓            │
# │          ⚫ END                 │                      Success           │
# │                                │                                        │
# └────────────────────────────────┴────────────────────────────────────────┘
# ```
#
# ---
#
# ### **สรุป Activity Diagram UCD-002**
# ✅ **5 กระบวนการหลัก:**
# 1. **User Management:** CRUD Users + Assign Roles + Email Notification
# 2. **Field Management:** CRUD Fields + Soft/Hard Delete ตาม Dependencies
# 3. **Booking View:** Filter & View Bookings
# 4. **Data Control:** Backup/Restore/Delete Database
# 5. **Security:** View Access Logs + Reset Password
#
# ✅ **Decision Points:**
# - User Action? (Add/Edit/Delete/View/Role)
# - Email ซ้ำ?
# - Field Action? (Add/Edit/Delete)
# - Has Dependencies? (Soft Delete vs Hard Delete)
# - Data Action? (Backup/Restore/Delete)
# - Success?
# - Security Action? (Logs/Reset Password)

# %% [markdown]
# ---
#
# ## 📊 Activity Diagram: UCD-003 (Booking Staff Operations)
#
# ```
# ┌─────────────────────────────────────────────────────────────────────────┐
# │            Activity Diagram: UCD-003 Booking Staff Operations           │
# ├────────────────────────────────┬────────────────────────────────────────┤
# │      Booking Staff             │         Computer System                │
# ├────────────────────────────────┼────────────────────────────────────────┤
# │                                │                                        │
# │          ⚪ START               │                                        │
# │             ↓                  │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ เข้าสู่ระบบ Staff        │──┼─→ ┌──────────────────────────────┐    │
# │  └─────────────────────────┘  │   │ ตรวจสอบ Role = 'staff'       │    │
# │             ↓                  │   └──────────────────────────────┘    │
# │  ┌─────────────────────────┐  │                ↓                       │
# │  │ เลือกเมนูการทำงาน:       │──┼─→ ┌──────────────────────────────┐    │
# │  │ - Create/Edit Booking   │  │   │ แสดงหน้าตามที่เลือก           │    │
# │  │ - Approve Booking       │  │   └──────────────────────────────┘    │
# │  │ - Payment Processing    │  │                                        │
# │  │ - Delivery Tracking     │  │                                        │
# │  │ - Customer Support      │  │                                        │
# │  └─────────────────────────┘  │                                        │
# │             ↓                  │                                        │
# │                                │                                        │
# │      ─── CREATE/EDIT BOOKING ───                                       │
# │                                │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ เลือก Create หรือ Edit  │──┼─→ ┌──────────────────────────────┐    │
# │  └─────────────────────────┘  │   │ [Decision] Create/Edit?      │    │
# │             ↓                  │   └──────────────────────────────┘    │
# │  ┌─────────────────────────┐  │         /              \               │
# │  │ เลือก Field             │──┼─→   Create            Edit             │
# │  │ เลือกวันที่และเวลา       │  │        ↓                ↓              │
# │  └─────────────────────────┘  │   ┌──────────┐   ┌─────────────────┐  │
# │             ↓                  │   │ Check    │   │ Load Booking    │  │
# │  ┌─────────────────────────┐  │   │ Field    │   │ Details         │  │
# │  │ เลือกอุปกรณ์ (ถ้าต้องการ)│──┼─→ │ Availab. │   └─────────────────┘  │
# │  └─────────────────────────┘  │   │ SELECT * │            ↓            │
# │             ↓                  │   │ FROM bkg │   ┌─────────────────┐  │
# │  ┌─────────────────────────┐  │   │ WHERE... │   │ แก้ไขข้อมูล      │  │
# │  │ ดูสรุปและราคา            │──┼─→ └──────────┘   └─────────────────┘  │
# │  └─────────────────────────┘  │        ↓                ↓              │
# │             ↓                  │   ┌──────────────────────────────┐    │
# │  ┌─────────────────────────┐  │   │ [Decision]                   │    │
# │  │ กดยืนยัน Booking         │──┼─→ │ Field Available?             │    │
# │  └─────────────────────────┘  │   └──────────────────────────────┘    │
# │                                │         /              \               │
# │                                │       YES               NO              │
# │                                │        ↓                ↓              │
# │                                │   ┌──────────┐   ┌─────────────────┐  │
# │                                │   │ คำนวณ    │   │ Error: Field    │  │
# │                                │   │ ราคารวม  │   │ Not Available   │  │
# │                                │   └──────────┘   └─────────────────┘  │
# │                                │        ↓                ↓              │
# │                                │   ┌──────────────────────────────┐    │
# │                                │   │ INSERT/UPDATE bookings       │    │
# │                                │   └──────────────────────────────┘    │
# │                                │                ↓                       │
# │                                │   ┌──────────────────────────────┐    │
# │                                │   │ [Decision] มีอุปกรณ์?         │    │
# │                                │   └──────────────────────────────┘    │
# │                                │         /              \               │
# │                                │       YES               NO              │
# │                                │        ↓                ↓              │
# │                                │   ┌──────────┐     Skip to Success     │
# │                                │   │ Generate │                         │
# │                                │   │ Order ID │                         │
# │                                │   └──────────┘                         │
# │                                │        ↓                               │
# │                                │   ┌──────────────────────────────┐    │
# │                                │   │ ส่งข้อมูลไป Logistic System  │    │
# │                                │   │ POST /api/orders             │    │
# │  ┌─────────────────────────┐  │   └──────────────────────────────┘    │
# │  │ แสดง Success            │←─┼──────────┌──────────────────────┐     │
# │  │ พร้อม Booking ID        │  │          │ Success              │     │
# │  └─────────────────────────┘  │          └──────────────────────┘     │
# │                                │                                        │
# │      ─── APPROVE/REJECT BOOKING ───                                    │
# │                                │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ ดูรายการ Pending         │──┼─→ ┌──────────────────────────────┐    │
# │  │ Bookings                │  │   │ SELECT * FROM bookings       │    │
# │  └─────────────────────────┘  │   │ WHERE status='pending'       │    │
# │             ↓                  │   └──────────────────────────────┘    │
# │  ┌─────────────────────────┐  │                ↓                       │
# │  │ เลือก Booking           │──┼─→ ┌──────────────────────────────┐    │
# │  │ ที่ต้องการพิจารณา        │  │   │ แสดงรายละเอียด Booking       │    │
# │  └─────────────────────────┘  │   └──────────────────────────────┘    │
# │             ↓                  │                ↓                       │
# │  ┌─────────────────────────┐  │                                        │
# │  │ เลือก Approve หรือ      │──┼─→ ┌──────────────────────────────┐    │
# │  │ Reject                  │  │   │ [Decision] Approve/Reject?   │    │
# │  └─────────────────────────┘  │   └──────────────────────────────┘    │
# │             ↓                  │         /              \               │
# │  ┌─────────────────────────┐  │    Approve           Reject             │
# │  │ ใส่เหตุผล (ถ้า Reject)  │──┼─→      ↓                ↓              │
# │  └─────────────────────────┘  │   ┌──────────┐   ┌─────────────────┐  │
# │             ↓                  │   │ Check    │   │ ต้องใส่เหตุผล    │  │
# │  ┌─────────────────────────┐  │   │ Field    │   │ (reason)        │  │
# │  │ ยืนยันการทำงาน          │──┼─→ │ Availab. │   └─────────────────┘  │
# │  └─────────────────────────┘  │   │ อีกครั้ง  │            ↓            │
# │                                │   └──────────┘   ┌─────────────────┐  │
# │                                │        ↓         │ UPDATE bookings │  │
# │                                │   ┌──────────┐   │ SET status=     │  │
# │                                │   │ UPDATE   │   │ 'rejected',     │  │
# │                                │   │ bookings │   │ reason=?        │  │
# │                                │   │ SET      │   └─────────────────┘  │
# │                                │   │ status=  │            ↓            │
# │                                │   │'approved'│   ┌─────────────────┐  │
# │                                │   └──────────┘   │ Notify Customer │  │
# │                                │        ↓         └─────────────────┘  │
# │                                │   ┌──────────────────────────────┐    │
# │                                │   │ Notify Customer (Email/SMS)  │    │
# │  ┌─────────────────────────┐  │   └──────────────────────────────┘    │
# │  │ แสดง Success            │←─┼──────────┌──────────────────────┐     │
# │  └─────────────────────────┘  │          │ Success              │     │
# │                                │          └──────────────────────┘     │
# │                                │                                        │
# │      ─── PAYMENT PROCESSING ───                                        │
# │                                │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ เลือก Booking           │──┼─→ ┌──────────────────────────────┐    │
# │  │ ที่ต้องการตรวจสอบ        │  │   │ SELECT booking details       │    │
# │  └─────────────────────────┘  │   └──────────────────────────────┘    │
# │             ↓                  │                ↓                       │
# │  ┌─────────────────────────┐  │   ┌──────────────────────────────┐    │
# │  │ ตรวจสอบหลักฐานการชำระ    │──┼─→ │ ดึงข้อมูลจาก Payment Gateway │    │
# │  │ (Slip/QR Code)          │  │   │ GET /api/payment/verify      │    │
# │  └─────────────────────────┘  │   └──────────────────────────────┘    │
# │             ↓                  │                ↓                       │
# │  ┌─────────────────────────┐  │   ┌──────────────────────────────┐    │
# │  │ ยืนยันการชำระเงิน        │──┼─→ │ [Decision] Payment Valid?    │    │
# │  └─────────────────────────┘  │   └──────────────────────────────┘    │
# │                                │         /              \               │
# │                                │       YES               NO              │
# │                                │        ↓                ↓              │
# │                                │   ┌──────────┐   ┌─────────────────┐  │
# │                                │   │ UPDATE   │   │ Error:          │  │
# │                                │   │ bookings │   │ Payment Invalid │  │
# │                                │   │ payments │   │ ต้องชำระใหม่    │  │
# │                                │   └──────────┘   └─────────────────┘  │
# │  ┌─────────────────────────┐  │        ↓                               │
# │  │ แสดง Success/Error      │←─┼────────┴────────────────────          │
# │  └─────────────────────────┘  │                                        │
# │                                │                                        │
# │      ─── DELIVERY TRACKING ───                                         │
# │                                │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ ใส่ Tracking Number      │──┼─→ ┌──────────────────────────────┐    │
# │  └─────────────────────────┘  │   │ Query Logistic System        │    │
# │             ↓                  │   │ GET /api/tracking/{id}       │    │
# │  ┌─────────────────────────┐  │   └──────────────────────────────┘    │
# │  │ กด "Track"              │──┼─→          ↓                           │
# │  └─────────────────────────┘  │   ┌──────────────────────────────┐    │
# │                                │   │ รับข้อมูล Status, Location   │    │
# │                                │   └──────────────────────────────┘    │
# │  ┌─────────────────────────┐  │                ↓                       │
# │  │ ดูสถานะการส่ง:          │←─┼───┌──────────────────────────────┐    │
# │  │ - Processing            │  │   │ แสดงสถานะ:                   │    │
# │  │ - In-Transit            │  │   │ - Processing                 │    │
# │  │ - Delivered             │  │   │ - In-Transit                 │    │
# │  └─────────────────────────┘  │   │ - Delivered                  │    │
# │                                │   │ - Delayed (ถ้ามี)             │    │
# │                                │   └──────────────────────────────┘    │
# │                                │                ↓                       │
# │                                │   ┌──────────────────────────────┐    │
# │                                │   │ [Decision] Delayed?          │    │
# │                                │   └──────────────────────────────┘    │
# │                                │         /              \               │
# │                                │       YES               NO              │
# │                                │        ↓                ↓              │
# │                                │   ┌──────────┐     Skip               │
# │                                │   │ Notify   │                         │
# │                                │   │ Staff &  │                         │
# │                                │   │ Customer │                         │
# │  ┌─────────────────────────┐  │   └──────────┘                         │
# │  │ แจ้งเตือน (ถ้า Delayed) │←─┼────────┘                               │
# │  └─────────────────────────┘  │                                        │
# │                                │                                        │
# │      ─── CUSTOMER SUPPORT ───                                          │
# │                                │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ ดูรายการ Inquiries       │──┼─→ ┌──────────────────────────────┐    │
# │  └─────────────────────────┘  │   │ SELECT * FROM inquiries      │    │
# │             ↓                  │   │ ORDER BY created_at DESC     │    │
# │  ┌─────────────────────────┐  │   └──────────────────────────────┘    │
# │  │ Filter ตามประเภท         │──┼─→ ┌──────────────────────────────┐    │
# │  │ (Booking/Payment/อื่นๆ)  │  │   │ WHERE category = ?           │    │
# │  └─────────────────────────┘  │   └──────────────────────────────┘    │
# │             ↓                  │                ↓                       │
# │  ┌─────────────────────────┐  │   ┌──────────────────────────────┐    │
# │  │ เลือก Inquiry           │──┼─→ │ แสดงรายละเอียด Inquiry        │    │
# │  └─────────────────────────┘  │   └──────────────────────────────┘    │
# │             ↓                  │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ เลือก Action:           │──┼─→ ┌──────────────────────────────┐    │
# │  │ - ตอบกลับ (Reply)        │  │   │ [Decision] Reply/Update?     │    │
# │  │ - อัพเดทสถานะ            │  │   └──────────────────────────────┘    │
# │  └─────────────────────────┘  │         /              \               │
# │             ↓                  │      Reply           Update            │
# │  ┌─────────────────────────┐  │        ↓                ↓              │
# │  │ พิมพ์ข้อความตอบกลับ      │──┼─→ ┌──────────┐   ┌─────────────────┐  │
# │  │ หรือ เปลี่ยนสถานะ        │  │   │ INSERT   │   │ UPDATE          │  │
# │  └─────────────────────────┘  │   │ reply    │   │ inquiries       │  │
# │             ↓                  │   │ message  │   │ SET status=?    │  │
# │  ┌─────────────────────────┐  │   └──────────┘   └─────────────────┘  │
# │  │ กด "Send" / "Update"    │──┼─→      ↓                ↓              │
# │  └─────────────────────────┘  │   ┌──────────────────────────────┐    │
# │                                │   │ Send Email/Notification      │    │
# │                                │   │ to Customer                  │    │
# │  ┌─────────────────────────┐  │   └──────────────────────────────┘    │
# │  │ แสดง Success            │←─┼──────────┌──────────────────────┐     │
# │  └─────────────────────────┘  │          │ Success              │     │
# │             ↓                  │          └──────────────────────┘     │
# │          ⚫ END                 │                                        │
# │                                │                                        │
# └────────────────────────────────┴────────────────────────────────────────┘
# ```
#
# ---
#
# ### **สรุป Activity Diagram UCD-003**
# ✅ **6 กระบวนการหลัก:**
# 1. **Create/Edit Booking:** ตรวจสอบ Field Available → คำนวณราคา → สร้าง Order (ถ้ามีอุปกรณ์) → บันทึก
# 2. **Approve/Reject Booking:** ดู Pending → Approve (ตรวจสอบว่าง) / Reject (ใส่เหตุผล) → แจ้งเตือน Customer
# 3. **Payment Processing:** ตรวจสอบหลักฐาน → Verify กับ Payment Gateway → อัพเดทสถานะ
# 4. **Delivery Tracking:** Query Logistic System → แสดงสถานะ → แจ้งเตือน (ถ้า Delayed)
# 5. **Customer Support:** ดู Inquiries → Reply/Update Status → แจ้งเตือน Customer

# %% [markdown]
# ---
#
# ## 📊 Activity Diagram: UCD-004 (Accounting Staff)
#
# ```
# ┌─────────────────────────────────────────────────────────────────────────┐
# │              Activity Diagram: UCD-004 Accounting Staff                 │
# ├────────────────────────────────┬────────────────────────────────────────┤
# │     Accounting Staff           │         Computer System                │
# ├────────────────────────────────┼────────────────────────────────────────┤
# │                                │                                        │
# │          ⚪ START               │                                        │
# │             ↓                  │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ เข้าสู่ระบบ Accounting   │──┼─→ ┌──────────────────────────────┐    │
# │  └─────────────────────────┘  │   │ ตรวจสอบ Role = 'accounting'  │    │
# │             ↓                  │   └──────────────────────────────┘    │
# │  ┌─────────────────────────┐  │                ↓                       │
# │  │ เลือกเมนูการทำงาน:       │──┼─→ ┌──────────────────────────────┐    │
# │  │ - Payment Management    │  │   │ แสดงหน้าตามที่เลือก           │    │
# │  │ - Invoice               │  │   └──────────────────────────────┘    │
# │  │ - Reconciliation        │  │                                        │
# │  │ - Revenue Analytics     │  │                                        │
# │  │ - Financial Reports     │  │                                        │
# │  └─────────────────────────┘  │                                        │
# │             ↓                  │                                        │
# │                                │                                        │
# │      ─── PAYMENT MANAGEMENT ───                                        │
# │                                │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ ดูรายการ Payments        │──┼─→ ┌──────────────────────────────┐    │
# │  │ Filter: Date Range,     │  │   │ SELECT * FROM payments       │    │
# │  │ Status, Method          │  │   │ JOIN bookings                │    │
# │  └─────────────────────────┘  │   │ WHERE date BETWEEN ? AND ?   │    │
# │             ↓                  │   └──────────────────────────────┘    │
# │  ┌─────────────────────────┐  │                ↓                       │
# │  │ เลือก Payment           │──┼─→ ┌──────────────────────────────┐    │
# │  │ ที่ต้องการตรวจสอบ        │  │   │ แสดงรายละเอียด Payment       │    │
# │  └─────────────────────────┘  │   └──────────────────────────────┘    │
# │             ↓                  │                ↓                       │
# │  ┌─────────────────────────┐  │   ┌──────────────────────────────┐    │
# │  │ ตรวจสอบสถานะกับ         │──┼─→ │ Query Payment Gateway        │    │
# │  │ Payment Gateway         │  │   │ GET /api/payment/verify/{id} │    │
# │  └─────────────────────────┘  │   └──────────────────────────────┘    │
# │             ↓                  │                ↓                       │
# │                                │   ┌──────────────────────────────┐    │
# │                                │   │ [Decision]                   │    │
# │                                │   │ Status Match?                │    │
# │                                │   └──────────────────────────────┘    │
# │                                │         /              \               │
# │                                │       YES               NO              │
# │  ┌─────────────────────────┐  │        ↓                ↓              │
# │  │ อัพเดทสถานะ (ถ้าต้องการ)│──┼─→ ┌──────────┐   ┌─────────────────┐  │
# │  └─────────────────────────┘  │   │ Success  │   │ แสดง Mismatch   │  │
# │             ↓                  │   │ Verified │   │ ต้องตรวจสอบ     │  │
# │  ┌─────────────────────────┐  │   └──────────┘   └─────────────────┘  │
# │  │ Process Refund (ถ้าต้องการ)│─┼─→      ↓                ↓            │
# │  └─────────────────────────┘  │   ┌──────────────────────────────┐    │
# │                                │   │ UPDATE payments              │    │
# │                                │   │ SET status = ?               │    │
# │  ┌─────────────────────────┐  │   └──────────────────────────────┘    │
# │  │ แสดง Success/Warning    │←─┼──────────┌──────────────────────┐     │
# │  └─────────────────────────┘  │          │ Success              │     │
# │                                │          └──────────────────────┘     │
# │                                │                                        │
# │      ─── INVOICE GENERATION ───                                        │
# │                                │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ เลือก Booking           │──┼─→ ┌──────────────────────────────┐    │
# │  │ ที่ต้องการออก Invoice    │  │   │ SELECT booking, payment,     │    │
# │  └─────────────────────────┘  │   │ field, equipment details     │    │
# │             ↓                  │   └──────────────────────────────┘    │
# │  ┌─────────────────────────┐  │                ↓                       │
# │  │ ตรวจสอบข้อมูล:          │──┼─→ ┌──────────────────────────────┐    │
# │  │ - Customer Info         │  │   │ แสดงข้อมูลครบถ้วน:           │    │
# │  │ - Booking Details       │  │   │ - ชื่อลูกค้า, Tax ID         │    │
# │  │ - Amount, Tax           │  │   │ - รายการสนาม + อุปกรณ์        │    │
# │  └─────────────────────────┘  │   │ - ยอดรวม, ภาษี VAT 7%       │    │
# │             ↓                  │   └──────────────────────────────┘    │
# │  ┌─────────────────────────┐  │                ↓                       │
# │  │ กด "Generate Invoice"   │──┼─→ ┌──────────────────────────────┐    │
# │  └─────────────────────────┘  │   │ Generate Invoice Number      │    │
# │                                │   │ INV-YYYYMMDD-XXXX            │    │
# │                                │   └──────────────────────────────┘    │
# │                                │                ↓                       │
# │                                │   ┌──────────────────────────────┐    │
# │                                │   │ INSERT INTO invoices         │    │
# │                                │   └──────────────────────────────┘    │
# │                                │                ↓                       │
# │                                │   ┌──────────────────────────────┐    │
# │                                │   │ Generate PDF Invoice         │    │
# │                                │   │ (Template + Data)            │    │
# │  ┌─────────────────────────┐  │   └──────────────────────────────┘    │
# │  │ Download/Print Invoice  │←─┼──────────┌──────────────────────┐     │
# │  └─────────────────────────┘  │          │ Success + PDF        │     │
# │                                │          └──────────────────────┘     │
# │                                │                                        │
# │      ─── RECONCILIATION ───                                            │
# │                                │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ เลือกช่วงเวลา            │──┼─→ ┌──────────────────────────────┐    │
# │  │ (วัน/เดือน)              │  │   │ รับ Date Range               │    │
# │  └─────────────────────────┘  │   └──────────────────────────────┘    │
# │             ↓                  │                ↓                       │
# │  ┌─────────────────────────┐  │   ┌──────────────────────────────┐    │
# │  │ กด "Start Reconciliation"│─┼─→ │ ดึงข้อมูลจาก 2 แหล่ง:        │    │
# │  └─────────────────────────┘  │   │ 1. Database (payments)       │    │
# │                                │   │ 2. Payment Gateway API       │    │
# │                                │   └──────────────────────────────┘    │
# │                                │                ↓                       │
# │                                │   ┌──────────────────────────────┐    │
# │                                │   │ เปรียบเทียบรายการ:            │    │
# │                                │   │ - Transaction ID             │    │
# │                                │   │ - Amount                     │    │
# │                                │   │ - Date/Time                  │    │
# │                                │   └──────────────────────────────┘    │
# │                                │                ↓                       │
# │                                │   ┌──────────────────────────────┐    │
# │                                │   │ [Decision]                   │    │
# │                                │   │ All Match?                   │    │
# │                                │   └──────────────────────────────┘    │
# │                                │         /              \               │
# │                                │       YES               NO              │
# │  ┌─────────────────────────┐  │        ↓                ↓              │
# │  │ ดูรายงาน Reconciliation │←─┼───┌──────────┐   ┌─────────────────┐  │
# │  │ - Matched: X รายการ     │  │   │ Success  │   │ แสดง Mismatch   │  │
# │  │ - Mismatched: Y รายการ  │  │   │ Report   │   │ List            │  │
# │  └─────────────────────────┘  │   └──────────┘   │ ต้องตรวจสอบ     │  │
# │             ↓                  │                  └─────────────────┘  │
# │  ┌─────────────────────────┐  │                           ↓            │
# │  │ ตรวจสอบรายการที่ไม่ตรง   │──┼─→ ┌──────────────────────────────┐    │
# │  │ (ถ้ามี)                  │  │   │ แสดงรายละเอียดที่แตกต่าง      │    │
# │  └─────────────────────────┘  │   └──────────────────────────────┘    │
# │             ↓                  │                ↓                       │
# │  ┌─────────────────────────┐  │   ┌──────────────────────────────┐    │
# │  │ แก้ไข/อัพเดท (ถ้าต้องการ)│─┼─→ │ UPDATE payments              │    │
# │  └─────────────────────────┘  │   │ SET reconciled = true        │    │
# │             ↓                  │   └──────────────────────────────┘    │
# │  ┌─────────────────────────┐  │                ↓                       │
# │  │ Export Report           │──┼─→ ┌──────────────────────────────┐    │
# │  │ (Excel/PDF)             │  │   │ Generate Report File         │    │
# │  └─────────────────────────┘  │   └──────────────────────────────┘    │
# │                                │                ↓                       │
# │                                │          Download File                 │
# │                                │                                        │
# │      ─── REVENUE ANALYTICS ───                                         │
# │                                │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ เลือกประเภทรายงาน:       │──┼─→ ┌──────────────────────────────┐    │
# │  │ - Daily Revenue         │  │   │ [Decision] Report Type?      │    │
# │  │ - Monthly Revenue       │  │   └──────────────────────────────┘    │
# │  │ - Yearly Revenue        │  │         /         |         \          │
# │  └─────────────────────────┘  │      Daily    Monthly    Yearly        │
# │             ↓                  │        ↓          ↓          ↓         │
# │  ┌─────────────────────────┐  │   ┌──────────────────────────────┐    │
# │  │ เลือกช่วงเวลา            │──┼─→ │ SELECT SUM(amount),          │    │
# │  │ และ Filter (ถ้าต้องการ)  │  │   │ DATE_FORMAT(created_at)      │    │
# │  └─────────────────────────┘  │   │ FROM payments                │    │
# │             ↓                  │   │ WHERE status = 'completed'   │    │
# │  ┌─────────────────────────┐  │   │ GROUP BY DATE/MONTH/YEAR     │    │
# │  │ กด "Generate Report"    │──┼─→ └──────────────────────────────┘    │
# │  └─────────────────────────┘  │                ↓                       │
# │                                │   ┌──────────────────────────────┐    │
# │                                │   │ คำนวณ:                        │    │
# │                                │   │ - Total Revenue              │    │
# │                                │   │ - Average per Transaction    │    │
# │                                │   │ - Top Fields by Revenue      │    │
# │                                │   │ - Payment Method Breakdown   │    │
# │  ┌─────────────────────────┐  │   └──────────────────────────────┘    │
# │  │ ดูกราฟและตาราง          │←─┼──────────┌──────────────────────┐     │
# │  │ - Bar Chart             │  │          │ Generate Charts      │     │
# │  │ - Pie Chart             │  │          │ & Tables             │     │
# │  │ - Trend Line            │  │          └──────────────────────┘     │
# │  └─────────────────────────┘  │                                        │
# │             ↓                  │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ Export Report           │──┼─→ ┌──────────────────────────────┐    │
# │  │ (Excel/CSV/PDF)         │  │   │ Export to File               │    │
# │  └─────────────────────────┘  │   └──────────────────────────────┘    │
# │                                │                ↓                       │
# │                                │          Download File                 │
# │                                │                                        │
# │      ─── FINANCIAL REPORTS ───                                         │
# │                                │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ เลือกประเภทรายงาน:       │──┼─→ ┌──────────────────────────────┐    │
# │  │ - Income Statement      │  │   │ [Decision] Report Type?      │    │
# │  │ - Cash Flow             │  │   └──────────────────────────────┘    │
# │  │ - Tax Report            │  │         /         |         \          │
# │  └─────────────────────────┘  │     Income    Cash Flow    Tax         │
# │             ↓                  │        ↓          ↓          ↓         │
# │  ┌─────────────────────────┐  │   ┌──────────────────────────────┐    │
# │  │ กำหนดช่วงเวลา           │──┼─→ │ Query ข้อมูลการเงิน:          │    │
# │  │ (เดือน/ไตรมาส/ปี)        │  │   │ - Revenue (รายรับ)            │    │
# │  └─────────────────────────┘  │   │ - Expenses (รายจ่าย)          │    │
# │             ↓                  │   │ - Tax (ภาษี)                 │    │
# │  ┌─────────────────────────┐  │   │ - Net Income (กำไรสุทธิ)      │    │
# │  │ กด "Generate"           │──┼─→ └──────────────────────────────┘    │
# │  └─────────────────────────┘  │                ↓                       │
# │                                │   ┌──────────────────────────────┐    │
# │                                │   │ สร้างรายงานตามมาตรฐาน:        │    │
# │                                │   │ - รายรับ - รายจ่าย = กำไร     │    │
# │                                │   │ - คำนวณ VAT 7%               │    │
# │  ┌─────────────────────────┐  │   │ - แยกตามหมวดหมู่             │    │
# │  │ Review รายงาน           │←─┼───└──────────────────────────────┘    │
# │  │ ตรวจสอบความถูกต้อง       │  │                ↓                       │
# │  └─────────────────────────┘  │   ┌──────────────────────────────┐    │
# │             ↓                  │   │ Generate PDF Report          │    │
# │  ┌─────────────────────────┐  │   └──────────────────────────────┘    │
# │  │ Export & Submit         │──┼─→          ↓                           │
# │  │ (ส่งให้ผู้บริหาร/สรรพากร)│  │   ┌──────────────────────────────┐    │
# │  └─────────────────────────┘  │   │ Send Email / Download        │    │
# │             ↓                  │   └──────────────────────────────┘    │
# │          ⚫ END                 │                                        │
# │                                │                                        │
# └────────────────────────────────┴────────────────────────────────────────┘
# ```
#
# ---
#
# ### **สรุป Activity Diagram UCD-004**
# ✅ **5 กระบวนการหลัก:**
# 1. **Payment Management:** ตรวจสอบ Payments → Verify กับ Gateway → อัพเดทสถานะ/Refund
# 2. **Invoice Generation:** เลือก Booking → Generate Invoice Number → สร้าง PDF
# 3. **Reconciliation:** ดึงข้อมูล DB + Gateway → เปรียบเทียบ → แสดง Mismatch → Export Report
# 4. **Revenue Analytics:** เลือกประเภท (Daily/Monthly/Yearly) → Query + คำนวณ → แสดงกราฟ → Export
# 5. **Financial Reports:** เลือกประเภท (Income/Cash Flow/Tax) → สร้างรายงานตามมาตรฐาน → Export/Submit

# %% [markdown]
# ---
#
# ## 📊 Activity Diagram: UCD-005 (Managing Director)
#
# ```
# ┌─────────────────────────────────────────────────────────────────────────┐
# │             Activity Diagram: UCD-005 Managing Director                │
# ├────────────────────────────────┬────────────────────────────────────────┤
# │    Managing Director           │         Computer System                │
# ├────────────────────────────────┼────────────────────────────────────────┤
# │                                │                                        │
# │          ⚪ START               │                                        │
# │             ↓                  │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ เข้าสู่ระบบ MD           │──┼─→ ┌──────────────────────────────┐    │
# │  └─────────────────────────┘  │   │ ตรวจสอบ Role = 'director'    │    │
# │             ↓                  │   └──────────────────────────────┘    │
# │  ┌─────────────────────────┐  │                ↓                       │
# │  │ เข้า Executive Dashboard│──┼─→ ┌──────────────────────────────┐    │
# │  └─────────────────────────┘  │   │ Load Dashboard Data          │    │
# │                                │   └──────────────────────────────┘    │
# │                                │                                        │
# │      ─── EXECUTIVE DASHBOARD ───                                       │
# │                                │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ ดู KPIs หลัก:            │←─┼───┌──────────────────────────────┐    │
# │  │ - Total Revenue Today   │  │   │ Query Real-time KPIs:        │    │
# │  │ - Active Bookings       │  │   │ SELECT SUM(amount),          │    │
# │  │ - New Customers         │  │   │ COUNT(bookings),             │    │
# │  │ - System Status         │  │   │ COUNT(new users),            │    │
# │  └─────────────────────────┘  │   │ AVG(rating)                  │    │
# │             ↓                  │   └──────────────────────────────┘    │
# │  ┌─────────────────────────┐  │                ↓                       │
# │  │ ดูกราฟ Trends:           │←─┼───┌──────────────────────────────┐    │
# │  │ - Revenue Trend (7 days)│  │   │ Generate Charts:             │    │
# │  │ - Booking Trend         │  │   │ - Line Chart (Revenue)       │    │
# │  │ - Customer Growth       │  │   │ - Bar Chart (Bookings)       │    │
# │  └─────────────────────────┘  │   │ - Growth Chart (Customers)   │    │
# │             ↓                  │   └──────────────────────────────┘    │
# │  ┌─────────────────────────┐  │                ↓                       │
# │  │ ดู Alerts/Notifications │←─┼───┌──────────────────────────────┐    │
# │  │ - Low Revenue Warning   │  │   │ [Decision]                   │    │
# │  │ - System Issues         │  │   │ มี Alerts?                   │    │
# │  │ - Pending Approvals     │  │   └──────────────────────────────┘    │
# │  └─────────────────────────┘  │         /              \               │
# │                                │       YES               NO              │
# │                                │        ↓                ↓              │
# │                                │   ┌──────────┐     Skip               │
# │                                │   │ Show     │                         │
# │                                │   │ Alerts   │                         │
# │                                │   └──────────┘                         │
# │                                │                                        │
# │      ─── REVENUE REPORTS ───                                           │
# │                                │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ เลือกประเภทรายงาน:       │──┼─→ ┌──────────────────────────────┐    │
# │  │ - Daily Revenue Summary │  │   │ [Decision] Report Type?      │    │
# │  │ - Monthly Comparison    │  │   └──────────────────────────────┘    │
# │  │ - Yearly Overview       │  │         /         |         \          │
# │  └─────────────────────────┘  │      Daily    Monthly    Yearly        │
# │             ↓                  │        ↓          ↓          ↓         │
# │  ┌─────────────────────────┐  │   ┌──────────────────────────────┐    │
# │  │ กำหนดช่วงเวลา           │──┼─→ │ Aggregate Data:              │    │
# │  └─────────────────────────┘  │   │ - Total Revenue              │    │
# │             ↓                  │   │ - Revenue by Field Type      │    │
# │  ┌─────────────────────────┐  │   │ - Revenue by Payment Method  │    │
# │  │ กด "Generate"           │──┼─→ │ - Comparison vs Last Period  │    │
# │  └─────────────────────────┘  │   └──────────────────────────────┘    │
# │                                │                ↓                       │
# │  ┌─────────────────────────┐  │   ┌──────────────────────────────┐    │
# │  │ ดูรายงานพร้อมกราฟ        │←─┼───│ Generate Executive Report    │    │
# │  │ - สรุปยอดรวม            │  │   │ with Visual Charts           │    │
# │  │ - เปรียบเทียบ YoY       │  │   └──────────────────────────────┘    │
# │  │ - Growth Percentage     │  │                                        │
# │  └─────────────────────────┘  │                                        │
# │             ↓                  │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ Export (PDF/Excel)      │──┼─→ ┌──────────────────────────────┐    │
# │  └─────────────────────────┘  │   │ Export Report                │    │
# │                                │   └──────────────────────────────┘    │
# │                                │                                        │
# │      ─── BUSINESS ANALYTICS ───                                        │
# │                                │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ เลือกประเภทการวิเคราะห์: │──┼─→ ┌──────────────────────────────┐    │
# │  │ - Field Performance     │  │   │ [Decision] Analytics Type?   │    │
# │  │ - Customer Behavior     │  │   └──────────────────────────────┘    │
# │  │ - Peak Hours Analysis   │  │         /         |         \          │
# │  │ - Seasonal Trends       │  │      Field    Customer    Peak         │
# │  └─────────────────────────┘  │        ↓          ↓          ↓         │
# │             ↓                  │   ┌──────────────────────────────┐    │
# │  ┌─────────────────────────┐  │   │ Complex Queries:             │    │
# │  │ กำหนด Parameters        │──┼─→ │ - TOP Fields by Revenue      │    │
# │  │ (Date Range, Filters)   │  │   │ - Customer Segmentation (RFM)│    │
# │  └─────────────────────────┘  │   │ - Booking Hours Distribution │    │
# │             ↓                  │   │ - Seasonal Pattern Analysis  │    │
# │  ┌─────────────────────────┐  │   └──────────────────────────────┘    │
# │  │ กด "Analyze"            │──┼─→          ↓                           │
# │  └─────────────────────────┘  │   ┌──────────────────────────────┐    │
# │                                │   │ Machine Learning Analysis    │    │
# │                                │   │ (ถ้ามี): Trend Prediction    │    │
# │  ┌─────────────────────────┐  │   └──────────────────────────────┘    │
# │  │ ดูผลการวิเคราะห์:        │←─┼──────────┌──────────────────────┐     │
# │  │ - Charts & Graphs       │  │          │ Generate Visual      │     │
# │  │ - Insights & Recomm.    │  │          │ Analytics Report     │     │
# │  │ - Growth Opportunities  │  │          └──────────────────────┘     │
# │  └─────────────────────────┘  │                                        │
# │             ↓                  │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ Export Report           │──┼─→ ┌──────────────────────────────┐    │
# │  └─────────────────────────┘  │   │ Export to PDF/Excel          │    │
# │                                │   └──────────────────────────────┘    │
# │                                │                                        │
# │      ─── APPROVALS ───                                                 │
# │                                │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ ดูรายการรออนุมัติ:        │──┼─→ ┌──────────────────────────────┐    │
# │  │ - Large Bookings (>X฿)  │  │   │ SELECT * FROM:               │    │
# │  │ - Staff Password Reset  │  │   │ - bookings (amount > limit)  │    │
# │  │ - Refund Requests       │  │   │ - password_requests          │    │
# │  │ - Promotion Campaigns   │  │   │ - refund_requests            │    │
# │  └─────────────────────────┘  │   │ - promotions                 │    │
# │             ↓                  │   │ WHERE status='pending'       │    │
# │  ┌─────────────────────────┐  │   └──────────────────────────────┘    │
# │  │ เลือกรายการที่ต้องการ    │──┼─→ ┌──────────────────────────────┐    │
# │  │ พิจารณา                 │  │   │ แสดงรายละเอียดครบถ้วน         │    │
# │  └─────────────────────────┘  │   └──────────────────────────────┘    │
# │             ↓                  │                ↓                       │
# │  ┌─────────────────────────┐  │   ┌──────────────────────────────┐    │
# │  │ ทบทวนรายละเอียด          │──┼─→ │ แสดง:                        │    │
# │  │ - ข้อมูลครบถ้วน         │  │   │ - เหตุผลการขออนุมัติ          │    │
# │  │ - เหตุผล                │  │   │ - ผลกระทบทางการเงิน          │    │
# │  │ - ผลกระทบ              │  │   │ - ความเสี่ยง                 │    │
# │  └─────────────────────────┘  │   └──────────────────────────────┘    │
# │             ↓                  │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ ตัดสินใจ:               │──┼─→ ┌──────────────────────────────┐    │
# │  │ - Approve               │  │   │ [Decision] Approve/Reject?   │    │
# │  │ - Reject                │  │   └──────────────────────────────┘    │
# │  └─────────────────────────┘  │         /              \               │
# │             ↓                  │    Approve           Reject            │
# │  ┌─────────────────────────┐  │        ↓                ↓              │
# │  │ ใส่หมายเหตุ (ถ้าต้องการ)│──┼─→ ┌──────────┐   ┌─────────────────┐  │
# │  └─────────────────────────┘  │   │ UPDATE   │   │ UPDATE + Reason │  │
# │             ↓                  │   │ status=  │   │ status=         │  │
# │  ┌─────────────────────────┐  │   │'approved'│   │ 'rejected'      │  │
# │  │ ยืนยันการอนุมัติ/ปฏิเสธ  │──┼─→ │ approved_│   │ rejected_by     │  │
# │  └─────────────────────────┘  │   │ by = MD  │   │ = MD            │  │
# │                                │   └──────────┘   └─────────────────┘  │
# │                                │        ↓                ↓              │
# │                                │   ┌──────────────────────────────┐    │
# │                                │   │ Send Notification to         │    │
# │                                │   │ Requester (Email/SMS)        │    │
# │  ┌─────────────────────────┐  │   └──────────────────────────────┘    │
# │  │ แสดง Success            │←─┼──────────┌──────────────────────┐     │
# │  └─────────────────────────┘  │          │ Success              │     │
# │             ↓                  │          └──────────────────────┘     │
# │          ⚫ END                 │                                        │
# │                                │                                        │
# └────────────────────────────────┴────────────────────────────────────────┘
# ```
#
# ---
#
# ### **สรุป Activity Diagram UCD-005**
# ✅ **4 กระบวนการหลัก:**
# 1. **Executive Dashboard:** แสดง Real-time KPIs → Trends → Alerts
# 2. **Revenue Reports:** เลือกประเภท (Daily/Monthly/Yearly) → Generate Report → Export
# 3. **Business Analytics:** เลือกประเภท (Field/Customer/Peak Hours) → Complex Queries → ML Analysis → Insights
# 4. **Approvals:** ดูรายการรออนุมัติ → ทบทวน → Approve/Reject → แจ้งเตือน

# %% [markdown]
# ---
#
# ## 📊 Activity Diagram: UCD-006 (Marketing Staff)
#
# ```
# ┌─────────────────────────────────────────────────────────────────────────┐
# │               Activity Diagram: UCD-006 Marketing Staff                 │
# ├────────────────────────────────┬────────────────────────────────────────┤
# │      Marketing Staff           │         Computer System                │
# ├────────────────────────────────┼────────────────────────────────────────┤
# │                                │                                        │
# │          ⚪ START               │                                        │
# │             ↓                  │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ เข้าสู่ระบบ Marketing    │──┼─→ ┌──────────────────────────────┐    │
# │  └─────────────────────────┘  │   │ ตรวจสอบ Role = 'marketing'   │    │
# │             ↓                  │   └──────────────────────────────┘    │
# │  ┌─────────────────────────┐  │                ↓                       │
# │  │ เลือกเมนู:              │──┼─→ ┌──────────────────────────────┐    │
# │  │ - Promotions            │  │   │ แสดงหน้าตามที่เลือก           │    │
# │  │ - Campaigns             │  │   └──────────────────────────────┘    │
# │  │ - Analytics             │  │                                        │
# │  │ - Reports               │  │                                        │
# │  └─────────────────────────┘  │                                        │
# │                                │                                        │
# │      ─── CREATE PROMOTION ───                                          │
# │                                │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ กรอกข้อมูล Promotion:   │──┼─→ ┌──────────────────────────────┐    │
# │  │ - ชื่อโปรโมชั่น          │  │   │ รับข้อมูล                    │    │
# │  │ - Promo Code            │  │   └──────────────────────────────┘    │
# │  │ - ประเภท (%, Fixed)     │  │                ↓                       │
# │  │ - Discount Value        │  │   ┌──────────────────────────────┐    │
# │  │ - วันที่เริ่ม-สิ้นสุด    │  │   │ [Decision]                   │    │
# │  │ - เงื่อนไข (min amount) │  │   │ Promo Code ซ้ำ?              │    │
# │  └─────────────────────────┘  │   └──────────────────────────────┘    │
# │             ↓                  │         /              \               │
# │  ┌─────────────────────────┐  │       YES               NO              │
# │  │ กด "Create Promotion"   │──┼─→      ↓                ↓              │
# │  └─────────────────────────┘  │   ┌──────────┐   ┌─────────────────┐  │
# │                                │   │ Error:   │   │ INSERT INTO     │  │
# │  ┌─────────────────────────┐  │   │ "Code ซ้ำ"│   │ promotions      │  │
# │  │ แสดง Error              │←─┼───└──────────┘   └─────────────────┘  │
# │  └─────────────────────────┘  │                           ↓            │
# │             หรือ               │                  ┌─────────────────┐  │
# │  ┌─────────────────────────┐  │                  │ SET status=     │  │
# │  │ แสดง Success +          │←─┼──────────────────│ 'draft'         │  │
# │  │ Promo Code              │  │                  └─────────────────┘  │
# │  └─────────────────────────┘  │                           ↓            │
# │             ↓                  │                  ┌─────────────────┐  │
# │  ┌─────────────────────────┐  │                  │ Success         │  │
# │  │ Activate Promotion      │──┼─→ ┌──────────────────────────────┐     │
# │  │ (เมื่อพร้อม)             │  │   │ UPDATE status = 'active'     │     │
# │  └─────────────────────────┘  │   └──────────────────────────────┘     │
# │                                │                                        │
# │      ─── CAMPAIGN MANAGEMENT ───                                       │
# │                                │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ สร้าง Campaign:         │──┼─→ ┌──────────────────────────────┐    │
# │  │ - Campaign Name         │  │   │ รับข้อมูล Campaign           │    │
# │  │ - เป้าหมาย (Target)     │  │   └──────────────────────────────┘    │
# │  │ - ช่องทาง (Email/SMS/   │  │                ↓                       │
# │  │   Social/Push Notif)    │  │   ┌──────────────────────────────┐    │
# │  │ - เนื้อหา Message       │  │   │ INSERT INTO campaigns        │    │
# │  │ - Schedule Date/Time    │  │   └──────────────────────────────┘    │
# │  └─────────────────────────┘  │                ↓                       │
# │             ↓                  │   ┌──────────────────────────────┐    │
# │  ┌─────────────────────────┐  │   │ [Decision]                   │    │
# │  │ เลือก Target Audience:  │──┼─→ │ Target Type?                 │    │
# │  │ - All Customers         │  │   └──────────────────────────────┘    │
# │  │ - Segment (RFM)         │  │         /         |         \          │
# │  │ - Inactive Users        │  │       All      Segment    Inactive     │
# │  │ - Custom List           │  │        ↓          ↓          ↓         │
# │  └─────────────────────────┘  │   ┌──────┐  ┌─────────┐ ┌──────────┐  │
# │             ↓                  │   │SELECT│  │ RFM     │ │ WHERE    │  │
# │  ┌─────────────────────────┐  │   │ ALL  │  │ Query   │ │ last>30d │  │
# │  │ Preview Campaign        │──┼─→ │ users│  │ Complex │ │          │  │
# │  └─────────────────────────┘  │   └──────┘  └─────────┘ └──────────┘  │
# │             ↓                  │        └──────────┴──────────┘         │
# │  ┌─────────────────────────┐  │                   ↓                    │
# │  │ Launch Campaign:        │──┼─→ ┌──────────────────────────────┐    │
# │  │ - ทันที (Immediate)      │  │   │ [Decision] Schedule Type?    │    │
# │  │ - กำหนดเวลา (Scheduled) │  │   └──────────────────────────────┘    │
# │  └─────────────────────────┘  │         /              \               │
# │             ↓                  │   Immediate        Scheduled           │
# │  ┌─────────────────────────┐  │        ↓                ↓              │
# │  │ ยืนยัน Launch           │──┼─→ ┌──────────┐   ┌─────────────────┐  │
# │  └─────────────────────────┘  │   │ Send Now │   │ Queue for Later │  │
# │                                │   │ to All   │   │ (Cron Job)      │  │
# │                                │   │ Targets  │   └─────────────────┘  │
# │                                │   └──────────┘            ↓            │
# │                                │        ↓         ┌─────────────────┐  │
# │                                │   ┌──────────────────────────────┐    │
# │                                │   │ Send via Selected Channels:  │    │
# │                                │   │ - Email API                  │    │
# │                                │   │ - SMS Gateway                │    │
# │  ┌─────────────────────────┐  │   │ - Social Media API           │    │
# │  │ แสดง Campaign Status:   │←─┼───│ - Push Notification Service  │    │
# │  │ - Sent: X               │  │   └──────────────────────────────┘    │
# │  │ - Delivered: Y          │  │                ↓                       │
# │  │ - Opened: Z             │  │   ┌──────────────────────────────┐    │
# │  │ - Clicked: W            │  │   │ Track Campaign Metrics       │    │
# │  └─────────────────────────┘  │   │ INSERT INTO campaign_metrics │    │
# │                                │   └──────────────────────────────┘    │
# │                                │                                        │
# │      ─── CUSTOMER ANALYTICS ───                                        │
# │                                │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ เลือกประเภทการวิเคราะห์: │──┼─→ ┌──────────────────────────────┐    │
# │  │ - RFM Segmentation      │  │   │ [Decision] Analytics Type?   │    │
# │  │ - Field Popularity      │  │   └──────────────────────────────┘    │
# │  │ - Customer Behavior     │  │         /         |         \          │
# │  └─────────────────────────┘  │       RFM      Field     Behavior      │
# │             ↓                  │        ↓          ↓          ↓         │
# │  ┌─────────────────────────┐  │   ┌──────────────────────────────┐    │
# │  │ กำหนด Parameters        │──┼─→ │ Complex Queries:             │    │
# │  │ (Date Range, Filters)   │  │   │ - RFM Score Calculation      │    │
# │  └─────────────────────────┘  │   │ - Field Booking Count        │    │
# │             ↓                  │   │ - Customer Journey Analysis  │    │
# │  ┌─────────────────────────┐  │   └──────────────────────────────┘    │
# │  │ กด "Analyze"            │──┼─→          ↓                           │
# │  └─────────────────────────┘  │   ┌──────────────────────────────┐    │
# │                                │   │ Segment Customers:           │    │
# │                                │   │ - Champions (High RFM)       │    │
# │  ┌─────────────────────────┐  │   │ - Loyal (Regular)            │    │
# │  │ ดูผลการวิเคราะห์:        │←─┼───│ - At Risk (Declining)        │    │
# │  │ - Customer Segments     │  │   │ - Lost (Inactive)            │    │
# │  │ - Top Fields by Revenue │  │   └──────────────────────────────┘    │
# │  │ - Booking Patterns      │  │                ↓                       │
# │  │ - Insights              │  │   ┌──────────────────────────────┐    │
# │  └─────────────────────────┘  │   │ Generate Visual Reports      │    │
# │             ↓                  │   │ - Pie Charts (Segments)      │    │
# │  ┌─────────────────────────┐  │   │ - Bar Charts (Fields)        │    │
# │  │ Export Report           │──┼─→ │ - Heatmaps (Patterns)        │    │
# │  └─────────────────────────┘  │   └──────────────────────────────┘    │
# │             ↓                  │                ↓                       │
# │  ┌─────────────────────────┐  │          Export to File                │
# │  │ สร้าง Targeted Campaign │──┼─→ ┌──────────────────────────────┐    │
# │  │ จากผล Insights          │  │   │ Use Segments for Campaigns   │    │
# │  └─────────────────────────┘  │   └──────────────────────────────┘    │
# │                                │                                        │
# │      ─── MARKETING DASHBOARD ───                                       │
# │                                │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ ดู Dashboard:           │←─┼───┌──────────────────────────────┐    │
# │  │ - Active Promotions     │  │   │ Real-time Marketing KPIs:    │    │
# │  │ - Running Campaigns     │  │   │ - Active Promotions Count    │    │
# │  │ - Promo Usage Stats     │  │   │ - Campaign Performance       │    │
# │  │ - ROI Calculations      │  │   │ - Promo Code Usage           │    │
# │  └─────────────────────────┘  │   │ - Marketing ROI              │    │
# │             ↓                  │   └──────────────────────────────┘    │
# │  ┌─────────────────────────┐  │                ↓                       │
# │  │ Drill Down:             │──┼─→ ┌──────────────────────────────┐    │
# │  │ - Promotion Details     │  │   │ Query Detailed Data:         │    │
# │  │ - Campaign Analytics    │  │   │ SELECT promo usage,          │    │
# │  └─────────────────────────┘  │   │ campaign metrics,            │    │
# │             ↓                  │   │ conversion rates             │    │
# │  ┌─────────────────────────┐  │   └──────────────────────────────┘    │
# │  │ ดูกราฟและแนวโน้ม         │←─┼──────────┌──────────────────────┐     │
# │  │ - Usage Trends          │  │          │ Generate Charts      │     │
# │  │ - Conversion Rates      │  │          └──────────────────────┘     │
# │  └─────────────────────────┘  │                                        │
# │             ↓                  │                                        │
# │          ⚫ END                 │                                        │
# │                                │                                        │
# └────────────────────────────────┴────────────────────────────────────────┘
# ```
#
# ---
#
# ### **สรุป Activity Diagram UCD-006**
# ✅ **4 กระบวนการหลัก:**
# 1. **Create Promotion:** กรอกข้อมูล → ตรวจสอบ Code ซ้ำ → บันทึก (Draft) → Activate
# 2. **Campaign Management:** สร้าง Campaign → เลือก Target Audience (All/Segment/Inactive) → Launch (Immediate/Scheduled) → Send via Channels → Track Metrics
# 3. **Customer Analytics:** เลือกประเภท (RFM/Field/Behavior) → Complex Queries → Segmentation → Visual Reports → Export
# 4. **Marketing Dashboard:** แสดง KPIs → Drill Down → กราฟแนวโน้ม

# %% [markdown]
# ---
#
# ## 📊 Activity Diagram: UCD-007 (Payment Gateway Integration)
#
# ```
# ┌─────────────────────────────────────────────────────────────────────────┐
# │          Activity Diagram: UCD-007 Payment Gateway Integration         │
# ├────────────────────────────────┬────────────────────────────────────────┤
# │      System                    │         Payment Gateway                │
# ├────────────────────────────────┼────────────────────────────────────────┤
# │                                │                                        │
# │          ⚪ START               │                                        │
# │        (Customer ทำ Booking)   │                                        │
# │             ↓                  │                                        │
# │                                │                                        │
# │      ─── PROCESS PAYMENT ───                                           │
# │                                │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ รับข้อมูล Booking        │  │                                        │
# │  │ - booking_id            │  │                                        │
# │  │ - amount                │  │                                        │
# │  │ - customer_id           │  │                                        │
# │  └─────────────────────────┘  │                                        │
# │             ↓                  │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ Customer เลือกวิธีชำระ:  │  │                                        │
# │  │ - QR Code (PromptPay)   │  │                                        │
# │  │ - Bank Transfer         │  │                                        │
# │  │ - Credit/Debit Card     │  │                                        │
# │  └─────────────────────────┘  │                                        │
# │             ↓                  │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ สร้าง Payment Record    │──┼─→ ┌──────────────────────────────┐    │
# │  │ INSERT INTO payments    │  │   │ เตรียมข้อมูลสำหรับ API       │    │
# │  │ SET status='pending'    │  │   └──────────────────────────────┘    │
# │  └─────────────────────────┘  │                ↓                       │
# │             ↓                  │   ┌──────────────────────────────┐    │
# │  ┌─────────────────────────┐  │   │ POST /api/payment/create     │    │
# │  │ ส่งข้อมูลไป Gateway      │──┼─→ │ Body: {                      │    │
# │  │ POST Request            │  │   │   amount, currency,          │    │
# │  └─────────────────────────┘  │   │   method, callback_url,      │    │
# │                                │   │   merchant_id                │    │
# │                                │   │ }                            │    │
# │                                │   └──────────────────────────────┘    │
# │                                │                ↓                       │
# │                                │   ┌──────────────────────────────┐    │
# │                                │   │ [Decision] Payment Method?   │    │
# │                                │   └──────────────────────────────┘    │
# │                                │         /         |         \          │
# │                                │       QR       Transfer    Card        │
# │                                │        ↓          ↓          ↓         │
# │                                │   ┌──────┐  ┌────────┐ ┌──────────┐   │
# │                                │   │ Gen  │  │Request │ │ Tokenize │   │
# │                                │   │ QR   │  │ Bank   │ │ Card     │   │
# │                                │   │ Code │  │ Account│ │ Info     │   │
# │                                │   └──────┘  └────────┘ └──────────┘   │
# │                                │        └──────────┴──────────┘         │
# │                                │                   ↓                    │
# │  ┌─────────────────────────┐  │   ┌──────────────────────────────┐    │
# │  │ รับ Response จาก Gateway│←─┼───│ Return Response:             │    │
# │  │ - transaction_id        │  │   │ - transaction_id             │    │
# │  │ - payment_url (QR/Form) │  │   │ - payment_url or QR data     │    │
# │  │ - expires_at            │  │   │ - status: 'pending'          │    │
# │  └─────────────────────────┘  │   │ - expires_at (15 min)        │    │
# │             ↓                  │   └──────────────────────────────┘    │
# │  ┌─────────────────────────┐  │                                        │
# │  │ UPDATE payment          │  │                                        │
# │  │ SET transaction_id=?    │  │                                        │
# │  └─────────────────────────┘  │                                        │
# │             ↓                  │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ แสดง QR Code / Form     │  │                                        │
# │  │ ให้ Customer            │  │                                        │
# │  └─────────────────────────┘  │                                        │
# │             ↓                  │                                        │
# │  Customer ทำการชำระเงิน        │         ↓                              │
# │                                │   ┌──────────────────────────────┐    │
# │                                │   │ Process Payment:             │    │
# │                                │   │ - Scan QR / Transfer / Card  │    │
# │                                │   └──────────────────────────────┘    │
# │                                │                ↓                       │
# │                                │   ┌──────────────────────────────┐    │
# │                                │   │ [Decision]                   │    │
# │                                │   │ Payment Success?             │    │
# │                                │   └──────────────────────────────┘    │
# │                                │         /              \               │
# │                                │      Success          Failure          │
# │                                │        ↓                ↓              │
# │                                │   ┌──────────┐   ┌─────────────────┐  │
# │                                │   │ Verify   │   │ Log Error       │  │
# │                                │   │ Amount   │   │ - Insufficient  │  │
# │                                │   │ & Account│   │ - Invalid Card  │  │
# │                                │   └──────────┘   │ - Timeout       │  │
# │                                │        ↓         └─────────────────┘  │
# │                                │                           ↓            │
# │      ─── WEBHOOK CALLBACK ───                                          │
# │                                │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ รับ Webhook Callback     │←─┼───┌──────────────────────────────┐    │
# │  │ POST /webhook/payment   │  │   │ POST Webhook:                │    │
# │  └─────────────────────────┘  │   │ - transaction_id             │    │
# │             ↓                  │   │ - status (success/failed)    │    │
# │  ┌─────────────────────────┐  │   │ - amount                     │    │
# │  │ ตรวจสอบ Signature        │  │   │ - timestamp                  │    │
# │  │ (Security)              │  │   │ - signature (HMAC-SHA256)    │    │
# │  └─────────────────────────┘  │   └──────────────────────────────┘    │
# │             ↓                  │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ [Decision]              │  │                                        │
# │  │ Signature Valid?        │  │                                        │
# │  └─────────────────────────┘  │                                        │
# │         /          \           │                                        │
# │       YES           NO          │                                        │
# │        ↓            ↓          │                                        │
# │  ┌─────────┐  ┌─────────┐     │                                        │
# │  │ Process │  │ Reject  │     │                                        │
# │  │ Webhook │  │ (Log)   │     │                                        │
# │  └─────────┘  └─────────┘     │                                        │
# │        ↓                       │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ UPDATE payments         │  │                                        │
# │  │ SET status=?,           │  │                                        │
# │  │ paid_at=NOW()           │  │                                        │
# │  └─────────────────────────┘  │                                        │
# │             ↓                  │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ UPDATE bookings         │  │                                        │
# │  │ SET payment_status=     │  │                                        │
# │  │ 'completed'             │  │                                        │
# │  └─────────────────────────┘  │                                        │
# │             ↓                  │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ Send Notification       │  │                                        │
# │  │ - Email Receipt         │  │                                        │
# │  │ - SMS Confirmation      │  │                                        │
# │  └─────────────────────────┘  │                                        │
# │             ↓                  │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ Return Success Response │──┼─→ ┌──────────────────────────────┐    │
# │  │ to Gateway              │  │   │ Acknowledge Webhook          │    │
# │  └─────────────────────────┘  │   │ HTTP 200 OK                  │    │
# │                                │   └──────────────────────────────┘    │
# │                                │                                        │
# │      ─── VERIFY PAYMENT ───                                            │
# │                                │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ Manual Verify Request   │  │                                        │
# │  │ (จาก Staff/Customer)     │  │                                        │
# │  └─────────────────────────┘  │                                        │
# │             ↓                  │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ Query Payment Gateway   │──┼─→ ┌──────────────────────────────┐    │
# │  │ GET /api/payment/verify │  │   │ GET /api/payment/{trans_id}  │    │
# │  └─────────────────────────┘  │   └──────────────────────────────┘    │
# │             ↓                  │                ↓                       │
# │  ┌─────────────────────────┐  │   ┌──────────────────────────────┐    │
# │  │ รับสถานะปัจจุบัน         │←─┼───│ Return Current Status:       │    │
# │  └─────────────────────────┘  │   │ - status                     │    │
# │             ↓                  │   │ - amount                     │    │
# │  ┌─────────────────────────┐  │   │ - paid_at                    │    │
# │  │ เปรียบเทียบกับ DB        │  │   └──────────────────────────────┘    │
# │  └─────────────────────────┘  │                                        │
# │             ↓                  │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ [Decision] Match?       │  │                                        │
# │  └─────────────────────────┘  │                                        │
# │         /          \           │                                        │
# │       YES           NO          │                                        │
# │        ↓            ↓          │                                        │
# │  ┌─────────┐  ┌─────────────┐ │                                        │
# │  │ Success │  │ Sync & Update│ │                                        │
# │  └─────────┘  └─────────────┘ │                                        │
# │                                │                                        │
# │      ─── PROCESS REFUND ───                                            │
# │                                │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ Refund Request          │  │                                        │
# │  │ (from Staff/System)     │  │                                        │
# │  └─────────────────────────┘  │                                        │
# │             ↓                  │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ ดึงข้อมูล Original      │  │                                        │
# │  │ Payment                 │  │                                        │
# │  └─────────────────────────┘  │                                        │
# │             ↓                  │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ คำนวณ Refund Amount     │  │                                        │
# │  │ (Full or Partial)       │  │                                        │
# │  └─────────────────────────┘  │                                        │
# │             ↓                  │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ ส่ง Refund Request      │──┼─→ ┌──────────────────────────────┐    │
# │  │ POST /api/refund        │  │   │ POST /api/refund             │    │
# │  └─────────────────────────┘  │   │ Body: {                      │    │
# │                                │   │   transaction_id,            │    │
# │                                │   │   amount,                    │    │
# │                                │   │   reason                     │    │
# │                                │   │ }                            │    │
# │                                │   └──────────────────────────────┘    │
# │                                │                ↓                       │
# │                                │   ┌──────────────────────────────┐    │
# │                                │   │ Process Refund:              │    │
# │                                │   │ - Validate Transaction       │    │
# │                                │   │ - Transfer Back to Account   │    │
# │  ┌─────────────────────────┐  │   └──────────────────────────────┘    │
# │  │ รับ Refund Response     │←─┼──────────┌──────────────────────┐     │
# │  └─────────────────────────┘  │          │ Return Response:     │     │
# │             ↓                  │          │ - refund_id          │     │
# │  ┌─────────────────────────┐  │          │ - status             │     │
# │  │ INSERT INTO refunds     │  │          │ - refunded_at        │     │
# │  │ UPDATE payments         │  │          └──────────────────────┘     │
# │  │ UPDATE bookings         │  │                                        │
# │  └─────────────────────────┘  │                                        │
# │             ↓                  │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ Notify Customer         │  │                                        │
# │  │ "Refund Processed"      │  │                                        │
# │  └─────────────────────────┘  │                                        │
# │             ↓                  │                                        │
# │          ⚫ END                 │                                        │
# │                                │                                        │
# └────────────────────────────────┴────────────────────────────────────────┘
# ```
#
# ---
#
# ### **สรุป Activity Diagram UCD-007**
# ✅ **5 กระบวนการหลัก:**
# 1. **Process Payment:** รับข้อมูล → เลือกวิธีชำระ → ส่ง API → รับ Response (QR/URL) → แสดงให้ Customer
# 2. **Webhook Callback:** รับ Webhook → ตรวจสอบ Signature → อัพเดทสถานะ → แจ้งเตือน Customer → Return 200 OK
# 3. **Verify Payment:** Query Gateway → เปรียบเทียบกับ DB → Sync (ถ้าไม่ตรง)
# 4. **Process Refund:** คำนวณยอด Refund → ส่ง API → รับ Response → อัพเดท DB → แจ้งเตือน
# 5. **Error Handling:** Log Errors → Retry Logic → Notify Admin

# %% [markdown]
# ---
#
# ## 📊 Activity Diagram: UCD-008 (Logistic System Integration)
#
# ```
# ┌─────────────────────────────────────────────────────────────────────────┐
# │         Activity Diagram: UCD-008 Logistic System Integration          │
# ├────────────────────────────────┬────────────────────────────────────────┤
# │      System                    │         Logistic System                │
# ├────────────────────────────────┼────────────────────────────────────────┤
# │                                │                                        │
# │          ⚪ START               │                                        │
# │      (Booking มีอุปกรณ์)        │                                        │
# │             ↓                  │                                        │
# │                                │                                        │
# │      ─── GENERATE ORDER-ID ───                                         │
# │                                │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ Booking Approved        │  │                                        │
# │  │ + มีอุปกรณ์              │  │                                        │
# │  └─────────────────────────┘  │                                        │
# │             ↓                  │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ ดึงข้อมูลจาก Booking:    │  │                                        │
# │  │ - booking_id            │  │                                        │
# │  │ - customer info         │  │                                        │
# │  │ - delivery address      │  │                                        │
# │  │ - equipment list        │  │                                        │
# │  └─────────────────────────┘  │                                        │
# │             ↓                  │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ Generate Order-ID       │  │                                        │
# │  │ ORD-YYYYMMDD-XXXX       │  │                                        │
# │  └─────────────────────────┘  │                                        │
# │             ↓                  │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ เตรียมข้อมูล Delivery:  │  │                                        │
# │  │ - sender info           │  │                                        │
# │  │ - receiver info         │  │                                        │
# │  │ - items list            │  │                                        │
# │  │ - delivery_date         │  │                                        │
# │  └─────────────────────────┘  │                                        │
# │             ↓                  │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ ส่งข้อมูลไป Logistic    │──┼─→ ┌──────────────────────────────┐    │
# │  │ POST /api/orders        │  │   │ POST /api/orders/create      │    │
# │  └─────────────────────────┘  │   │ Body: {                      │    │
# │                                │   │   order_id,                  │    │
# │                                │   │   sender: {...},             │    │
# │                                │   │   receiver: {...},           │    │
# │                                │   │   items: [...],              │    │
# │                                │   │   delivery_date,             │    │
# │                                │   │   service_type               │    │
# │                                │   │ }                            │    │
# │                                │   └──────────────────────────────┘    │
# │                                │                ↓                       │
# │                                │   ┌──────────────────────────────┐    │
# │                                │   │ Validate Order Data:         │    │
# │                                │   │ - Address format             │    │
# │                                │   │ - Items weight/size          │    │
# │                                │   │ - Service availability       │    │
# │                                │   └──────────────────────────────┘    │
# │                                │                ↓                       │
# │                                │   ┌──────────────────────────────┐    │
# │                                │   │ [Decision]                   │    │
# │                                │   │ Validation OK?               │    │
# │                                │   └──────────────────────────────┘    │
# │                                │         /              \               │
# │                                │       YES               NO              │
# │                                │        ↓                ↓              │
# │                                │   ┌──────────┐   ┌─────────────────┐  │
# │                                │   │ Create   │   │ Error Response: │  │
# │                                │   │ Order in │   │ - Invalid Addr  │  │
# │                                │   │ System   │   │ - Overweight    │  │
# │                                │   └──────────┘   └─────────────────┘  │
# │                                │        ↓                ↓              │
# │                                │   ┌──────────────────────────────┐    │
# │                                │   │ Assign to Warehouse          │    │
# │                                │   └──────────────────────────────┘    │
# │                                │                ↓                       │
# │      ─── RECEIVE TRACKING NUMBER ───                                   │
# │                                │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ รับ Response จาก         │←─┼───┌──────────────────────────────┐    │
# │  │ Logistic System         │  │   │ Return Response:             │    │
# │  └─────────────────────────┘  │   │ - tracking_number            │    │
# │             ↓                  │   │ - estimated_delivery         │    │
# │  ┌─────────────────────────┐  │   │ - warehouse_location         │    │
# │  │ INSERT INTO deliveries  │  │   │ - status: 'confirmed'        │    │
# │  │ SET:                    │  │   └──────────────────────────────┘    │
# │  │ - order_id              │  │                                        │
# │  │ - tracking_number       │  │                                        │
# │  │ - status='confirmed'    │  │                                        │
# │  └─────────────────────────┘  │                                        │
# │             ↓                  │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ UPDATE bookings         │  │                                        │
# │  │ SET delivery_status=    │  │                                        │
# │  │ 'confirmed'             │  │                                        │
# │  └─────────────────────────┘  │                                        │
# │             ↓                  │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ Send Notification to    │  │                                        │
# │  │ Customer:               │  │                                        │
# │  │ - Email with Tracking # │  │                                        │
# │  │ - SMS with Link         │  │                                        │
# │  └─────────────────────────┘  │                                        │
# │                                │                                        │
# │      ─── REAL-TIME STATUS UPDATES (Webhook) ───                       │
# │                                │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ รับ Webhook Callback    │←─┼───┌──────────────────────────────┐    │
# │  │ POST /webhook/delivery  │  │   │ POST Webhook:                │    │
# │  └─────────────────────────┘  │   │ - tracking_number            │    │
# │             ↓                  │   │ - status (processing/        │    │
# │  ┌─────────────────────────┐  │   │   in-transit/delivered/      │    │
# │  │ ตรวจสอบ Webhook         │  │   │   failed)                    │    │
# │  │ Signature (Security)    │  │   │ - location                   │    │
# │  └─────────────────────────┘  │   │ - timestamp                  │    │
# │             ↓                  │   │ - signature (HMAC)           │    │
# │  ┌─────────────────────────┐  │   │ - updated_by (driver_id)     │    │
# │  │ [Decision]              │  │   └──────────────────────────────┘    │
# │  │ Signature Valid?        │  │                                        │
# │  └─────────────────────────┘  │                                        │
# │         /          \           │                                        │
# │       YES           NO          │                                        │
# │        ↓            ↓          │                                        │
# │  ┌─────────┐  ┌─────────┐     │                                        │
# │  │ Process │  │ Reject  │     │                                        │
# │  │ Update  │  │ (Log)   │     │                                        │
# │  └─────────┘  └─────────┘     │                                        │
# │        ↓                       │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ UPDATE deliveries       │  │                                        │
# │  │ SET:                    │  │                                        │
# │  │ - status=?              │  │                                        │
# │  │ - current_location=?    │  │                                        │
# │  │ - updated_at=NOW()      │  │                                        │
# │  └─────────────────────────┘  │                                        │
# │             ↓                  │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ INSERT INTO             │  │                                        │
# │  │ delivery_history        │  │                                        │
# │  │ (Status Timeline)       │  │                                        │
# │  └─────────────────────────┘  │                                        │
# │             ↓                  │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ [Decision]              │  │                                        │
# │  │ Status Changed?         │  │                                        │
# │  └─────────────────────────┘  │                                        │
# │         /          \           │                                        │
# │       YES           NO          │                                        │
# │        ↓            ↓          │                                        │
# │  ┌─────────┐      Skip         │                                        │
# │  │ Notify  │                   │                                        │
# │  │Customer │                   │                                        │
# │  │ & Staff │                   │                                        │
# │  └─────────┘                   │                                        │
# │        ↓                       │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ Return 200 OK to        │──┼─→ ┌──────────────────────────────┐    │
# │  │ Logistic System         │  │   │ Acknowledge Webhook          │    │
# │  └─────────────────────────┘  │   │ HTTP 200 OK                  │    │
# │                                │   └──────────────────────────────┘    │
# │                                │                                        │
# │      ─── TRACK DELIVERY ───                                            │
# │                                │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ Customer/Staff Request  │  │                                        │
# │  │ Tracking Info           │  │                                        │
# │  └─────────────────────────┘  │                                        │
# │             ↓                  │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ ดึงข้อมูลจาก DB:         │  │                                        │
# │  │ SELECT * FROM           │  │                                        │
# │  │ deliveries              │  │                                        │
# │  │ WHERE tracking_number=? │  │                                        │
# │  └─────────────────────────┘  │                                        │
# │             ↓                  │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ Query Logistic System   │──┼─→ ┌──────────────────────────────┐    │
# │  │ (Real-time Update)      │  │   │ GET /api/tracking/{number}   │    │
# │  └─────────────────────────┘  │   └──────────────────────────────┘    │
# │             ↓                  │                ↓                       │
# │  ┌─────────────────────────┐  │   ┌──────────────────────────────┐    │
# │  │ รับข้อมูลปัจจุบัน:        │←─┼───│ Return Current Status:       │    │
# │  │ - current_status        │  │   │ - status                     │    │
# │  │ - location              │  │   │ - current_location           │    │
# │  │ - estimated_arrival     │  │   │ - driver info                │    │
# │  │ - timeline              │  │   │ - history timeline           │    │
# │  └─────────────────────────┘  │   │ - photo proof (if any)       │    │
# │             ↓                  │   └──────────────────────────────┘    │
# │  ┌─────────────────────────┐  │                                        │
# │  │ แสดงข้อมูลให้ User:      │  │                                        │
# │  │ - สถานะปัจจุบัน          │  │                                        │
# │  │ - แผนที่เส้นทาง          │  │                                        │
# │  │ - Timeline History      │  │                                        │
# │  │ - คาดการณ์ถึง            │  │                                        │
# │  └─────────────────────────┘  │                                        │
# │                                │                                        │
# │      ─── SCHEDULE DELIVERY ───                                         │
# │                                │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ Customer เลือกช่วงเวลา   │  │                                        │
# │  │ ที่ต้องการรับ             │  │                                        │
# │  └─────────────────────────┘  │                                        │
# │             ↓                  │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ ส่ง Request ไป Logistic │──┼─→ ┌──────────────────────────────┐    │
# │  │ PUT /api/schedule       │  │   │ PUT /api/orders/{id}/schedule│    │
# │  └─────────────────────────┘  │   │ Body: {                      │    │
# │                                │   │   preferred_time_slot,       │    │
# │                                │   │   date,                      │    │
# │                                │   │   special_instructions       │    │
# │                                │   │ }                            │    │
# │                                │   └──────────────────────────────┘    │
# │                                │                ↓                       │
# │                                │   ┌──────────────────────────────┐    │
# │                                │   │ [Decision]                   │    │
# │                                │   │ Time Slot Available?         │    │
# │                                │   └──────────────────────────────┘    │
# │                                │         /              \               │
# │                                │       YES               NO              │
# │  ┌─────────────────────────┐  │        ↓                ↓              │
# │  │ รับ Response            │←─┼───┌──────────┐   ┌─────────────────┐  │
# │  └─────────────────────────┘  │   │ Confirm  │   │ Suggest         │  │
# │             ↓                  │   │ Schedule │   │ Alternative     │  │
# │  ┌─────────────────────────┐  │   └──────────┘   │ Time Slots      │  │
# │  │ UPDATE deliveries       │  │                  └─────────────────┘  │
# │  │ SET scheduled_time=?    │  │                                        │
# │  └─────────────────────────┘  │                                        │
# │             ↓                  │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ Notify Customer         │  │                                        │
# │  │ "กำหนดเวลาส่งแล้ว"       │  │                                        │
# │  └─────────────────────────┘  │                                        │
# │                                │                                        │
# │      ─── DELIVERY COMPLETED ───                                        │
# │                                │                                        │
# │                                │   ┌──────────────────────────────┐    │
# │                                │   │ Driver ส่งสินค้าสำเร็จ        │    │
# │                                │   │ Upload:                      │    │
# │                                │   │ - Photo with Customer        │    │
# │                                │   │ - Signature                  │    │
# │  ┌─────────────────────────┐  │   │ - Timestamp & GPS            │    │
# │  │ รับ Webhook "Delivered" │←─┼───└──────────────────────────────┘    │
# │  └─────────────────────────┘  │                ↓                       │
# │             ↓                  │   ┌──────────────────────────────┐    │
# │  ┌─────────────────────────┐  │   │ POST Webhook:                │    │
# │  │ UPDATE deliveries       │  │   │ status = 'delivered'         │    │
# │  │ SET status='delivered'  │  │   │ delivered_at, proof_photo    │    │
# │  │ delivered_at=NOW()      │  │   └──────────────────────────────┘    │
# │  └─────────────────────────┘  │                                        │
# │             ↓                  │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ UPDATE bookings         │  │                                        │
# │  │ SET delivery_status=    │  │                                        │
# │  │ 'completed'             │  │                                        │
# │  └─────────────────────────┘  │                                        │
# │             ↓                  │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ Send Notification:      │  │                                        │
# │  │ - Customer: "ได้รับแล้ว" │  │                                        │
# │  │ - Staff: "ส่งสำเร็จ"     │  │                                        │
# │  └─────────────────────────┘  │                                        │
# │             ↓                  │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ Request Customer Review │  │                                        │
# │  │ (Rating Delivery)       │  │                                        │
# │  └─────────────────────────┘  │                                        │
# │             ↓                  │                                        │
# │          ⚫ END                 │                                        │
# │                                │                                        │
# └────────────────────────────────┴────────────────────────────────────────┘
# ```
#
# ---
#
# ### **สรุป Activity Diagram UCD-008**
# ✅ **6 กระบวนการหลัก:**
# 1. **Generate Order-ID:** รวบรวมข้อมูล → สร้าง Order-ID → ส่งไป Logistic API → รับ Response
# 2. **Receive Tracking Number:** รับ Tracking Number + Estimated Delivery → บันทึก DB → แจ้งเตือน Customer
# 3. **Real-time Status Updates (Webhook):** รับ Webhook → ตรวจสอบ Signature → อัพเดทสถานะ → บันทึก History → แจ้งเตือน (ถ้ามีการเปลี่ยนแปลง)
# 4. **Track Delivery:** Query Logistic API → รับสถานะปัจจุบัน → แสดงข้อมูล + Timeline
# 5. **Schedule Delivery:** เลือกช่วงเวลา → ส่ง Request → รับ Confirmation/Alternative → อัพเดท DB
# 6. **Delivery Completed:** รับ Webhook "Delivered" → อัพเดทสถานะ → แจ้งเตือน → Request Review

# %% [markdown]
# ---
#
# ## 📊 Activity Diagram: UCD-009 (Customer Experience)
#
# ```
# ┌─────────────────────────────────────────────────────────────────────────┐
# │              Activity Diagram: UCD-009 Customer Experience              │
# ├────────────────────────────────┬────────────────────────────────────────┤
# │         Customer               │         Computer System                │
# ├────────────────────────────────┼────────────────────────────────────────┤
# │                                │                                        │
# │          ⚪ START               │                                        │
# │             ↓                  │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ เข้าเว็บไซต์             │──┼─→ ┌──────────────────────────────┐    │
# │  └─────────────────────────┘  │   │ Load Homepage                │    │
# │             ↓                  │   └──────────────────────────────┘    │
# │                                │                                        │
# │      ─── BROWSE & SEARCH FIELDS ───                                    │
# │                                │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ ดูรายการสนามทั้งหมด      │──┼─→ ┌──────────────────────────────┐    │
# │  └─────────────────────────┘  │   │ SELECT f.*, AVG(r.rating)    │    │
# │             ↓                  │   │ FROM fields f                │    │
# │  ┌─────────────────────────┐  │   │ LEFT JOIN reviews r          │    │
# │  │ ใช้ Search/Filter:      │──┼─→ │ WHERE f.is_active=true       │    │
# │  │ - ชื่อสนาม               │  │   │ GROUP BY f.field_id          │    │
# │  │ - ประเภทกีฬา            │  │   └──────────────────────────────┘    │
# │  │ - ราคา (Min-Max)        │  │                ↓                       │
# │  │ - Rating                │  │   ┌──────────────────────────────┐    │
# │  │ - สิ่งอำนวยความสะดวก    │  │   │ Apply Filters to Query       │    │
# │  └─────────────────────────┘  │   │ WHERE field_type LIKE ?      │    │
# │             ↓                  │   │ AND price BETWEEN ? AND ?    │    │
# │  ┌─────────────────────────┐  │   │ ORDER BY rating DESC         │    │
# │  │ ดูรายการที่กรองแล้ว      │←─┼───└──────────────────────────────┘    │
# │  └─────────────────────────┘  │                                        │
# │             ↓                  │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ คลิกดูรายละเอียดสนาม     │──┼─→ ┌──────────────────────────────┐    │
# │  └─────────────────────────┘  │   │ SELECT * FROM fields         │    │
# │             ↓                  │   │ JOIN field_photos            │    │
# │  ┌─────────────────────────┐  │   │ JOIN reviews                 │    │
# │  │ ดู:                     │←─┼───│ WHERE field_id = ?           │    │
# │  │ - รูปภาพทั้งหมด          │  │   └──────────────────────────────┘    │
# │  │ - รายละเอียดสนาม        │  │                ↓                       │
# │  │ - สิ่งอำนวยความสะดวก    │  │   ┌──────────────────────────────┐    │
# │  │ - Reviews & Ratings     │  │   │ แสดงข้อมูลครบถ้วน +          │    │
# │  │ - ช่วงเวลาว่าง          │  │   │ Available Time Slots         │    │
# │  │ - ราคา                  │  │   └──────────────────────────────┘    │
# │  └─────────────────────────┘  │                                        │
# │                                │                                        │
# │      ─── MAKE BOOKING ───                                              │
# │                                │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ เลือกวันที่ที่ต้องการ    │──┼─→ ┌──────────────────────────────┐    │
# │  └─────────────────────────┘  │   │ ดึง Available Time Slots     │    │
# │             ↓                  │   │ สำหรับวันที่นั้น              │    │
# │  ┌─────────────────────────┐  │   └──────────────────────────────┘    │
# │  │ เลือกช่วงเวลา            │──┼─→ ┌──────────────────────────────┐    │
# │  └─────────────────────────┘  │   │ Check Availability:          │    │
# │             ↓                  │   │ SELECT * FROM bookings       │    │
# │  ┌─────────────────────────┐  │   │ WHERE field_id=?             │    │
# │  │ เลือกอุปกรณ์ (ถ้าต้องการ)│──┼─→ │ AND date=? AND time_slot=?   │    │
# │  └─────────────────────────┘  │   └──────────────────────────────┘    │
# │             ↓                  │                ↓                       │
# │  ┌─────────────────────────┐  │   ┌──────────────────────────────┐    │
# │  │ ดูสรุปการจอง:           │←─┼───│ [Decision] Available?        │    │
# │  │ - สนาม: X               │  │   └──────────────────────────────┘    │
# │  │ - วันที่: Y             │  │         /              \               │
# │  │ - เวลา: Z               │  │       YES               NO              │
# │  │ - อุปกรณ์: ...          │  │        ↓                ↓              │
# │  │ - ราคารวม: XXX฿        │  │   ┌──────────┐   ┌─────────────────┐  │
# │  └─────────────────────────┘  │   │ คำนวณ    │   │ Error:          │  │
# │             ↓                  │   │ ราคารวม  │   │ "ช่วงนี้ถูกจอง"  │  │
# │  ┌─────────────────────────┐  │   └──────────┘   └─────────────────┘  │
# │  │ กรอก Promo Code (ถ้ามี) │──┼─→          ↓                           │
# │  └─────────────────────────┘  │   ┌──────────────────────────────┐    │
# │             ↓                  │   │ Validate Promo Code:         │    │
# │                                │   │ SELECT * FROM promotions     │    │
# │                                │   │ WHERE code=? AND active      │    │
# │                                │   └──────────────────────────────┘    │
# │                                │                ↓                       │
# │                                │   ┌──────────────────────────────┐    │
# │                                │   │ [Decision] Valid Code?       │    │
# │                                │   └──────────────────────────────┘    │
# │                                │         /              \               │
# │                                │       YES               NO              │
# │                                │        ↓                ↓              │
# │                                │   ┌──────────┐      Skip               │
# │  ┌─────────────────────────┐  │   │ Apply    │                         │
# │  │ ดูราคาหลังหักส่วนลด      │←─┼───│ Discount │                         │
# │  │ (ถ้ามี Promo)            │  │   └──────────┘                         │
# │  └─────────────────────────┘  │        ↓                               │
# │             ↓                  │   ┌──────────────────────────────┐    │
# │  ┌─────────────────────────┐  │   │ INSERT INTO bookings         │    │
# │  │ ยืนยันการจอง            │──┼─→ │ SET status='pending'         │    │
# │  └─────────────────────────┘  │   └──────────────────────────────┘    │
# │             ↓                  │                ↓                       │
# │  ┌─────────────────────────┐  │   ┌──────────────────────────────┐    │
# │  │ Redirect to Payment     │←─┼───│ Success + booking_id         │    │
# │  └─────────────────────────┘  │   └──────────────────────────────┘    │
# │                                │                                        │
# │      ─── MAKE PAYMENT ───                                              │
# │                                │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ เลือกวิธีชำระเงิน:       │──┼─→ ┌──────────────────────────────┐    │
# │  │ - QR Code (PromptPay)   │  │   │ [Decision] Payment Method?   │    │
# │  │ - Bank Transfer         │  │   └──────────────────────────────┘    │
# │  │ - Credit/Debit Card     │  │         /         |         \          │
# │  └─────────────────────────┘  │       QR       Transfer    Card        │
# │             ↓                  │        ↓          ↓          ↓         │
# │  ┌─────────────────────────┐  │   ┌──────────────────────────────┐    │
# │  │ สแกน QR / กรอกข้อมูล    │──┼─→ │ ส่งไป Payment Gateway        │    │
# │  │ บัตร                    │  │   │ (ดู UCD-007)                 │    │
# │  └─────────────────────────┘  │   └──────────────────────────────┘    │
# │             ↓                  │                ↓                       │
# │  ┌─────────────────────────┐  │   ┌──────────────────────────────┐    │
# │  │ รอการยืนยัน...          │  │   │ Process Payment              │    │
# │  └─────────────────────────┘  │   └──────────────────────────────┘    │
# │             ↓                  │                ↓                       │
# │  ┌─────────────────────────┐  │   ┌──────────────────────────────┐    │
# │  │ แสดงผลการชำระ:          │←─┼───│ [Decision] Success?          │    │
# │  │ - Success: "ชำระสำเร็จ"  │  │   └──────────────────────────────┘    │
# │  │ - Failed: "ล้มเหลว"     │  │         /              \               │
# │  │   พร้อมเหตุผล            │  │    Success           Failed            │
# │  └─────────────────────────┘  │        ↓                ↓              │
# │             ↓                  │   ┌──────────┐   ┌─────────────────┐  │
# │  ┌─────────────────────────┐  │   │ UPDATE   │   │ Error + Allow   │  │
# │  │ รับ Confirmation:       │←─┼───│ status=  │   │ Retry           │  │
# │  │ - Booking ID            │  │   │'approved'│   └─────────────────┘  │
# │  │ - ใบเสร็จ (PDF/Email)   │  │   └──────────┘                         │
# │  │ - Tracking # (ถ้ามีอุปกรณ์)│ │       ↓                               │
# │  └─────────────────────────┘  │   ┌──────────────────────────────┐    │
# │                                │   │ Send Confirmation Email/SMS  │    │
# │                                │   └──────────────────────────────┘    │
# │                                │                                        │
# │      ─── TRACK ORDER (Equipment Delivery) ───                          │
# │                                │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ เปิดหน้า "My Bookings"  │──┼─→ ┌──────────────────────────────┐    │
# │  └─────────────────────────┘  │   │ SELECT * FROM bookings       │    │
# │             ↓                  │   │ WHERE user_id = ?            │    │
# │  ┌─────────────────────────┐  │   └──────────────────────────────┘    │
# │  │ เลือก Booking ที่มีอุปกรณ์│──┼─→ ┌──────────────────────────────┐    │
# │  └─────────────────────────┘  │   │ SELECT * FROM deliveries     │    │
# │             ↓                  │   │ WHERE booking_id = ?         │    │
# │  ┌─────────────────────────┐  │   └──────────────────────────────┘    │
# │  │ คลิก "Track Delivery"   │──┼─→          ↓                           │
# │  └─────────────────────────┘  │   ┌──────────────────────────────┐    │
# │             ↓                  │   │ Query Logistic System        │    │
# │  ┌─────────────────────────┐  │   │ (ดู UCD-008)                 │    │
# │  │ ดูสถานะการส่ง:          │←─┼───└──────────────────────────────┘    │
# │  │ - Processing            │  │                ↓                       │
# │  │ - In-Transit (แสดงแผนที่)│  │   ┌──────────────────────────────┐    │
# │  │ - Delivered             │  │   │ แสดง Status + Timeline       │    │
# │  │ - Timeline              │  │   └──────────────────────────────┘    │
# │  └─────────────────────────┘  │                                        │
# │                                │                                        │
# │      ─── VIEW BOOKING HISTORY ───                                      │
# │                                │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ เข้าหน้า "My Bookings"  │──┼─→ ┌──────────────────────────────┐    │
# │  └─────────────────────────┘  │   │ SELECT b.*, f.field_name,    │    │
# │             ↓                  │   │ p.payment_status, d.status   │    │
# │  ┌─────────────────────────┐  │   │ FROM bookings b              │    │
# │  │ ดูรายการ:               │←─┼───│ JOIN fields f                │    │
# │  │ - Upcoming Bookings     │  │   │ LEFT JOIN payments p         │    │
# │  │ - Completed             │  │   │ LEFT JOIN deliveries d       │    │
# │  │ - Cancelled             │  │   │ WHERE b.user_id = ?          │    │
# │  └─────────────────────────┘  │   │ ORDER BY b.created_at DESC   │    │
# │             ↓                  │   └──────────────────────────────┘    │
# │  ┌─────────────────────────┐  │                                        │
# │  │ คลิกดูรายละเอียด         │──┼─→ ┌──────────────────────────────┐    │
# │  │ Booking                 │  │   │ แสดงข้อมูลครบถ้วน             │    │
# │  └─────────────────────────┘  │   └──────────────────────────────┘    │
# │             ↓                  │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ ดูตัวเลือก:             │  │                                        │
# │  │ - Download Receipt      │  │                                        │
# │  │ - Track Delivery        │  │                                        │
# │  │ - Cancel (ถ้าได้)        │  │                                        │
# │  │ - Rate & Review         │  │                                        │
# │  └─────────────────────────┘  │                                        │
# │                                │                                        │
# │      ─── CANCEL BOOKING ───                                            │
# │                                │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ เลือก Booking           │──┼─→ ┌──────────────────────────────┐    │
# │  │ ที่ต้องการยกเลิก         │  │   │ SELECT booking_date,         │    │
# │  └─────────────────────────┘  │   │ created_at, total_price      │    │
# │             ↓                  │   └──────────────────────────────┘    │
# │  ┌─────────────────────────┐  │                ↓                       │
# │  │ กด "Cancel Booking"     │──┼─→ ┌──────────────────────────────┐    │
# │  └─────────────────────────┘  │   │ คำนวณค่าปรับตาม Policy:      │    │
# │             ↓                  │   │ - >24h: คืน 100%             │    │
# │  ┌─────────────────────────┐  │   │ - <24h: คืน 50%              │    │
# │  │ ดู Cancellation Policy: │←─┼───│ - <6h: ไม่คืนเงิน             │    │
# │  │ "จะได้รับเงินคืน XXX฿"  │  │   └──────────────────────────────┘    │
# │  └─────────────────────────┘  │                ↓                       │
# │             ↓                  │   ┌──────────────────────────────┐    │
# │  ┌─────────────────────────┐  │   │ [Decision]                   │    │
# │  │ ยืนยันการยกเลิก          │──┼─→ │ Within Cancel Period?        │    │
# │  └─────────────────────────┘  │   └──────────────────────────────┘    │
# │                                │         /              \               │
# │                                │       YES               NO              │
# │                                │        ↓                ↓              │
# │                                │   ┌──────────┐   ┌─────────────────┐  │
# │                                │   │ UPDATE   │   │ Error: Cannot   │  │
# │                                │   │ bookings │   │ Cancel (Late)   │  │
# │                                │   │ status=  │   └─────────────────┘  │
# │                                │   │'canceled'│                         │
# │                                │   └──────────┘                         │
# │                                │        ↓                               │
# │                                │   ┌──────────────────────────────┐    │
# │                                │   │ Process Refund (ถ้ามี)        │    │
# │  ┌─────────────────────────┐  │   │ (ดู UCD-007)                 │    │
# │  │ แสดง Success            │←─┼───└──────────────────────────────┘    │
# │  │ "ยกเลิกสำเร็จ"           │  │                ↓                       │
# │  │ "จะได้รับเงินคืนภายใน... "│ │   ┌──────────────────────────────┐    │
# │  └─────────────────────────┘  │   │ Send Notification            │    │
# │                                │   └──────────────────────────────┘    │
# │                                │                                        │
# │      ─── RATE & REVIEW ───                                             │
# │                                │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ เลือก Completed Booking │──┼─→ ┌──────────────────────────────┐    │
# │  └─────────────────────────┘  │   │ Check if already reviewed    │    │
# │             ↓                  │   └──────────────────────────────┘    │
# │  ┌─────────────────────────┐  │                ↓                       │
# │  │ กด "Rate & Review"      │──┼─→ ┌──────────────────────────────┐    │
# │  └─────────────────────────┘  │   │ แสดงฟอร์ม Review             │    │
# │             ↓                  │   └──────────────────────────────┘    │
# │  ┌─────────────────────────┐  │                                        │
# │  │ ให้คะแนน (1-5 ⭐)        │  │                                        │
# │  │ เขียน Review            │  │                                        │
# │  │ แนบรูปภาพ (ถ้ามี)        │  │                                        │
# │  └─────────────────────────┘  │                                        │
# │             ↓                  │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ กด "Submit Review"      │──┼─→ ┌──────────────────────────────┐    │
# │  └─────────────────────────┘  │   │ INSERT INTO reviews          │    │
# │                                │   │ (booking_id, field_id,       │    │
# │                                │   │  rating, comment, photos)    │    │
# │                                │   └──────────────────────────────┘    │
# │                                │                ↓                       │
# │                                │   ┌──────────────────────────────┐    │
# │                                │   │ UPDATE fields                │    │
# │                                │   │ SET avg_rating = (           │    │
# │                                │   │   SELECT AVG(rating)...)     │    │
# │  ┌─────────────────────────┐  │   └──────────────────────────────┘    │
# │  │ แสดง Success            │←─┼──────────┌──────────────────────┐     │
# │  │ "ขอบคุณสำหรับ Review"   │  │          │ Success              │     │
# │  └─────────────────────────┘  │          └──────────────────────┘     │
# │                                │                                        │
# │      ─── CONTACT SUPPORT ───                                           │
# │                                │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ เข้าหน้า "Contact"      │──┼─→ ┌──────────────────────────────┐    │
# │  └─────────────────────────┘  │   │ แสดงฟอร์ม Contact           │    │
# │             ↓                  │   └──────────────────────────────┘    │
# │  ┌─────────────────────────┐  │                                        │
# │  │ เลือกประเภทคำถาม:        │  │                                        │
# │  │ - Booking Issues        │  │                                        │
# │  │ - Payment Problems      │  │                                        │
# │  │ - General Inquiry       │  │                                        │
# │  └─────────────────────────┘  │                                        │
# │             ↓                  │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ กรอก:                   │  │                                        │
# │  │ - Booking ID (ถ้ามี)     │  │                                        │
# │  │ - รายละเอียดปัญหา        │  │                                        │
# │  │ - แนบไฟล์ (ถ้ามี)        │  │                                        │
# │  └─────────────────────────┘  │                                        │
# │             ↓                  │                                        │
# │  ┌─────────────────────────┐  │                                        │
# │  │ กด "Send"               │──┼─→ ┌──────────────────────────────┐    │
# │  └─────────────────────────┘  │   │ INSERT INTO inquiries        │    │
# │                                │   │ SET status='pending'         │    │
# │                                │   └──────────────────────────────┘    │
# │                                │                ↓                       │
# │                                │   ┌──────────────────────────────┐    │
# │                                │   │ Notify Staff (Email)         │    │
# │  ┌─────────────────────────┐  │   └──────────────────────────────┘    │
# │  │ รับ Ticket Number       │←─┼──────────┌──────────────────────┐     │
# │  │ "Ticket #12345"         │  │          │ Success + Ticket ID  │     │
# │  │ "จะติดต่อกลับภายใน 24ชม."│ │          └──────────────────────┘     │
# │  └─────────────────────────┘  │                                        │
# │             ↓                  │                                        │
# │          ⚫ END                 │                                        │
# │                                │                                        │
# └────────────────────────────────┴────────────────────────────────────────┘
# ```
#
# ---
#
# ### **สรุป Activity Diagram UCD-009**
# ✅ **10 กระบวนการหลัก:**
# 1. **Browse & Search Fields:** ดูรายการ → Search/Filter → ดูรายละเอียดสนาม + Reviews + Available Slots
# 2. **Make Booking:** เลือกวันที่/เวลา → เลือกอุปกรณ์ → กรอก Promo Code → ยืนยัน → Redirect to Payment
# 3. **Make Payment:** เลือกวิธีชำระ → Process Payment (QR/Transfer/Card) → รับ Confirmation + Receipt
# 4. **Track Order:** เข้า My Bookings → เลือก Booking → Track Delivery Status (Real-time)
# 5. **View Booking History:** ดูรายการ (Upcoming/Completed/Cancelled) → ดูรายละเอียด → ตัวเลือก (Download/Track/Cancel/Review)
# 6. **Cancel Booking:** เลือก Booking → คำนวณค่าปรับ → ยืนยัน → Process Refund → แจ้งเตือน
# 7. **Rate & Review:** เลือก Completed Booking → ให้คะแนน + เขียน Review + แนบรูป → Submit → อัพเดท Field Rating
# 8. **Contact Support:** กรอกฟอร์ม → ส่ง Inquiry → รับ Ticket Number → แจ้ง Staff
# 9. **View Promotions:** ดูรายการโปรโมชั่น → ดูรายละเอียด → คัดลอก Code
# 10. **Download Receipt:** เลือก Booking → Generate PDF → Download
#
# ---

# %% [markdown]
# # Class diagram

# %% [markdown]
# <mxGraphModel dx="2494" dy="605" grid="1" gridSize="10" guides="1" tooltips="1" connect="1" arrows="1" fold="1" page="1" pageScale="1" pageWidth="1800" pageHeight="2400" math="0" shadow="0">
#   <root>
#     <mxCell id="0" />
#     <mxCell id="1" parent="0" />
#     <mxCell id="person" value="&lt;&lt;abstract&gt;&gt;&#xa;Person" style="swimlane;fontStyle=1;align=center;verticalAlign=top;childLayout=stackLayout;horizontal=1;startSize=40;horizontalStack=0;resizeParent=1;resizeParentMax=0;resizeLast=0;collapsible=1;marginBottom=0;fillColor=#dae8fc;strokeColor=#6c8ebf;fontFamily=Helvetica;fontSize=12;" parent="1" vertex="1">
#       <mxGeometry x="760" y="40" width="280" height="280" as="geometry" />
#     </mxCell>
#     <mxCell id="person-attrs" value="- personId : int {PK}&#xa;- firstName : String(100)&#xa;- lastName : String(100)&#xa;- email : String(100) {UK}&#xa;- phone : String(20)&#xa;- address : String(300)&#xa;- createdAt : Timestamp&#xa;- updatedAt : Timestamp" style="text;strokeColor=none;fillColor=none;align=left;verticalAlign=top;spacingLeft=4;spacingRight=4;overflow=hidden;rotatable=0;points=[[0,0.5],[1,0.5]];portConstraint=eastwest;" parent="person" vertex="1">
#       <mxGeometry y="40" width="280" height="120" as="geometry" />
#     </mxCell>
#     <mxCell id="person-line" value="" style="line;strokeWidth=1;fillColor=none;align=left;verticalAlign=middle;spacingTop=-1;spacingLeft=3;spacingRight=3;rotatable=0;labelPosition=right;points=[];portConstraint=eastwest;" parent="person" vertex="1">
#       <mxGeometry y="160" width="280" height="8" as="geometry" />
#     </mxCell>
#     <mxCell id="person-methods" value="+ getFullName() : String&#xa;+ validateEmail() : boolean&#xa;+ validatePhone() : boolean&#xa;+ getRole() : String {abstract}" style="text;strokeColor=none;fillColor=none;align=left;verticalAlign=top;spacingLeft=4;spacingRight=4;overflow=hidden;rotatable=0;points=[[0,0.5],[1,0.5]];portConstraint=eastwest;fontStyle=0" parent="person" vertex="1">
#       <mxGeometry y="168" width="280" height="112" as="geometry" />
#     </mxCell>
#     <mxCell id="account" value="Account" style="swimlane;fontStyle=1;align=center;verticalAlign=top;childLayout=stackLayout;horizontal=1;startSize=26;horizontalStack=0;resizeParent=1;resizeParentMax=0;resizeLast=0;collapsible=1;marginBottom=0;fillColor=#dae8fc;strokeColor=#6c8ebf;" parent="1" vertex="1">
#       <mxGeometry x="230" y="40" width="300" height="220" as="geometry" />
#     </mxCell>
#     <mxCell id="account-attrs" value="- accountId : int {PK}&#xa;- personId : int {FK}&#xa;- username : String(50) {UK}&#xa;- password : String(255)&#xa;- lastLogin : Timestamp&#xa;- isActive : boolean&#xa;- failedLoginAttempts : int" style="text;strokeColor=none;fillColor=none;align=left;verticalAlign=top;spacingLeft=4;spacingRight=4;overflow=hidden;rotatable=0;points=[[0,0.5],[1,0.5]];portConstraint=eastwest;" parent="account" vertex="1">
#       <mxGeometry y="26" width="300" height="104" as="geometry" />
#     </mxCell>
#     <mxCell id="account-line" value="" style="line;strokeWidth=1;fillColor=none;align=left;verticalAlign=middle;spacingTop=-1;spacingLeft=3;spacingRight=3;rotatable=0;labelPosition=right;points=[];portConstraint=eastwest;" parent="account" vertex="1">
#       <mxGeometry y="130" width="300" height="8" as="geometry" />
#     </mxCell>
#     <mxCell id="account-methods" value="+ authenticate(password) : boolean&#xa;+ changePassword(old, new) : boolean&#xa;+ resetPassword() : String&#xa;+ lockAccount() : void" style="text;strokeColor=none;fillColor=none;align=left;verticalAlign=top;spacingLeft=4;spacingRight=4;overflow=hidden;rotatable=0;points=[[0,0.5],[1,0.5]];portConstraint=eastwest;" parent="account" vertex="1">
#       <mxGeometry y="138" width="300" height="82" as="geometry" />
#     </mxCell>
#     <mxCell id="customer" value="Customer" style="swimlane;fontStyle=1;align=center;verticalAlign=top;childLayout=stackLayout;horizontal=1;startSize=26;horizontalStack=0;resizeParent=1;resizeParentMax=0;resizeLast=0;collapsible=1;marginBottom=0;fillColor=#d5e8d4;strokeColor=#82b366;" parent="1" vertex="1">
#       <mxGeometry x="400" y="320" width="280" height="240" as="geometry" />
#     </mxCell>
#     <mxCell id="customer-attrs" value="- customerId : int {PK}&#xa;- personId : int {FK}&#xa;- membershipLevel : String(20)&#xa;- loyaltyPoints : int&#xa;- totalBookings : int&#xa;- registrationDate : Date&#xa;- isVIP : boolean" style="text;strokeColor=none;fillColor=none;align=left;verticalAlign=top;spacingLeft=4;spacingRight=4;overflow=hidden;rotatable=0;points=[[0,0.5],[1,0.5]];portConstraint=eastwest;" parent="customer" vertex="1">
#       <mxGeometry y="26" width="280" height="104" as="geometry" />
#     </mxCell>
#     <mxCell id="customer-line" value="" style="line;strokeWidth=1;fillColor=none;align=left;verticalAlign=middle;spacingTop=-1;spacingLeft=3;spacingRight=3;rotatable=0;labelPosition=right;points=[];portConstraint=eastwest;" parent="customer" vertex="1">
#       <mxGeometry y="130" width="280" height="8" as="geometry" />
#     </mxCell>
#     <mxCell id="customer-methods" value="+ makeBooking() : Booking&#xa;+ cancelBooking(id) : boolean&#xa;+ viewBookingHistory() : List&#xa;+ addLoyaltyPoints(pts) : void&#xa;+ upgradeMembership() : boolean" style="text;strokeColor=none;fillColor=none;align=left;verticalAlign=top;spacingLeft=4;spacingRight=4;overflow=hidden;rotatable=0;points=[[0,0.5],[1,0.5]];portConstraint=eastwest;" parent="customer" vertex="1">
#       <mxGeometry y="138" width="280" height="102" as="geometry" />
#     </mxCell>
#     <mxCell id="employee" value="&lt;&lt;abstract&gt;&gt;&#xa;Employee" style="swimlane;fontStyle=1;align=center;verticalAlign=top;childLayout=stackLayout;horizontal=1;startSize=40;horizontalStack=0;resizeParent=1;resizeParentMax=0;resizeLast=0;collapsible=1;marginBottom=0;fillColor=#dae8fc;strokeColor=#6c8ebf;" parent="1" vertex="1">
#       <mxGeometry x="1120" y="320" width="280" height="240" as="geometry" />
#     </mxCell>
#     <mxCell id="employee-attrs" value="- employeeId : int {PK}&#xa;- personId : int {FK}&#xa;- employeeCode : String(15) {UK}&#xa;- department : String(50)&#xa;- position : String(50)&#xa;- salary : Decimal(10,2)&#xa;- hireDate : Date" style="text;strokeColor=none;fillColor=none;align=left;verticalAlign=top;spacingLeft=4;spacingRight=4;overflow=hidden;rotatable=0;points=[[0,0.5],[1,0.5]];portConstraint=eastwest;" parent="employee" vertex="1">
#       <mxGeometry y="40" width="280" height="104" as="geometry" />
#     </mxCell>
#     <mxCell id="employee-line" value="" style="line;strokeWidth=1;fillColor=none;align=left;verticalAlign=middle;spacingTop=-1;spacingLeft=3;spacingRight=3;rotatable=0;labelPosition=right;points=[];portConstraint=eastwest;" parent="employee" vertex="1">
#       <mxGeometry y="144" width="280" height="8" as="geometry" />
#     </mxCell>
#     <mxCell id="employee-methods" value="+ clockIn() : boolean&#xa;+ clockOut() : boolean&#xa;+ performDuty() : void {abstract}&#xa;+ getRole() : String" style="text;strokeColor=none;fillColor=none;align=left;verticalAlign=top;spacingLeft=4;spacingRight=4;overflow=hidden;rotatable=0;points=[[0,0.5],[1,0.5]];portConstraint=eastwest;" parent="employee" vertex="1">
#       <mxGeometry y="152" width="280" height="88" as="geometry" />
#     </mxCell>
#     <mxCell id="bookingstaff" value="BookingStaff" style="swimlane;fontStyle=1;align=center;verticalAlign=top;childLayout=stackLayout;horizontal=1;startSize=26;horizontalStack=0;resizeParent=1;resizeParentMax=0;resizeLast=0;collapsible=1;marginBottom=0;fillColor=#fff2cc;strokeColor=#d6b656;" parent="1" vertex="1">
#       <mxGeometry x="750" y="640" width="320" height="220" as="geometry" />
#     </mxCell>
#     <mxCell id="bookingstaff-attrs" value="- staffId : int {PK}&#xa;- employeeId : int {FK}&#xa;- shiftSchedule : String(50)&#xa;- bookingQuota : int&#xa;- performanceRating : Decimal(3,2)" style="text;strokeColor=none;fillColor=none;align=left;verticalAlign=top;spacingLeft=4;spacingRight=4;overflow=hidden;rotatable=0;points=[[0,0.5],[1,0.5]];portConstraint=eastwest;" parent="bookingstaff" vertex="1">
#       <mxGeometry y="26" width="320" height="84" as="geometry" />
#     </mxCell>
#     <mxCell id="bookingstaff-line" value="" style="line;strokeWidth=1;fillColor=none;align=left;verticalAlign=middle;spacingTop=-1;spacingLeft=3;spacingRight=3;rotatable=0;labelPosition=right;points=[];portConstraint=eastwest;" parent="bookingstaff" vertex="1">
#       <mxGeometry y="110" width="320" height="8" as="geometry" />
#     </mxCell>
#     <mxCell id="bookingstaff-methods" value="+ approveBooking(id) : boolean&#xa;+ rejectBooking(id, reason) : boolean&#xa;+ searchBookings(criteria) : List&#xa;+ updateBookingStatus(id, status) : boolean&#xa;+ assignField(bookingId, fieldId) : boolean" style="text;strokeColor=none;fillColor=none;align=left;verticalAlign=top;spacingLeft=4;spacingRight=4;overflow=hidden;rotatable=0;points=[[0,0.5],[1,0.5]];portConstraint=eastwest;" parent="bookingstaff" vertex="1">
#       <mxGeometry y="118" width="320" height="102" as="geometry" />
#     </mxCell>
#     <mxCell id="systemadmin" value="SystemAdmin" style="swimlane;fontStyle=1;align=center;verticalAlign=top;childLayout=stackLayout;horizontal=1;startSize=26;horizontalStack=0;resizeParent=1;resizeParentMax=0;resizeLast=0;collapsible=1;marginBottom=0;fillColor=#fff2cc;strokeColor=#d6b656;" parent="1" vertex="1">
#       <mxGeometry x="1120" y="640" width="280" height="220" as="geometry" />
#     </mxCell>
#     <mxCell id="systemadmin-attrs" value="- adminId : int {PK}&#xa;- employeeId : int {FK}&#xa;- accessLevel : int&#xa;- permissions : Text(500)&#xa;- lastBackup : Timestamp" style="text;strokeColor=none;fillColor=none;align=left;verticalAlign=top;spacingLeft=4;spacingRight=4;overflow=hidden;rotatable=0;points=[[0,0.5],[1,0.5]];portConstraint=eastwest;" parent="systemadmin" vertex="1">
#       <mxGeometry y="26" width="280" height="84" as="geometry" />
#     </mxCell>
#     <mxCell id="systemadmin-line" value="" style="line;strokeWidth=1;fillColor=none;align=left;verticalAlign=middle;spacingTop=-1;spacingLeft=3;spacingRight=3;rotatable=0;labelPosition=right;points=[];portConstraint=eastwest;" parent="systemadmin" vertex="1">
#       <mxGeometry y="110" width="280" height="8" as="geometry" />
#     </mxCell>
#     <mxCell id="systemadmin-methods" value="+ manageUsers() : void&#xa;+ manageFields() : void&#xa;+ systemMaintenance() : boolean&#xa;+ backupDatabase() : boolean&#xa;+ viewAuditLogs() : List" style="text;strokeColor=none;fillColor=none;align=left;verticalAlign=top;spacingLeft=4;spacingRight=4;overflow=hidden;rotatable=0;points=[[0,0.5],[1,0.5]];portConstraint=eastwest;" parent="systemadmin" vertex="1">
#       <mxGeometry y="118" width="280" height="102" as="geometry" />
#     </mxCell>
#     <mxCell id="accountingstaff" value="AccountingStaff" style="swimlane;fontStyle=1;align=center;verticalAlign=top;childLayout=stackLayout;horizontal=1;startSize=26;horizontalStack=0;resizeParent=1;resizeParentMax=0;resizeLast=0;collapsible=1;marginBottom=0;fillColor=#fff2cc;strokeColor=#d6b656;" parent="1" vertex="1">
#       <mxGeometry x="1450" y="640" width="300" height="220" as="geometry" />
#     </mxCell>
#     <mxCell id="accountingstaff-attrs" value="- accountingId : int {PK}&#xa;- employeeId : int {FK}&#xa;- financeAuthority : String(50)&#xa;- certification : String(100)&#xa;- approvalLimit : Decimal(12,2)" style="text;strokeColor=none;fillColor=none;align=left;verticalAlign=top;spacingLeft=4;spacingRight=4;overflow=hidden;rotatable=0;points=[[0,0.5],[1,0.5]];portConstraint=eastwest;" parent="accountingstaff" vertex="1">
#       <mxGeometry y="26" width="300" height="84" as="geometry" />
#     </mxCell>
#     <mxCell id="accountingstaff-line" value="" style="line;strokeWidth=1;fillColor=none;align=left;verticalAlign=middle;spacingTop=-1;spacingLeft=3;spacingRight=3;rotatable=0;labelPosition=right;points=[];portConstraint=eastwest;" parent="accountingstaff" vertex="1">
#       <mxGeometry y="110" width="300" height="8" as="geometry" />
#     </mxCell>
#     <mxCell id="accountingstaff-methods" value="+ generateInvoice(paymentId) : Invoice&#xa;+ processRefund(paymentId, amt) : boolean&#xa;+ reconcileTransactions() : Report&#xa;+ auditFinancialRecords() : Report&#xa;+ verifyPayment(paymentId) : boolean" style="text;strokeColor=none;fillColor=none;align=left;verticalAlign=top;spacingLeft=4;spacingRight=4;overflow=hidden;rotatable=0;points=[[0,0.5],[1,0.5]];portConstraint=eastwest;" parent="accountingstaff" vertex="1">
#       <mxGeometry y="118" width="300" height="102" as="geometry" />
#     </mxCell>
#     <mxCell id="managingdirector" value="ManagingDirector" style="swimlane;fontStyle=1;align=center;verticalAlign=top;childLayout=stackLayout;horizontal=1;startSize=26;horizontalStack=0;resizeParent=1;resizeParentMax=0;resizeLast=0;collapsible=1;marginBottom=0;fillColor=#e1d5e7;strokeColor=#9673a6;" parent="1" vertex="1">
#       <mxGeometry x="740" y="920" width="300" height="200" as="geometry" />
#     </mxCell>
#     <mxCell id="managingdirector-attrs" value="- directorId : int {PK}&#xa;- employeeId : int {FK}&#xa;- authorityLevel : int&#xa;- signatureLimit : Decimal(15,2)" style="text;strokeColor=none;fillColor=none;align=left;verticalAlign=top;spacingLeft=4;spacingRight=4;overflow=hidden;rotatable=0;points=[[0,0.5],[1,0.5]];portConstraint=eastwest;" parent="managingdirector" vertex="1">
#       <mxGeometry y="26" width="300" height="64" as="geometry" />
#     </mxCell>
#     <mxCell id="managingdirector-line" value="" style="line;strokeWidth=1;fillColor=none;align=left;verticalAlign=middle;spacingTop=-1;spacingLeft=3;spacingRight=3;rotatable=0;labelPosition=right;points=[];portConstraint=eastwest;" parent="managingdirector" vertex="1">
#       <mxGeometry y="90" width="300" height="8" as="geometry" />
#     </mxCell>
#     <mxCell id="managingdirector-methods" value="+ viewExecutiveDashboard() : Dashboard&#xa;+ viewReports(type, period) : Report&#xa;+ analyzeBusinessPerformance() : Analytics&#xa;+ approveDecisions(requestId) : boolean&#xa;+ setBusinessPolicies() : void" style="text;strokeColor=none;fillColor=none;align=left;verticalAlign=top;spacingLeft=4;spacingRight=4;overflow=hidden;rotatable=0;points=[[0,0.5],[1,0.5]];portConstraint=eastwest;" parent="managingdirector" vertex="1">
#       <mxGeometry y="98" width="300" height="102" as="geometry" />
#     </mxCell>
#     <mxCell id="marketingstaff" value="MarketingStaff" style="swimlane;fontStyle=1;align=center;verticalAlign=top;childLayout=stackLayout;horizontal=1;startSize=26;horizontalStack=0;resizeParent=1;resizeParentMax=0;resizeLast=0;collapsible=1;marginBottom=0;fillColor=#e1d5e7;strokeColor=#9673a6;" parent="1" vertex="1">
#       <mxGeometry x="1080" y="920" width="320" height="200" as="geometry" />
#     </mxCell>
#     <mxCell id="marketingstaff-attrs" value="- marketingId : int {PK}&#xa;- employeeId : int {FK}&#xa;- campaignAccess : String(100)&#xa;- targetRegion : String(50)&#xa;- activeCampaigns : int" style="text;strokeColor=none;fillColor=none;align=left;verticalAlign=top;spacingLeft=4;spacingRight=4;overflow=hidden;rotatable=0;points=[[0,0.5],[1,0.5]];portConstraint=eastwest;" parent="marketingstaff" vertex="1">
#       <mxGeometry y="26" width="320" height="74" as="geometry" />
#     </mxCell>
#     <mxCell id="marketingstaff-line" value="" style="line;strokeWidth=1;fillColor=none;align=left;verticalAlign=middle;spacingTop=-1;spacingLeft=3;spacingRight=3;rotatable=0;labelPosition=right;points=[];portConstraint=eastwest;" parent="marketingstaff" vertex="1">
#       <mxGeometry y="100" width="320" height="8" as="geometry" />
#     </mxCell>
#     <mxCell id="marketingstaff-methods" value="+ createCampaign(campaign) : boolean&#xa;+ analyzeTrends() : Analytics&#xa;+ generateSalesReport() : Report&#xa;+ trackCampaignPerformance(id) : Analytics&#xa;+ segmentCustomers() : List" style="text;strokeColor=none;fillColor=none;align=left;verticalAlign=top;spacingLeft=4;spacingRight=4;overflow=hidden;rotatable=0;points=[[0,0.5],[1,0.5]];portConstraint=eastwest;" parent="marketingstaff" vertex="1">
#       <mxGeometry y="108" width="320" height="92" as="geometry" />
#     </mxCell>
#     <mxCell id="field" value="Field" style="swimlane;fontStyle=1;align=center;verticalAlign=top;childLayout=stackLayout;horizontal=1;startSize=26;horizontalStack=0;resizeParent=1;resizeParentMax=0;resizeLast=0;collapsible=1;marginBottom=0;fillColor=#d5e8d4;strokeColor=#82b366;" parent="1" vertex="1">
#       <mxGeometry x="30" y="640" width="300" height="260" as="geometry" />
#     </mxCell>
#     <mxCell id="field-attrs" value="- fieldId : int {PK}&#xa;- fieldType : String(50)&#xa;- name : String(100) {UK}&#xa;- description : Text(2000)&#xa;- hourlyRate : Decimal(8,2)&#xa;- location : String(200)&#xa;- status : String(20)&#xa;- capacity : int&#xa;- operatingHours : String(50)" style="text;strokeColor=none;fillColor=none;align=left;verticalAlign=top;spacingLeft=4;spacingRight=4;overflow=hidden;rotatable=0;points=[[0,0.5],[1,0.5]];portConstraint=eastwest;" parent="field" vertex="1">
#       <mxGeometry y="26" width="300" height="134" as="geometry" />
#     </mxCell>
#     <mxCell id="field-line" value="" style="line;strokeWidth=1;fillColor=none;align=left;verticalAlign=middle;spacingTop=-1;spacingLeft=3;spacingRight=3;rotatable=0;labelPosition=right;points=[];portConstraint=eastwest;" parent="field" vertex="1">
#       <mxGeometry y="160" width="300" height="8" as="geometry" />
#     </mxCell>
#     <mxCell id="field-methods" value="+ isAvailable() : boolean&#xa;+ checkAvailability(date, time) : boolean&#xa;+ calculateRate(hours) : Decimal&#xa;+ updateStatus(status) : void&#xa;+ scheduleMaintenance(date) : void" style="text;strokeColor=none;fillColor=none;align=left;verticalAlign=top;spacingLeft=4;spacingRight=4;overflow=hidden;rotatable=0;points=[[0,0.5],[1,0.5]];portConstraint=eastwest;" parent="field" vertex="1">
#       <mxGeometry y="168" width="300" height="92" as="geometry" />
#     </mxCell>
#     <mxCell id="service" value="Service" style="swimlane;fontStyle=1;align=center;verticalAlign=top;childLayout=stackLayout;horizontal=1;startSize=26;horizontalStack=0;resizeParent=1;resizeParentMax=0;resizeLast=0;collapsible=1;marginBottom=0;fillColor=#d5e8d4;strokeColor=#82b366;" parent="1" vertex="1">
#       <mxGeometry x="30" y="960" width="300" height="200" as="geometry" />
#     </mxCell>
#     <mxCell id="service-attrs" value="- serviceId : int {PK}&#xa;- fieldId : int {FK}&#xa;- serviceName : String(100)&#xa;- servicePrice : Decimal(8,2)&#xa;- serviceDuration : int&#xa;- availability : boolean&#xa;- serviceCode : String(15) {UK}" style="text;strokeColor=none;fillColor=none;align=left;verticalAlign=top;spacingLeft=4;spacingRight=4;overflow=hidden;rotatable=0;points=[[0,0.5],[1,0.5]];portConstraint=eastwest;" parent="service" vertex="1">
#       <mxGeometry y="26" width="300" height="104" as="geometry" />
#     </mxCell>
#     <mxCell id="service-line" value="" style="line;strokeWidth=1;fillColor=none;align=left;verticalAlign=middle;spacingTop=-1;spacingLeft=3;spacingRight=3;rotatable=0;labelPosition=right;points=[];portConstraint=eastwest;" parent="service" vertex="1">
#       <mxGeometry y="130" width="300" height="8" as="geometry" />
#     </mxCell>
#     <mxCell id="service-methods" value="+ getServiceInfo() : ServiceInfo&#xa;+ updatePrice(newPrice) : void&#xa;+ checkAvailability() : boolean&#xa;+ applyDiscount(discount) : Decimal" style="text;strokeColor=none;fillColor=none;align=left;verticalAlign=top;spacingLeft=4;spacingRight=4;overflow=hidden;rotatable=0;points=[[0,0.5],[1,0.5]];portConstraint=eastwest;" parent="service" vertex="1">
#       <mxGeometry y="138" width="300" height="62" as="geometry" />
#     </mxCell>
#     <mxCell id="booking" value="Booking" style="swimlane;fontStyle=1;align=center;verticalAlign=top;childLayout=stackLayout;horizontal=1;startSize=26;horizontalStack=0;resizeParent=1;resizeParentMax=0;resizeLast=0;collapsible=1;marginBottom=0;fillColor=#d5e8d4;strokeColor=#82b366;" parent="1" vertex="1">
#       <mxGeometry x="400" y="640" width="300" height="280" as="geometry" />
#     </mxCell>
#     <mxCell id="booking-attrs" value="- bookingId : int {PK}&#xa;- customerId : int {FK}&#xa;- fieldId : int {FK}&#xa;- staffId : int {FK}&#xa;- bookingRef : String(20) {UK}&#xa;- bookingDate : Date&#xa;- startTime : Time&#xa;- endTime : Time&#xa;- status : String(20)&#xa;- totalAmount : Decimal(10,2)&#xa;- paymentStatus : String(20)" style="text;strokeColor=none;fillColor=none;align=left;verticalAlign=top;spacingLeft=4;spacingRight=4;overflow=hidden;rotatable=0;points=[[0,0.5],[1,0.5]];portConstraint=eastwest;" parent="booking" vertex="1">
#       <mxGeometry y="26" width="300" height="164" as="geometry" />
#     </mxCell>
#     <mxCell id="booking-line" value="" style="line;strokeWidth=1;fillColor=none;align=left;verticalAlign=middle;spacingTop=-1;spacingLeft=3;spacingRight=3;rotatable=0;labelPosition=right;points=[];portConstraint=eastwest;" parent="booking" vertex="1">
#       <mxGeometry y="190" width="300" height="8" as="geometry" />
#     </mxCell>
#     <mxCell id="booking-methods" value="+ calculateTotalAmount() : Decimal&#xa;+ validateBookingTime() : boolean&#xa;+ confirm() : boolean&#xa;+ cancel() : boolean&#xa;+ generateBookingRef() : String" style="text;strokeColor=none;fillColor=none;align=left;verticalAlign=top;spacingLeft=4;spacingRight=4;overflow=hidden;rotatable=0;points=[[0,0.5],[1,0.5]];portConstraint=eastwest;" parent="booking" vertex="1">
#       <mxGeometry y="198" width="300" height="82" as="geometry" />
#     </mxCell>
#     <mxCell id="bookingdetail" value="BookingDetail" style="swimlane;fontStyle=1;align=center;verticalAlign=top;childLayout=stackLayout;horizontal=1;startSize=26;horizontalStack=0;resizeParent=1;resizeParentMax=0;resizeLast=0;collapsible=1;marginBottom=0;fillColor=#d5e8d4;strokeColor=#82b366;" parent="1" vertex="1">
#       <mxGeometry x="30" y="1240" width="300" height="200" as="geometry" />
#     </mxCell>
#     <mxCell id="bookingdetail-attrs" value="- detailId : int {PK}&#xa;- bookingId : int {FK}&#xa;- serviceId : int {FK}&#xa;- quantity : int&#xa;- unitPrice : Decimal(8,2)&#xa;- subtotal : Decimal(10,2)&#xa;- discount : Decimal(5,2)" style="text;strokeColor=none;fillColor=none;align=left;verticalAlign=top;spacingLeft=4;spacingRight=4;overflow=hidden;rotatable=0;points=[[0,0.5],[1,0.5]];portConstraint=eastwest;" parent="bookingdetail" vertex="1">
#       <mxGeometry y="26" width="300" height="104" as="geometry" />
#     </mxCell>
#     <mxCell id="bookingdetail-line" value="" style="line;strokeWidth=1;fillColor=none;align=left;verticalAlign=middle;spacingTop=-1;spacingLeft=3;spacingRight=3;rotatable=0;labelPosition=right;points=[];portConstraint=eastwest;" parent="bookingdetail" vertex="1">
#       <mxGeometry y="130" width="300" height="8" as="geometry" />
#     </mxCell>
#     <mxCell id="bookingdetail-methods" value="+ calculateSubtotal() : Decimal&#xa;+ validateQuantity() : boolean&#xa;+ applyDiscount(discount) : void" style="text;strokeColor=none;fillColor=none;align=left;verticalAlign=top;spacingLeft=4;spacingRight=4;overflow=hidden;rotatable=0;points=[[0,0.5],[1,0.5]];portConstraint=eastwest;" parent="bookingdetail" vertex="1">
#       <mxGeometry y="138" width="300" height="62" as="geometry" />
#     </mxCell>
#     <mxCell id="payment" value="Payment" style="swimlane;fontStyle=1;align=center;verticalAlign=top;childLayout=stackLayout;horizontal=1;startSize=26;horizontalStack=0;resizeParent=1;resizeParentMax=0;resizeLast=0;collapsible=1;marginBottom=0;fillColor=#ffe6cc;strokeColor=#d79b00;" parent="1" vertex="1">
#       <mxGeometry x="720" y="1180" width="300" height="260" as="geometry" />
#     </mxCell>
#     <mxCell id="payment-attrs" value="- paymentId : int {PK}&#xa;- bookingId : int {FK}&#xa;- gatewayId : int {FK}&#xa;- transactionId : String(100) {UK}&#xa;- paymentMethod : String(30)&#xa;- amount : Decimal(10,2)&#xa;- paymentStatus : String(20)&#xa;- paymentDate : Timestamp&#xa;- receiptNumber : String(25) {UK}" style="text;strokeColor=none;fillColor=none;align=left;verticalAlign=top;spacingLeft=4;spacingRight=4;overflow=hidden;rotatable=0;points=[[0,0.5],[1,0.5]];portConstraint=eastwest;" parent="payment" vertex="1">
#       <mxGeometry y="26" width="300" height="134" as="geometry" />
#     </mxCell>
#     <mxCell id="payment-line" value="" style="line;strokeWidth=1;fillColor=none;align=left;verticalAlign=middle;spacingTop=-1;spacingLeft=3;spacingRight=3;rotatable=0;labelPosition=right;points=[];portConstraint=eastwest;" parent="payment" vertex="1">
#       <mxGeometry y="160" width="300" height="8" as="geometry" />
#     </mxCell>
#     <mxCell id="payment-methods" value="+ processPayment() : boolean&#xa;+ verifyPayment() : boolean&#xa;+ refund(amount) : boolean&#xa;+ generateReceipt() : Receipt&#xa;+ generateTransactionId() : String" style="text;strokeColor=none;fillColor=none;align=left;verticalAlign=top;spacingLeft=4;spacingRight=4;overflow=hidden;rotatable=0;points=[[0,0.5],[1,0.5]];portConstraint=eastwest;" parent="payment" vertex="1">
#       <mxGeometry y="168" width="300" height="92" as="geometry" />
#     </mxCell>
#     <mxCell id="paymentgateway" value="PaymentGateway" style="swimlane;fontStyle=1;align=center;verticalAlign=top;childLayout=stackLayout;horizontal=1;startSize=26;horizontalStack=0;resizeParent=1;resizeParentMax=0;resizeLast=0;collapsible=1;marginBottom=0;fillColor=#ffe6cc;strokeColor=#d79b00;" parent="1" vertex="1">
#       <mxGeometry x="1090" y="1180" width="320" height="240" as="geometry" />
#     </mxCell>
#     <mxCell id="paymentgateway-attrs" value="- gatewayId : int {PK}&#xa;- gatewayName : String(50)&#xa;- gatewayCode : String(10) {UK}&#xa;- apiEndpoint : String(200)&#xa;- apiKey : String(100)&#xa;- isActive : boolean&#xa;- commissionRate : Decimal(5,4)&#xa;- timeout : int" style="text;strokeColor=none;fillColor=none;align=left;verticalAlign=top;spacingLeft=4;spacingRight=4;overflow=hidden;rotatable=0;points=[[0,0.5],[1,0.5]];portConstraint=eastwest;" parent="paymentgateway" vertex="1">
#       <mxGeometry y="26" width="320" height="124" as="geometry" />
#     </mxCell>
#     <mxCell id="paymentgateway-line" value="" style="line;strokeWidth=1;fillColor=none;align=left;verticalAlign=middle;spacingTop=-1;spacingLeft=3;spacingRight=3;rotatable=0;labelPosition=right;points=[];portConstraint=eastwest;" parent="paymentgateway" vertex="1">
#       <mxGeometry y="150" width="320" height="8" as="geometry" />
#     </mxCell>
#     <mxCell id="paymentgateway-methods" value="+ initializePayment(payment) : String&#xa;+ confirmPayment(txnId) : Result&#xa;+ processRefund(txnId, amt) : Result&#xa;+ validateTransaction(txnId) : boolean" style="text;strokeColor=none;fillColor=none;align=left;verticalAlign=top;spacingLeft=4;spacingRight=4;overflow=hidden;rotatable=0;points=[[0,0.5],[1,0.5]];portConstraint=eastwest;" parent="paymentgateway" vertex="1">
#       <mxGeometry y="158" width="320" height="82" as="geometry" />
#     </mxCell>
#     <mxCell id="invoice" value="Invoice" style="swimlane;fontStyle=1;align=center;verticalAlign=top;childLayout=stackLayout;horizontal=1;startSize=26;horizontalStack=0;resizeParent=1;resizeParentMax=0;resizeLast=0;collapsible=1;marginBottom=0;fillColor=#ffe6cc;strokeColor=#d79b00;" parent="1" vertex="1">
#       <mxGeometry x="740" y="1500" width="300" height="240" as="geometry" />
#     </mxCell>
#     <mxCell id="invoice-attrs" value="- invoiceId : int {PK}&#xa;- paymentId : int {FK}&#xa;- accountingId : int {FK}&#xa;- invoiceNumber : String(20) {UK}&#xa;- issueDate : Date&#xa;- dueDate : Date&#xa;- totalAmount : Decimal(10,2)&#xa;- taxAmount : Decimal(8,2)&#xa;- invoiceStatus : String(20)" style="text;strokeColor=none;fillColor=none;align=left;verticalAlign=top;spacingLeft=4;spacingRight=4;overflow=hidden;rotatable=0;points=[[0,0.5],[1,0.5]];portConstraint=eastwest;" parent="invoice" vertex="1">
#       <mxGeometry y="26" width="300" height="134" as="geometry" />
#     </mxCell>
#     <mxCell id="invoice-line" value="" style="line;strokeWidth=1;fillColor=none;align=left;verticalAlign=middle;spacingTop=-1;spacingLeft=3;spacingRight=3;rotatable=0;labelPosition=right;points=[];portConstraint=eastwest;" parent="invoice" vertex="1">
#       <mxGeometry y="160" width="300" height="8" as="geometry" />
#     </mxCell>
#     <mxCell id="invoice-methods" value="+ generateInvoiceNumber() : String&#xa;+ calculateTax(rate) : Decimal&#xa;+ sendInvoice(email) : boolean&#xa;+ markAsPaid() : void" style="text;strokeColor=none;fillColor=none;align=left;verticalAlign=top;spacingLeft=4;spacingRight=4;overflow=hidden;rotatable=0;points=[[0,0.5],[1,0.5]];portConstraint=eastwest;" parent="invoice" vertex="1">
#       <mxGeometry y="168" width="300" height="72" as="geometry" />
#     </mxCell>
#     <mxCell id="logistic" value="Logistic" style="swimlane;fontStyle=1;align=center;verticalAlign=top;childLayout=stackLayout;horizontal=1;startSize=26;horizontalStack=0;resizeParent=1;resizeParentMax=0;resizeLast=0;collapsible=1;marginBottom=0;fillColor=#f8cecc;strokeColor=#b85450;" parent="1" vertex="1">
#       <mxGeometry x="1110" y="1520" width="300" height="220" as="geometry" />
#     </mxCell>
#     <mxCell id="logistic-attrs" value="- logisticId : int {PK}&#xa;- bookingId : int {FK}&#xa;- trackingNumber : String(25) {UK}&#xa;- deliveryAddress : String(300)&#xa;- deliveryStatus : String(20)&#xa;- courierInfo : String(100)&#xa;- estimatedDelivery : Timestamp&#xa;- actualDelivery : Timestamp" style="text;strokeColor=none;fillColor=none;align=left;verticalAlign=top;spacingLeft=4;spacingRight=4;overflow=hidden;rotatable=0;points=[[0,0.5],[1,0.5]];portConstraint=eastwest;" parent="logistic" vertex="1">
#       <mxGeometry y="26" width="300" height="114" as="geometry" />
#     </mxCell>
#     <mxCell id="logistic-line" value="" style="line;strokeWidth=1;fillColor=none;align=left;verticalAlign=middle;spacingTop=-1;spacingLeft=3;spacingRight=3;rotatable=0;labelPosition=right;points=[];portConstraint=eastwest;" parent="logistic" vertex="1">
#       <mxGeometry y="140" width="300" height="8" as="geometry" />
#     </mxCell>
#     <mxCell id="logistic-methods" value="+ generateTrackingNumber() : String&#xa;+ updateStatus(status) : void&#xa;+ trackDelivery() : TrackingInfo&#xa;+ confirmDelivery(signature) : boolean&#xa;+ sendNotification() : void" style="text;strokeColor=none;fillColor=none;align=left;verticalAlign=top;spacingLeft=4;spacingRight=4;overflow=hidden;rotatable=0;points=[[0,0.5],[1,0.5]];portConstraint=eastwest;" parent="logistic" vertex="1">
#       <mxGeometry y="148" width="300" height="72" as="geometry" />
#     </mxCell>
#     <mxCell id="report" value="Report" style="swimlane;fontStyle=1;align=center;verticalAlign=top;childLayout=stackLayout;horizontal=1;startSize=26;horizontalStack=0;resizeParent=1;resizeParentMax=0;resizeLast=0;collapsible=1;marginBottom=0;fillColor=#e1d5e7;strokeColor=#9673a6;" parent="1" vertex="1">
#       <mxGeometry x="1460" y="920" width="300" height="220" as="geometry" />
#     </mxCell>
#     <mxCell id="report-attrs" value="- reportId : int {PK}&#xa;- reportType : String(50)&#xa;- reportName : String(100)&#xa;- generatedBy : int {FK}&#xa;- reportPeriod : String(50)&#xa;- startDate : Date&#xa;- endDate : Date&#xa;- filePath : String(500)" style="text;strokeColor=none;fillColor=none;align=left;verticalAlign=top;spacingLeft=4;spacingRight=4;overflow=hidden;rotatable=0;points=[[0,0.5],[1,0.5]];portConstraint=eastwest;" parent="report" vertex="1">
#       <mxGeometry y="26" width="300" height="114" as="geometry" />
#     </mxCell>
#     <mxCell id="report-line" value="" style="line;strokeWidth=1;fillColor=none;align=left;verticalAlign=middle;spacingTop=-1;spacingLeft=3;spacingRight=3;rotatable=0;labelPosition=right;points=[];portConstraint=eastwest;" parent="report" vertex="1">
#       <mxGeometry y="140" width="300" height="8" as="geometry" />
#     </mxCell>
#     <mxCell id="report-methods" value="+ generateReport() : boolean&#xa;+ exportToExcel() : File&#xa;+ exportToPDF() : File&#xa;+ sendByEmail(email) : boolean" style="text;strokeColor=none;fillColor=none;align=left;verticalAlign=top;spacingLeft=4;spacingRight=4;overflow=hidden;rotatable=0;points=[[0,0.5],[1,0.5]];portConstraint=eastwest;" parent="report" vertex="1">
#       <mxGeometry y="148" width="300" height="72" as="geometry" />
#     </mxCell>
#     <mxCell id="campaign" value="Campaign" style="swimlane;fontStyle=1;align=center;verticalAlign=top;childLayout=stackLayout;horizontal=1;startSize=26;horizontalStack=0;resizeParent=1;resizeParentMax=0;resizeLast=0;collapsible=1;marginBottom=0;fillColor=#e1d5e7;strokeColor=#9673a6;" parent="1" vertex="1">
#       <mxGeometry x="1460" y="1180" width="300" height="240" as="geometry" />
#     </mxCell>
#     <mxCell id="campaign-attrs" value="- campaignId : int {PK}&#xa;- marketingId : int {FK}&#xa;- campaignName : String(100)&#xa;- campaignType : String(50)&#xa;- budget : Decimal(10,2)&#xa;- startDate : Date&#xa;- endDate : Date&#xa;- status : String(20)&#xa;- impressions : int&#xa;- conversions : int" style="text;strokeColor=none;fillColor=none;align=left;verticalAlign=top;spacingLeft=4;spacingRight=4;overflow=hidden;rotatable=0;points=[[0,0.5],[1,0.5]];portConstraint=eastwest;" parent="campaign" vertex="1">
#       <mxGeometry y="26" width="300" height="144" as="geometry" />
#     </mxCell>
#     <mxCell id="campaign-line" value="" style="line;strokeWidth=1;fillColor=none;align=left;verticalAlign=middle;spacingTop=-1;spacingLeft=3;spacingRight=3;rotatable=0;labelPosition=right;points=[];portConstraint=eastwest;" parent="campaign" vertex="1">
#       <mxGeometry y="170" width="300" height="8" as="geometry" />
#     </mxCell>
#     <mxCell id="campaign-methods" value="+ launch() : boolean&#xa;+ pause() : boolean&#xa;+ trackPerformance() : Analytics&#xa;+ calculateROI() : Decimal" style="text;strokeColor=none;fillColor=none;align=left;verticalAlign=top;spacingLeft=4;spacingRight=4;overflow=hidden;rotatable=0;points=[[0,0.5],[1,0.5]];portConstraint=eastwest;" parent="campaign" vertex="1">
#       <mxGeometry y="178" width="300" height="62" as="geometry" />
#     </mxCell>
#     <mxCell id="auditlog" value="AuditLog" style="swimlane;fontStyle=1;align=center;verticalAlign=top;childLayout=stackLayout;horizontal=1;startSize=26;horizontalStack=0;resizeParent=1;resizeParentMax=0;resizeLast=0;collapsible=1;marginBottom=0;fillColor=#f5f5f5;strokeColor=#666666;" parent="1" vertex="1">
#       <mxGeometry x="30" y="1460" width="300" height="200" as="geometry" />
#     </mxCell>
#     <mxCell id="auditlog-attrs" value="- logId : int {PK}&#xa;- customerId : int {FK}&#xa;- action : String(100)&#xa;- tableName : String(50)&#xa;- recordId : int&#xa;- oldValue : Text(2000)&#xa;- newValue : Text(2000)&#xa;- timestamp : Timestamp" style="text;strokeColor=none;fillColor=none;align=left;verticalAlign=top;spacingLeft=4;spacingRight=4;overflow=hidden;rotatable=0;points=[[0,0.5],[1,0.5]];portConstraint=eastwest;" parent="auditlog" vertex="1">
#       <mxGeometry y="26" width="300" height="114" as="geometry" />
#     </mxCell>
#     <mxCell id="auditlog-line" value="" style="line;strokeWidth=1;fillColor=none;align=left;verticalAlign=middle;spacingTop=-1;spacingLeft=3;spacingRight=3;rotatable=0;labelPosition=right;points=[];portConstraint=eastwest;" parent="auditlog" vertex="1">
#       <mxGeometry y="140" width="300" height="8" as="geometry" />
#     </mxCell>
#     <mxCell id="auditlog-methods" value="+ logAction(action, data) : void&#xa;+ getHistory(recordId) : List&#xa;+ searchLogs(criteria) : List" style="text;strokeColor=none;fillColor=none;align=left;verticalAlign=top;spacingLeft=4;spacingRight=4;overflow=hidden;rotatable=0;points=[[0,0.5],[1,0.5]];portConstraint=eastwest;" parent="auditlog" vertex="1">
#       <mxGeometry y="148" width="300" height="52" as="geometry" />
#     </mxCell>
#     <mxCell id="inherit-person-customer" value="" style="endArrow=block;endSize=16;endFill=0;html=1;entryX=-0.009;entryY=0.286;entryDx=0;entryDy=0;strokeWidth=2;entryPerimeter=0;exitX=0.569;exitY=0.007;exitDx=0;exitDy=0;exitPerimeter=0;" parent="1" source="customer" target="person-methods" edge="1">
#       <mxGeometry width="160" relative="1" as="geometry">
#         <mxPoint x="560" y="390" as="sourcePoint" />
#         <mxPoint x="830" y="330" as="targetPoint" />
#         <Array as="points">
#           <mxPoint x="560" y="240" />
#         </Array>
#       </mxGeometry>
#     </mxCell>
#     <mxCell id="inherit-employee-bookingstaff" value="" style="endArrow=block;endSize=16;endFill=0;html=1;exitX=0.5;exitY=0;exitDx=0;exitDy=0;entryX=0;entryY=0.5;entryDx=0;entryDy=0;strokeWidth=2;" parent="1" source="bookingstaff" target="employee-methods" edge="1">
#       <mxGeometry width="160" relative="1" as="geometry">
#         <mxPoint x="760" y="700" as="sourcePoint" />
#         <mxPoint x="1176" y="650" as="targetPoint" />
#         <Array as="points">
#           <mxPoint x="910" y="516" />
#         </Array>
#       </mxGeometry>
#     </mxCell>
#     <mxCell id="inherit-employee-systemadmin" value="" style="endArrow=block;endSize=16;endFill=0;html=1;exitX=0.5;exitY=0;exitDx=0;exitDy=0;entryX=0.5;entryY=1;entryDx=0;entryDy=0;strokeWidth=2;" parent="1" source="systemadmin" target="employee" edge="1">
#       <mxGeometry width="160" relative="1" as="geometry">
#         <mxPoint x="1100" y="700" as="sourcePoint" />
#         <mxPoint x="1260" y="650" as="targetPoint" />
#       </mxGeometry>
#     </mxCell>
#     <mxCell id="inherit-employee-accountingstaff" value="" style="endArrow=block;endSize=16;endFill=0;html=1;entryX=1;entryY=0.5;entryDx=0;entryDy=0;strokeWidth=2;exitX=0.533;exitY=-0.003;exitDx=0;exitDy=0;exitPerimeter=0;" parent="1" source="accountingstaff" target="employee-methods" edge="1">
#       <mxGeometry width="160" relative="1" as="geometry">
#         <mxPoint x="1600" y="630" as="sourcePoint" />
#         <mxPoint x="1344" y="650" as="targetPoint" />
#         <Array as="points">
#           <mxPoint x="1610" y="520" />
#         </Array>
#       </mxGeometry>
#     </mxCell>
#     <mxCell id="inherit-employee-managingdirector" value="" style="endArrow=block;endSize=16;endFill=0;html=1;exitX=0.5;exitY=0;exitDx=0;exitDy=0;entryX=0.5;entryY=1;entryDx=0;entryDy=0;strokeWidth=1;dashed=1;" parent="1" source="managingdirector" target="employee" edge="1">
#       <mxGeometry width="160" relative="1" as="geometry">
#         <mxPoint x="1110" y="980" as="sourcePoint" />
#         <mxPoint x="1260" y="660" as="targetPoint" />
#         <Array as="points">
#           <mxPoint x="890" y="880" />
#           <mxPoint x="1110" y="880" />
#           <mxPoint x="1110" y="600" />
#           <mxPoint x="1110" y="580" />
#           <mxPoint x="1220" y="580" />
#           <mxPoint x="1220" y="560" />
#         </Array>
#       </mxGeometry>
#     </mxCell>
#     <mxCell id="inherit-employee-marketingstaff" value="" style="endArrow=block;endSize=16;endFill=0;html=1;exitX=0.5;exitY=0;exitDx=0;exitDy=0;entryX=0.9;entryY=1;entryDx=0;entryDy=0;strokeWidth=1;dashed=1;" parent="1" source="marketingstaff" target="employee" edge="1">
#       <mxGeometry width="160" relative="1" as="geometry">
#         <mxPoint x="1480" y="980" as="sourcePoint" />
#         <mxPoint x="1372" y="650" as="targetPoint" />
#         <Array as="points">
#           <mxPoint x="1240" y="890" />
#           <mxPoint x="1410" y="890" />
#           <mxPoint x="1410" y="730" />
#           <mxPoint x="1410" y="590" />
#           <mxPoint x="1370" y="590" />
#         </Array>
#       </mxGeometry>
#     </mxCell>
#     <mxCell id="assoc-person-account" value="has" style="endArrow=diamondThin;endFill=1;endSize=24;html=1;strokeWidth=2;exitX=-0.009;exitY=0.653;exitDx=0;exitDy=0;exitPerimeter=0;entryX=0.991;entryY=0.919;entryDx=0;entryDy=0;entryPerimeter=0;" parent="1" source="person-attrs" target="account-attrs" edge="1">
#       <mxGeometry width="160" relative="1" as="geometry">
#         <mxPoint x="760" y="150" as="sourcePoint" />
#         <mxPoint x="510" y="150" as="targetPoint" />
#       </mxGeometry>
#     </mxCell>
#     <mxCell id="assoc-person-account-mult-1" value="1" style="edgeLabel;html=1;align=center;verticalAlign=middle;resizable=0;points=[];fontSize=14;fontStyle=1" parent="assoc-person-account" vertex="1" connectable="0">
#       <mxGeometry x="-0.75" y="2" relative="1" as="geometry">
#         <mxPoint x="-8" y="-12" as="offset" />
#       </mxGeometry>
#     </mxCell>
#     <mxCell id="assoc-person-account-mult-2" value="1" style="edgeLabel;html=1;align=center;verticalAlign=middle;resizable=0;points=[];fontSize=14;fontStyle=1" parent="assoc-person-account" vertex="1" connectable="0">
#       <mxGeometry x="0.75" y="1" relative="1" as="geometry">
#         <mxPoint x="8" y="-12" as="offset" />
#       </mxGeometry>
#     </mxCell>
#     <mxCell id="assoc-customer-booking" value="makes" style="endArrow=open;endFill=1;endSize=12;html=1;exitX=0.5;exitY=1;exitDx=0;exitDy=0;entryX=0.469;entryY=-0.003;entryDx=0;entryDy=0;strokeWidth=2;entryPerimeter=0;" parent="1" source="customer" target="booking" edge="1">
#       <mxGeometry width="160" relative="1" as="geometry">
#         <mxPoint x="540" y="660" as="sourcePoint" />
#         <mxPoint x="475" y="1260" as="targetPoint" />
#         <Array as="points">
#           <mxPoint x="540" y="600" />
#           <mxPoint x="540" y="610" />
#         </Array>
#       </mxGeometry>
#     </mxCell>
#     <mxCell id="assoc-customer-booking-mult-1" value="1" style="edgeLabel;html=1;align=center;verticalAlign=middle;resizable=0;points=[];fontSize=14;fontStyle=1" parent="assoc-customer-booking" vertex="1" connectable="0">
#       <mxGeometry x="-0.85" y="2" relative="1" as="geometry">
#         <mxPoint x="-15" y="10" as="offset" />
#       </mxGeometry>
#     </mxCell>
#     <mxCell id="assoc-customer-booking-mult-2" value="0..*" style="edgeLabel;html=1;align=center;verticalAlign=middle;resizable=0;points=[];fontSize=14;fontStyle=1" parent="assoc-customer-booking" vertex="1" connectable="0">
#       <mxGeometry x="0.85" y="1" relative="1" as="geometry">
#         <mxPoint x="15" y="-10" as="offset" />
#       </mxGeometry>
#     </mxCell>
#     <mxCell id="assoc-bookingstaff-booking" value="manages" style="endArrow=open;endFill=1;endSize=12;html=1;exitX=0;exitY=0.5;exitDx=0;exitDy=0;strokeWidth=1;dashed=1;" parent="1" source="bookingstaff" edge="1">
#       <mxGeometry width="160" relative="1" as="geometry">
#         <mxPoint x="590" y="830" as="sourcePoint" />
#         <mxPoint x="639" y="640" as="targetPoint" />
#         <Array as="points">
#           <mxPoint x="720" y="750" />
#           <mxPoint x="720" y="600" />
#           <mxPoint x="640" y="600" />
#         </Array>
#       </mxGeometry>
#     </mxCell>
#     <mxCell id="assoc-bookingstaff-booking-mult-1" value="1" style="edgeLabel;html=1;align=center;verticalAlign=middle;resizable=0;points=[];fontSize=14;fontStyle=1" parent="assoc-bookingstaff-booking" vertex="1" connectable="0">
#       <mxGeometry x="-0.85" y="2" relative="1" as="geometry">
#         <mxPoint x="15" y="10" as="offset" />
#       </mxGeometry>
#     </mxCell>
#     <mxCell id="assoc-bookingstaff-booking-mult-2" value="0..*" style="edgeLabel;html=1;align=center;verticalAlign=middle;resizable=0;points=[];fontSize=14;fontStyle=1" parent="assoc-bookingstaff-booking" vertex="1" connectable="0">
#       <mxGeometry x="0.85" y="1" relative="1" as="geometry">
#         <mxPoint x="-15" y="-10" as="offset" />
#       </mxGeometry>
#     </mxCell>
#     <mxCell id="assoc-field-booking" value="hosts" style="endArrow=open;endFill=1;endSize=12;html=1;exitX=1;exitY=0.5;exitDx=0;exitDy=0;entryX=-0.01;entryY=0.633;entryDx=0;entryDy=0;strokeWidth=2;entryPerimeter=0;" parent="1" source="field" target="booking-attrs" edge="1">
#       <mxGeometry width="160" relative="1" as="geometry">
#         <mxPoint x="350" y="1410" as="sourcePoint" />
#         <mxPoint x="390" y="1410" as="targetPoint" />
#       </mxGeometry>
#     </mxCell>
#     <mxCell id="assoc-field-booking-mult-1" value="1" style="edgeLabel;html=1;align=center;verticalAlign=middle;resizable=0;points=[];fontSize=14;fontStyle=1" parent="assoc-field-booking" vertex="1" connectable="0">
#       <mxGeometry x="-0.7" y="2" relative="1" as="geometry">
#         <mxPoint x="-8" y="-12" as="offset" />
#       </mxGeometry>
#     </mxCell>
#     <mxCell id="assoc-field-booking-mult-2" value="0..*" style="edgeLabel;html=1;align=center;verticalAlign=middle;resizable=0;points=[];fontSize=14;fontStyle=1" parent="assoc-field-booking" vertex="1" connectable="0">
#       <mxGeometry x="0.7" y="1" relative="1" as="geometry">
#         <mxPoint x="8" y="-12" as="offset" />
#       </mxGeometry>
#     </mxCell>
#     <mxCell id="assoc-field-service" value="provides" style="endArrow=open;endFill=1;endSize=12;html=1;exitX=0.5;exitY=1;exitDx=0;exitDy=0;entryX=0.5;entryY=0;entryDx=0;entryDy=0;strokeWidth=2;" parent="1" source="field" target="service" edge="1">
#       <mxGeometry width="160" relative="1" as="geometry">
#         <mxPoint x="190" y="1560" as="sourcePoint" />
#         <mxPoint x="190" y="1590" as="targetPoint" />
#       </mxGeometry>
#     </mxCell>
#     <mxCell id="assoc-field-service-mult-1" value="1" style="edgeLabel;html=1;align=center;verticalAlign=middle;resizable=0;points=[];fontSize=14;fontStyle=1" parent="assoc-field-service" vertex="1" connectable="0">
#       <mxGeometry x="-0.6" y="2" relative="1" as="geometry">
#         <mxPoint x="-15" y="5" as="offset" />
#       </mxGeometry>
#     </mxCell>
#     <mxCell id="assoc-field-service-mult-2" value="0..*" style="edgeLabel;html=1;align=center;verticalAlign=middle;resizable=0;points=[];fontSize=14;fontStyle=1" parent="assoc-field-service" vertex="1" connectable="0">
#       <mxGeometry x="0.6" y="1" relative="1" as="geometry">
#         <mxPoint x="15" y="-5" as="offset" />
#       </mxGeometry>
#     </mxCell>
#     <mxCell id="assoc-booking-bookingdetail" value="contains" style="endArrow=diamondThin;endFill=1;endSize=24;html=1;exitX=0.5;exitY=1;exitDx=0;exitDy=0;entryX=1.003;entryY=0.084;entryDx=0;entryDy=0;strokeWidth=2;entryPerimeter=0;" parent="1" source="booking" target="bookingdetail" edge="1">
#       <mxGeometry width="160" relative="1" as="geometry">
#         <mxPoint x="550" y="1580" as="sourcePoint" />
#         <mxPoint x="550" y="1610" as="targetPoint" />
#         <Array as="points">
#           <mxPoint x="550" y="960" />
#           <mxPoint x="400" y="960" />
#           <mxPoint x="400" y="1110" />
#           <mxPoint x="400" y="1255" />
#         </Array>
#       </mxGeometry>
#     </mxCell>
#     <mxCell id="assoc-booking-bookingdetail-mult-1" value="1" style="edgeLabel;html=1;align=center;verticalAlign=middle;resizable=0;points=[];fontSize=14;fontStyle=1" parent="assoc-booking-bookingdetail" vertex="1" connectable="0">
#       <mxGeometry x="-0.6" y="2" relative="1" as="geometry">
#         <mxPoint x="-15" y="5" as="offset" />
#       </mxGeometry>
#     </mxCell>
#     <mxCell id="assoc-booking-bookingdetail-mult-2" value="0..*" style="edgeLabel;html=1;align=center;verticalAlign=middle;resizable=0;points=[];fontSize=14;fontStyle=1" parent="assoc-booking-bookingdetail" vertex="1" connectable="0">
#       <mxGeometry x="0.6" y="1" relative="1" as="geometry">
#         <mxPoint x="15" y="-5" as="offset" />
#       </mxGeometry>
#     </mxCell>
#     <mxCell id="assoc-service-bookingdetail" value="included_in" style="endArrow=open;endFill=1;endSize=12;html=1;exitX=1;exitY=0.5;exitDx=0;exitDy=0;entryX=0;entryY=0.5;entryDx=0;entryDy=0;strokeWidth=2;dashed=1;" parent="1" source="service" target="bookingdetail" edge="1">
#       <mxGeometry width="160" relative="1" as="geometry">
#         <mxPoint x="350" y="1700" as="sourcePoint" />
#         <mxPoint x="390" y="1700" as="targetPoint" />
#         <Array as="points">
#           <mxPoint x="370" y="1060" />
#           <mxPoint x="370" y="1200" />
#           <mxPoint x="10" y="1200" />
#           <mxPoint x="10" y="1330" />
#         </Array>
#       </mxGeometry>
#     </mxCell>
#     <mxCell id="assoc-service-bookingdetail-mult-1" value="1" style="edgeLabel;html=1;align=center;verticalAlign=middle;resizable=0;points=[];fontSize=14;fontStyle=1" parent="assoc-service-bookingdetail" vertex="1" connectable="0">
#       <mxGeometry x="-0.7" y="2" relative="1" as="geometry">
#         <mxPoint x="-8" y="-12" as="offset" />
#       </mxGeometry>
#     </mxCell>
#     <mxCell id="assoc-service-bookingdetail-mult-2" value="0..*" style="edgeLabel;html=1;align=center;verticalAlign=middle;resizable=0;points=[];fontSize=14;fontStyle=1" parent="assoc-service-bookingdetail" vertex="1" connectable="0">
#       <mxGeometry x="0.7" y="1" relative="1" as="geometry">
#         <mxPoint x="8" y="-12" as="offset" />
#       </mxGeometry>
#     </mxCell>
#     <mxCell id="assoc-booking-payment" value="requires" style="endArrow=open;endFill=1;endSize=12;html=1;exitX=1;exitY=0.5;exitDx=0;exitDy=0;entryX=0;entryY=0.5;entryDx=0;entryDy=0;strokeWidth=2;" parent="1" source="booking" target="payment" edge="1">
#       <mxGeometry width="160" relative="1" as="geometry">
#         <mxPoint x="710" y="1420" as="sourcePoint" />
#         <mxPoint x="750" y="1420" as="targetPoint" />
#         <Array as="points">
#           <mxPoint x="720" y="780" />
#           <mxPoint x="720" y="970" />
#           <mxPoint x="680" y="970" />
#           <mxPoint x="680" y="1310" />
#           <mxPoint x="720" y="1310" />
#         </Array>
#       </mxGeometry>
#     </mxCell>
#     <mxCell id="assoc-booking-payment-mult-1" value="1" style="edgeLabel;html=1;align=center;verticalAlign=middle;resizable=0;points=[];fontSize=14;fontStyle=1" parent="assoc-booking-payment" vertex="1" connectable="0">
#       <mxGeometry x="-0.7" y="2" relative="1" as="geometry">
#         <mxPoint x="-8" y="-12" as="offset" />
#       </mxGeometry>
#     </mxCell>
#     <mxCell id="assoc-booking-payment-mult-2" value="0..1" style="edgeLabel;html=1;align=center;verticalAlign=middle;resizable=0;points=[];fontSize=14;fontStyle=1" parent="assoc-booking-payment" vertex="1" connectable="0">
#       <mxGeometry x="0.7" y="1" relative="1" as="geometry">
#         <mxPoint x="8" y="-12" as="offset" />
#       </mxGeometry>
#     </mxCell>
#     <mxCell id="assoc-payment-paymentgateway" value="uses" style="endArrow=open;endFill=1;endSize=12;html=1;exitX=1;exitY=0.5;exitDx=0;exitDy=0;entryX=-0.006;entryY=0.806;entryDx=0;entryDy=0;strokeWidth=2;entryPerimeter=0;" parent="1" source="payment" target="paymentgateway-attrs" edge="1">
#       <mxGeometry width="160" relative="1" as="geometry">
#         <mxPoint x="1070" y="1410" as="sourcePoint" />
#         <mxPoint x="1110" y="1410" as="targetPoint" />
#       </mxGeometry>
#     </mxCell>
#     <mxCell id="assoc-payment-paymentgateway-mult-1" value="0..*" style="edgeLabel;html=1;align=center;verticalAlign=middle;resizable=0;points=[];fontSize=14;fontStyle=1" parent="assoc-payment-paymentgateway" vertex="1" connectable="0">
#       <mxGeometry x="-0.7" y="2" relative="1" as="geometry">
#         <mxPoint x="-8" y="-12" as="offset" />
#       </mxGeometry>
#     </mxCell>
#     <mxCell id="assoc-payment-paymentgateway-mult-2" value="1" style="edgeLabel;html=1;align=center;verticalAlign=middle;resizable=0;points=[];fontSize=14;fontStyle=1" parent="assoc-payment-paymentgateway" vertex="1" connectable="0">
#       <mxGeometry x="0.7" y="1" relative="1" as="geometry">
#         <mxPoint x="8" y="-12" as="offset" />
#       </mxGeometry>
#     </mxCell>
#     <mxCell id="assoc-payment-invoice" value="generates" style="endArrow=open;endFill=1;endSize=12;html=1;exitX=0.5;exitY=1;exitDx=0;exitDy=0;entryX=0.439;entryY=0.011;entryDx=0;entryDy=0;strokeWidth=2;entryPerimeter=0;" parent="1" source="payment" target="invoice" edge="1">
#       <mxGeometry width="160" relative="1" as="geometry">
#         <mxPoint x="910" y="1560" as="sourcePoint" />
#         <mxPoint x="910" y="1590" as="targetPoint" />
#       </mxGeometry>
#     </mxCell>
#     <mxCell id="assoc-payment-invoice-mult-1" value="1" style="edgeLabel;html=1;align=center;verticalAlign=middle;resizable=0;points=[];fontSize=14;fontStyle=1" parent="assoc-payment-invoice" vertex="1" connectable="0">
#       <mxGeometry x="-0.6" y="2" relative="1" as="geometry">
#         <mxPoint x="-15" y="5" as="offset" />
#       </mxGeometry>
#     </mxCell>
#     <mxCell id="assoc-payment-invoice-mult-2" value="0..1" style="edgeLabel;html=1;align=center;verticalAlign=middle;resizable=0;points=[];fontSize=14;fontStyle=1" parent="assoc-payment-invoice" vertex="1" connectable="0">
#       <mxGeometry x="0.6" y="1" relative="1" as="geometry">
#         <mxPoint x="15" y="-5" as="offset" />
#       </mxGeometry>
#     </mxCell>
#     <mxCell id="assoc-accountingstaff-invoice" value="creates" style="endArrow=open;endFill=1;endSize=12;html=1;exitX=0.25;exitY=1;exitDx=0;exitDy=0;entryX=1;entryY=0.25;entryDx=0;entryDy=0;strokeWidth=1;dashed=1;" parent="1" source="accountingstaff" target="invoice" edge="1">
#       <mxGeometry width="160" relative="1" as="geometry">
#         <mxPoint x="1355" y="960" as="sourcePoint" />
#         <mxPoint x="1080" y="1650" as="targetPoint" />
#         <Array as="points">
#           <mxPoint x="1525" y="890" />
#           <mxPoint x="1420" y="890" />
#           <mxPoint x="1420" y="1080" />
#           <mxPoint x="1420" y="1130" />
#           <mxPoint x="1420" y="1440" />
#           <mxPoint x="1080" y="1440" />
#           <mxPoint x="1080" y="1560" />
#         </Array>
#       </mxGeometry>
#     </mxCell>
#     <mxCell id="assoc-accountingstaff-invoice-mult-1" value="1" style="edgeLabel;html=1;align=center;verticalAlign=middle;resizable=0;points=[];fontSize=14;fontStyle=1" parent="assoc-accountingstaff-invoice" vertex="1" connectable="0">
#       <mxGeometry x="-0.85" y="2" relative="1" as="geometry">
#         <mxPoint x="15" y="10" as="offset" />
#       </mxGeometry>
#     </mxCell>
#     <mxCell id="assoc-accountingstaff-invoice-mult-2" value="0..*" style="edgeLabel;html=1;align=center;verticalAlign=middle;resizable=0;points=[];fontSize=14;fontStyle=1" parent="assoc-accountingstaff-invoice" vertex="1" connectable="0">
#       <mxGeometry x="0.85" y="1" relative="1" as="geometry">
#         <mxPoint x="-15" y="-10" as="offset" />
#       </mxGeometry>
#     </mxCell>
#     <mxCell id="assoc-booking-logistic" value="ships" style="endArrow=open;endFill=1;endSize=12;html=1;exitX=0.852;exitY=1.02;exitDx=0;exitDy=0;entryX=0;entryY=0.25;entryDx=0;entryDy=0;strokeWidth=1;dashed=1;exitPerimeter=0;" parent="1" source="booking-methods" target="logistic" edge="1">
#       <mxGeometry width="160" relative="1" as="geometry">
#         <mxPoint x="710" y="1570" as="sourcePoint" />
#         <mxPoint x="1110" y="1670" as="targetPoint" />
#         <Array as="points">
#           <mxPoint x="656" y="1280" />
#           <mxPoint x="656" y="1490" />
#           <mxPoint x="656" y="1770" />
#           <mxPoint x="1080" y="1770" />
#           <mxPoint x="1080" y="1655" />
#           <mxPoint x="1080" y="1575" />
#         </Array>
#       </mxGeometry>
#     </mxCell>
#     <mxCell id="assoc-booking-logistic-mult-1" value="1" style="edgeLabel;html=1;align=center;verticalAlign=middle;resizable=0;points=[];fontSize=14;fontStyle=1" parent="assoc-booking-logistic" vertex="1" connectable="0">
#       <mxGeometry x="-0.8" y="2" relative="1" as="geometry">
#         <mxPoint x="-10" y="10" as="offset" />
#       </mxGeometry>
#     </mxCell>
#     <mxCell id="assoc-booking-logistic-mult-2" value="0..1" style="edgeLabel;html=1;align=center;verticalAlign=middle;resizable=0;points=[];fontSize=14;fontStyle=1" parent="assoc-booking-logistic" vertex="1" connectable="0">
#       <mxGeometry x="0.8" y="1" relative="1" as="geometry">
#         <mxPoint x="10" y="-10" as="offset" />
#       </mxGeometry>
#     </mxCell>
#     <mxCell id="assoc-employee-report" value="generates" style="endArrow=open;endFill=1;endSize=12;html=1;exitX=1;exitY=0.75;exitDx=0;exitDy=0;entryX=0;entryY=0.25;entryDx=0;entryDy=0;strokeWidth=1;dashed=1;" parent="1" source="employee" target="report" edge="1">
#       <mxGeometry width="160" relative="1" as="geometry">
#         <mxPoint x="1410" y="580" as="sourcePoint" />
#         <mxPoint x="1470" y="1335" as="targetPoint" />
#         <Array as="points">
#           <mxPoint x="1480" y="500" />
#           <mxPoint x="1480" y="590" />
#           <mxPoint x="1430" y="590" />
#           <mxPoint x="1430" y="975" />
#         </Array>
#       </mxGeometry>
#     </mxCell>
#     <mxCell id="assoc-employee-report-mult-1" value="1" style="edgeLabel;html=1;align=center;verticalAlign=middle;resizable=0;points=[];fontSize=14;fontStyle=1" parent="assoc-employee-report" vertex="1" connectable="0">
#       <mxGeometry x="-0.85" y="2" relative="1" as="geometry">
#         <mxPoint x="15" y="10" as="offset" />
#       </mxGeometry>
#     </mxCell>
#     <mxCell id="assoc-employee-report-mult-2" value="0..*" style="edgeLabel;html=1;align=center;verticalAlign=middle;resizable=0;points=[];fontSize=14;fontStyle=1" parent="assoc-employee-report" vertex="1" connectable="0">
#       <mxGeometry x="0.85" y="1" relative="1" as="geometry">
#         <mxPoint x="-15" y="-10" as="offset" />
#       </mxGeometry>
#     </mxCell>
#     <mxCell id="assoc-marketingstaff-campaign" value="manages" style="endArrow=open;endFill=1;endSize=12;html=1;exitX=0.5;exitY=1;exitDx=0;exitDy=0;entryX=0.5;entryY=0;entryDx=0;entryDy=0;strokeWidth=2;" parent="1" source="marketingstaff" target="campaign" edge="1">
#       <mxGeometry width="160" relative="1" as="geometry">
#         <mxPoint x="1480" y="1220" as="sourcePoint" />
#         <mxPoint x="1480" y="1540" as="targetPoint" />
#         <Array as="points">
#           <mxPoint x="1240" y="1160" />
#           <mxPoint x="1430" y="1160" />
#           <mxPoint x="1520" y="1160" />
#           <mxPoint x="1610" y="1160" />
#         </Array>
#       </mxGeometry>
#     </mxCell>
#     <mxCell id="assoc-marketingstaff-campaign-mult-1" value="1" style="edgeLabel;html=1;align=center;verticalAlign=middle;resizable=0;points=[];fontSize=14;fontStyle=1" parent="assoc-marketingstaff-campaign" vertex="1" connectable="0">
#       <mxGeometry x="-0.7" y="2" relative="1" as="geometry">
#         <mxPoint x="-15" y="10" as="offset" />
#       </mxGeometry>
#     </mxCell>
#     <mxCell id="assoc-marketingstaff-campaign-mult-2" value="0..*" style="edgeLabel;html=1;align=center;verticalAlign=middle;resizable=0;points=[];fontSize=14;fontStyle=1" parent="assoc-marketingstaff-campaign" vertex="1" connectable="0">
#       <mxGeometry x="0.7" y="1" relative="1" as="geometry">
#         <mxPoint x="15" y="-10" as="offset" />
#       </mxGeometry>
#     </mxCell>
#     <mxCell id="RyWySGgBTrj4eKPy6vWw-1" value="" style="endArrow=block;endSize=16;endFill=0;html=1;strokeWidth=2;targetPerimeterSpacing=0;" parent="1" edge="1">
#       <mxGeometry width="160" relative="1" as="geometry">
#         <mxPoint x="1220" y="320" as="sourcePoint" />
#         <mxPoint x="1040" y="240" as="targetPoint" />
#         <Array as="points">
#           <mxPoint x="1220" y="280" />
#           <mxPoint x="1220" y="240" />
#         </Array>
#       </mxGeometry>
#     </mxCell>
#     <mxCell id="M23tOcFi-PCJ6dNwYqNU-1" value="" style="endArrow=block;endSize=16;endFill=0;html=1;strokeWidth=1;dashed=1;entryX=0.009;entryY=0.142;entryDx=0;entryDy=0;entryPerimeter=0;" parent="1" target="customer-attrs" edge="1">
#       <mxGeometry width="160" relative="1" as="geometry">
#         <mxPoint x="330" y="1520" as="sourcePoint" />
#         <mxPoint x="340" y="610" as="targetPoint" />
#         <Array as="points">
#           <mxPoint x="360" y="1520" />
#           <mxPoint x="360" y="1490" />
#           <mxPoint x="360" y="1370" />
#           <mxPoint x="360" y="620" />
#           <mxPoint x="360" y="361" />
#         </Array>
#       </mxGeometry>
#     </mxCell>
#   </root>
# </mxGraphModel>

# %% [markdown]
# ![class diagram.drawio.png](<attachment:class diagram.drawio.png>)
